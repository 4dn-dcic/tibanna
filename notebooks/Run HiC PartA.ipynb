# %%
from core.utils import Tibanna
from core import ff_utils

#format for input json in hic-partA
'''
{
  "input_files": [
    {
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "object_key": "4DNFIFBK258N.fastq.gz",
      "uuid" : "06aa0af1-2ccf-4dfe-aa14-209b1bd2754d",
      "workflow_argument_name": "fastq1"
    },
    {
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "object_key": "4DNFINZVD2W3.fastq.gz",
      "uuid": "52646398-29d5-4200-b3b5-059ff5c40b82",
      "workflow_argument_name": "fastq2"
    },
    {
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "object_key": "4DNFIZQZ39L9.bwaIndex.tgz",
      "uuid": "1f53df95-4cf3-41cc-971d-81bb16c486dd",
      "workflow_argument_name": "bwa_index"
    }
        {
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "object_key": "4DNFI823LSII.chrom.sizes",
      "uuid": "4a6d10ee-2edb-4402-a98f-0edb1d58f5e9",
      "workflow_argument_name": "chrsizes"
    },
    {
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "object_key": "4DNFI823L888.fasta.gz",
      "uuid": "4a6d10ee-2edb-4402-a98f-0edb1d58ddd2",
      "workflow_argument_name": "reference_fasta"
    },
    {
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "object_key": "4DNFI823L812.txt",
      "uuid": "4a6d10ee-2edb-4402-a98f-0edb1d582084",
      "workflow_argument_name": "restriction_file"
    }
  ],
  "workflow_uuid": "02d636b9-d82d-4da9-950c-2ca994a0943e",
  "app_name": "hi-c-processing-parta/9",
  "parameters": {
    "nThreads": 8
  },
  "output_bucket": "elasticbeanstalk-fourfront-webprod-wfoutput-files",
  "_tibanna": {"env": "fourfront-webprod"}
}
'''


def make_input_file_json(obj_id, arg_name, tibanna):
    '''
    {
      "bucket_name": "%s",
      "object_key": "%s",
      "uuid" : "%s",
      "workflow_argument_name": "%s"
    }
    '''
    ff = ff_utils.fdn_connection(key=tibanna.ff_keys)
    metadata = ff_utils.get_metadata(obj_id, connection=ff)
    data = {}
    
    # just make sure the file is on s3, otherwise bail
    print("looking for upload key %s, on bucket %s" % 
          (metadata['upload_key'],
           tibanna.s3.outfile_bucket))
    if tibanna.s3.does_key_exist(metadata['upload_key']):
        data = {'bucket_name' : tibanna.s3.outfile_bucket,
                'object_key' : metadata['upload_key'].split('/')[1],
                'uuid' : metadata['uuid'],
                'workflow_argument_name': arg_name
                }
    return data
    
        
def make_hica_json(input_files, env, output_bucket, accession):
    input_json = {'input_files': input_files,
                  'output_bucket': output_bucket,
                  'workflow_uuid': "a9caf6f3-49e5-4c33-afab-9ec90d65faf3",
                  "app_name": "hi-c-processing-parta-juicer/5",
                  "parameters": {
                      "nsplit": 100
                      },
                  "_tibanna": {"env": env, "run_type": "hic-parta",
                               "run_id": accession}
                  }
    return input_json

# %%
from tasks import run_md5
from tasks import run_fastqc
from invoke import run
import time
from datetime import datetime

# for a given experiment set and some parameters like instrument
# print set of files and their partA hic workflow status
# if there are one that are running report the number of running cases
# if there are file pairs that don't have a corresponding part A, report them separately

all_sets = ['dciclab:rao_rep07',
'dciclab:rao_rep02',
'dciclab:rao_rep12',
'dciclab:rao_rep13',
'dcic:Selvaraj_gm12878_hic',
'dcic:Jin_imr90_hic']
    
my_rep_set = all_sets[5]
exclude_miseq = False
wf_md5 = "md5"
wf_fastqc = "fastqc-0-11-4-1/1"
wf_partA = "hi-c-processing-parta-juicer/5"
env = 'fourfront-webdev'
tibanna = Tibanna(env=env)
run_md_qc = raw_input("Do you wanna run md5 and/or fastqc if missing? (md5/qc/all/none)")

# status for completion
# there are two flavors of complete signals, before it was output_file_transfer_finished, not it is complete.
# old completed wf runs have former one.
status_done = ['complete', 'output_file_transfer_finished']

ff = ff_utils.fdn_connection(key=tibanna.ff_keys)
rep_resp = ff_utils.get_metadata(my_rep_set, connection=ff)['experiments_in_set']


def summarize_file(file_resp):
    qc = False
    file_id = file_resp['accession']
    sequencer = file_resp.get('instrument')
    relations = file_resp.get('related_files')
    status = file_resp.get('status')
    workflows = file_resp.get('workflow_run_inputs')
    first_alias = file_resp.get('aliases',[None])[0]
    pair_no = file_resp.get('paired_end')
    # get related file
    paired_file = ''
    for relation in relations:
        if relation['relationship_type'] == 'paired with':
            paired_file = relation['file']
    
    # is there a qc?
    if file_resp.get('quality_metric'):
        qc = True
    # Check workflows for qc fastqc workflow partA
    last_part_A = ''
    last_part_A_status = 'did_not_run'
    md5_status = 'did_not_run'
    fastqc_status = 'did_not_run'
    # Assumes workflow_runs come in time ordered list, and grabs the last ones for each wf run
    if workflows:
        for wfr in workflows:
            wfr_resp = ff_utils.get_metadata(wfr, connection=ff)
            wfr_name = wfr_resp['display_title']
            if wfr_name.startswith(wf_md5):
                md5_status = wfr_resp.get('run_status')     
            elif wfr_name.startswith(wf_fastqc):
                fastqc_status = wfr_resp.get('run_status')     
            elif wfr_name.startswith(wf_partA):
                last_part_A=wfr
                last_part_A_status = wfr_resp.get('run_status')  
                
    # Check for md5 and fastqc, and if not complete, run or report it. 
    # if exclude miseq is on, do this only if sequencer is not miseq
    if not exclude_miseq or sequencer != "Illumina MiSeq":
        # check if md5 step is completed properly
        
        if status != "uploaded" or md5_status not in status_done:
            # if not, shall we run it?
            if run_md_qc in ['md5', 'all']:
                print 'md5 running for', file_resp['accession']
                code_md5= "invoke run_md5 " + env + " " + file_resp['accession'] + " " + file_resp['uuid']
                run(code_md5)
                print ''
                time.sleep(10)
            # user does not want it to be run, so just report
            else:
                print 'md5 run missing for', file_resp['accession']
        # check fastqc if md5 is fine
        else:
            if not qc or fastqc_status not in status_done:
                # if not, shall we run it?
                if run_md_qc in ['qc', 'all']:
                    print 'fastqc running for', file_resp['accession']
                    code_qc= "invoke run_fastqc " + env + " " + file_resp['accession'] + " " + file_resp['uuid']
                    run(code_qc)
                    print ''    
                    time.sleep(10)
                # user does not want it to be run, so just report
                else:
                    print 'fastqc run missing for', file_resp['accession'], fastqc_status
                    print 
                    
#             if fastqc_status == "did_not_run":
#                     print 'fastqc running for', file_resp['accession']
#                     code_qc= "invoke run_fastqc " + env + " " + file_resp['accession'] + " " + file_resp['uuid']
#                     run(code_qc)
#                     print ''    
#                     time.sleep(10)
           
     
    # return a small report
    return {'file': file_id,
            'alias': first_alias,
            'sequencer': sequencer,
            'pair_no': pair_no,
            'paired_file': paired_file,
            'file_status': status,
            'qc': qc,
            'md5_status': md5_status,
            'fastqc_status': fastqc_status,
            'last_part_A': last_part_A,
            'last_part_A_status': last_part_A_status
           }


report = []
enzymes = []
for exp in rep_resp:
    # print 'Experiment', exp
    exp_resp = ff_utils.get_metadata(exp, connection=ff)
    exp_files = exp_resp['files']
    enzyme = exp_resp['digestion_enzyme']
    enzymes.append(enzyme)
    for fastq_file in exp_files[:]:
        file_resp = ff_utils.get_metadata(fastq_file, connection=ff)
        if file_resp['paired_end']=='2':
            continue  
        file_info = summarize_file(file_resp)

        # check for miseq
        if exclude_miseq:
            if file_info['sequencer'] == 'Illumina MiSeq':
                continue
        paired_file = file_info['paired_file']
        pair_file_resp = ff_utils.get_metadata(paired_file, connection=ff)
        pair_file_info = summarize_file(pair_file_resp)

        # check consistency of paired file info
        # status differences gives error but there are multiple statuses that indicate complete
        # TODO fix it
        pairs_inconsistent = ""
        check_items = [ i for i in file_info.keys() if i not in ['file', 'paired_file', 'pair_no', 'alias']]
        for check_item in check_items:
            try:
                assert file_info[check_item] == pair_file_info[check_item]
            except AssertionError:
                print check_item, "not the same between pair", fastq_file, 'and', paired_file
                pairs_inconsistent += check_item + ', '
        wf_check = ''
        # check if md5 and qc are okay
        for info in [file_info, pair_file_info]:
            if (info['md5_status'] in status_done and info['file_status'] == 'uploaded' and
                info['fastqc_status'] in status_done and info['qc'] == True):
                wf_check += '+'
        rep = {"consistency": pairs_inconsistent,  
               "file1": file_info['alias'],
               "file2": pair_file_info['alias'],
               "const_check": pairs_inconsistent,
               "wf_check": wf_check, 
               "partA_wf": file_info['last_part_A'], 
               "partA_status": file_info['last_part_A_status']
               }
        # status differences gives error but there are multiple statuses that indicate complete
        # TODO fix it
        report.append(rep)
        if rep.get('const_check'):
            print rep['const_check']

    
# need to add failed ones
# 1 completed pairs
pairs_completed = [i for i in report if i['partA_status']=='complete']
# 2 running pairs
pairs_running = [i for i in report if i['partA_status'] not in ['complete','did_not_run']]
# 3 no run pairs
pairs_did_not_run = [i for i in report if i['partA_status']=='did_not_run']
# 3a no run pairs with fine qc md5
pairs_ready_to_run = [(i['file1'], i['file2']) for i in pairs_did_not_run if i['wf_check'] == '++']
# 3b no run pairs with problematic qc md5
pairs_qcmd_problem = [(i['file1'], i['file2']) for i in pairs_did_not_run if i['wf_check'] != '++']

# 2 running pairs to run again
rerun_running_pairs = [(i['file1'], i['file2']) for i in report if i['partA_status'] not in ['complete','did_not_run']]



print "{}/{} pairs completed partA".format(len(report), len(pairs_completed))
print "{}/{} pairs still running partA".format(len(report), len(pairs_running))
print ",".join(i['partA_status'] for i in pairs_running)
print ''
print 'ready to run (pairs_ready_to_run)'
for a,b in pairs_ready_to_run:
    print a,b
print ""

print 'problematics ones (pairs_qcmd_problem)'
for a,b in pairs_qcmd_problem:
    print a,b
print ""

print 'running ones (rerun_running_pairs)'
for a,b in rerun_running_pairs:
    print a,b
print ""

# Choose the right NZ reference file
re_ref_file = ''
choice = {'HindIII': '4DNFI823L811', 'MboI': '4DNFI823L812'}
# Check if all experiments use the same enzyme
if len(list(set(enzymes))) != 1:
    print "ERROR Mixed Enzyme Content in Experiment Set"
else:
    nz_name = enzymes[0].split('/')[2]
    re_ref_file = choice[nz_name]
print 'using {} ({}) as the enzyme'.format(nz_name, re_ref_file)
print "DONE"
# Out:
# Do you wanna run md5 and/or fastqc if missing? (md5/qc/all/none)
# 17/0 pairs completed partA
# 17/17 pairs still running partA
# output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished,output_file_transfer_finished
#
# ready to run (pairs_ready_to_run)
#
# problematics ones (pairs_qcmd_problem)
#
# running ones (rerun_running_pairs)
# dcic:jin_SRX212172_SRR639025_1 dcic:jin_SRX212172_SRR639025_2
# dcic:jin_SRX212172_SRR639026_1 dcic:jin_SRX212172_SRR639026_2
# dcic:jin_SRX212172_SRR639027_1 dcic:jin_SRX212172_SRR639027_2
# dcic:jin_SRX212172_SRR639028_1 dcic:jin_SRX212172_SRR639028_2
# dcic:jin_SRX212172_SRR639029_1 dcic:jin_SRX212172_SRR639029_2
# dcic:jin_SRX212173_SRR639030_1 dcic:jin_SRX212173_SRR639030_2
# dcic:jin_SRX212173_SRR639031_1 dcic:jin_SRX212173_SRR639031_2
# dcic:jin_SRX212173_SRR639032_1 dcic:jin_SRX212173_SRR639032_2
# dcic:jin_SRX212173_SRR639033_1 dcic:jin_SRX212173_SRR639033_2
# dcic:jin_SRX294948_SRR881990_1 dcic:jin_SRX294948_SRR881990_2
# dcic:jin_SRX294948_SRR881991_1 dcic:jin_SRX294948_SRR881991_2
# dcic:jin_SRX294948_SRR881992_1 dcic:jin_SRX294948_SRR881992_2
# dcic:jin_SRX294949_SRR881993_1 dcic:jin_SRX294949_SRR881993_2
# dcic:jin_SRX294949_SRR881994_1 dcic:jin_SRX294949_SRR881994_2
# dcic:jin_SRX294949_SRR881995_1 dcic:jin_SRX294949_SRR881995_2
# dcic:jin_SRX294950_SRR881996_1 dcic:jin_SRX294950_SRR881996_2
# dcic:jin_SRX294951_SRR881997_1 dcic:jin_SRX294951_SRR881997_2
#
# using HindIII (4DNFI823L811) as the enzyme
# DONE

# %%
from core.utils import run_workflow
import time

# hic-partA, paired files
paired_files = rerun_running_pairs
#pairs_qcmd_problem
#pairs_ready_to_run
#rerun_running_pairs


# testportal
env = 'fourfront-webdev'
tibanna = Tibanna(env=env)
outfiles = tibanna.s3.outfile_bucket
tibanna.s3.outfile_bucket = 'elasticbeanstalk-fourfront-webdev-files'

# todo need a function to determin this given fastq1
index = make_input_file_json('4DNFIZQZ39L9', 'bwa_index', tibanna)
chrsizes = make_input_file_json('4DNFI823LSII', 'chrsizes', tibanna)
ref = make_input_file_json('4DNFI823L888', 'reference_fasta', tibanna)
restrict = make_input_file_json(re_ref_file, 'restriction_file', tibanna)

for pair in paired_files:
    fastq1 = make_input_file_json(pair[0], 'fastq1', tibanna)
    fastq2 = make_input_file_json(pair[1], 'fastq2', tibanna)
    
     
    input_files = [fastq1, fastq2, index, chrsizes, ref, restrict]
    if all(input_files):
        name = fastq1['object_key'].split('.')[0] + "-" + fastq2['object_key'].split('.')[0]
        input_json = make_hica_json(input_files, env, outfiles, name)
        res = run_workflow(input_json)
    else:
        print("some files not found on s3.  Investigate this list %s" % input_files)
    time.sleep(30)
print 'Done'
# Out:
# looking for upload key 1f53df95-4cf3-41cc-971d-81bb16c486dd/4DNFIZQZ39L9.bwaIndex.tgz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 4a6d10ee-2edb-4402-a98f-0edb1d58f5e9/4DNFI823LSII.chrom.sizes, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 4a6d10ee-2edb-4402-a98f-0edb1d58ddd2/4DNFI823L888.fasta.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 4a6d10ee-2edb-4402-a98f-0edb1d582083/4DNFI823L811.txt, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 43b41b77-5bdf-4c74-99df-9672fc496519/4DNFI4OVHWAR.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key d9a4862b-c6dd-4925-8e88-201bdfb50ef6/4DNFI2YH6GYR.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFI4OVHWAR-4DNFI2YH6GYR
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 1, 57, 266000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '10ac62a6-4a19-11e7-9d58-fd823b40271e', 'HTTPHeaders': {'x-amzn-requestid': '10ac62a6-4a19-11e7-9d58-fd823b40271e', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFI4OVHWAR-4DNFI2YH6GYR'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFI4OVHWAR-4DNFI2YH6GYR
# looking for upload key 34b3ff7f-a099-4953-a140-73239d495257/4DNFITYAC54H.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 235144f7-34ca-47f6-9e9e-9fcd7b174c17/4DNFIX74ER1E.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFITYAC54H-4DNFIX74ER1E
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 2, 28, 503000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '234917f4-4a19-11e7-83c5-25036bb7935e', 'HTTPHeaders': {'x-amzn-requestid': '234917f4-4a19-11e7-83c5-25036bb7935e', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFITYAC54H-4DNFIX74ER1E'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFITYAC54H-4DNFIX74ER1E
# looking for upload key 1eba13c7-53e1-425e-85b5-eb102c7e82c5/4DNFI11TYHYK.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 8e6e79a5-a29f-4d77-9782-022f6d6eaf99/4DNFIXTJQC23.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFI11TYHYK-4DNFIXTJQC23
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 2, 59, 714000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '35e3d24a-4a19-11e7-be04-57bc03d58bc8', 'HTTPHeaders': {'x-amzn-requestid': '35e3d24a-4a19-11e7-be04-57bc03d58bc8', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFI11TYHYK-4DNFIXTJQC23'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFI11TYHYK-4DNFIXTJQC23
# looking for upload key 1c30563c-54ca-4509-b58d-dfe8efc90cfd/4DNFI5J1EKPD.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key b2336387-4b0f-410b-a60d-2bbd65edf328/4DNFIYB8LM2V.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFI5J1EKPD-4DNFIYB8LM2V
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 3, 30, 932000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '48819928-4a19-11e7-a021-edbcb2c5db13', 'HTTPHeaders': {'x-amzn-requestid': '48819928-4a19-11e7-a021-edbcb2c5db13', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFI5J1EKPD-4DNFIYB8LM2V'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFI5J1EKPD-4DNFIYB8LM2V
# looking for upload key c25878eb-7030-43a7-b86b-72b182e2fbf7/4DNFIO53ESDG.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 657285d4-8817-4512-8d2d-eb3c5deeab53/4DNFIRZC3E2S.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFIO53ESDG-4DNFIRZC3E2S
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 4, 2, 134000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '5b1833cd-4a19-11e7-bc5c-81d16a575934', 'HTTPHeaders': {'x-amzn-requestid': '5b1833cd-4a19-11e7-bc5c-81d16a575934', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIO53ESDG-4DNFIRZC3E2S'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIO53ESDG-4DNFIRZC3E2S
# looking for upload key cb5006c4-35ad-4756-8cc9-e4e2418913ea/4DNFIIA5XWAN.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key b6315a9a-8c3c-4ba1-a703-20429b194952/4DNFIEMS6Q7F.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFIIA5XWAN-4DNFIEMS6Q7F
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 4, 33, 480000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '6dc93502-4a19-11e7-929d-d91adc48455c', 'HTTPHeaders': {'x-amzn-requestid': '6dc93502-4a19-11e7-929d-d91adc48455c', 'content-length': '149', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIIA5XWAN-4DNFIEMS6Q7F'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIIA5XWAN-4DNFIEMS6Q7F
# looking for upload key 45fbc01a-99c9-44f4-bf29-f5e4d2ad3d4a/4DNFIVQTINMQ.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 43f42a75-2756-4e64-bd98-c53a80f04d9a/4DNFIJB3EHIK.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFIVQTINMQ-4DNFIJB3EHIK
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 5, 5, 507000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '80deeb49-4a19-11e7-ad95-f999574daefb', 'HTTPHeaders': {'x-amzn-requestid': '80deeb49-4a19-11e7-ad95-f999574daefb', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIVQTINMQ-4DNFIJB3EHIK'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIVQTINMQ-4DNFIJB3EHIK
# looking for upload key 67f155e3-7b2c-43a8-bb07-c68172c68527/4DNFIDVYOR8H.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 00160a33-bf15-486e-b365-6ca715dab13f/4DNFIHQPR8I3.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFIDVYOR8H-4DNFIHQPR8I3
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 5, 36, 846000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '938c4274-4a19-11e7-9ea3-53298e7b2ba5', 'HTTPHeaders': {'x-amzn-requestid': '938c4274-4a19-11e7-9ea3-53298e7b2ba5', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIDVYOR8H-4DNFIHQPR8I3'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIDVYOR8H-4DNFIHQPR8I3
# looking for upload key 40e63422-be3a-4aae-92e4-2940fb14b187/4DNFIVK1ZA2K.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key c340841a-7331-473f-ad06-deb3bfa9f9e2/4DNFIH3VP5SH.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFIVK1ZA2K-4DNFIH3VP5SH
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 6, 8, 41000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'a62686fc-4a19-11e7-8c20-a5ea43fb8538', 'HTTPHeaders': {'x-amzn-requestid': 'a62686fc-4a19-11e7-8c20-a5ea43fb8538', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIVK1ZA2K-4DNFIH3VP5SH'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIVK1ZA2K-4DNFIH3VP5SH
# looking for upload key 58e9d609-27a1-4136-9108-671588b34f52/4DNFIT44VVVW.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 47fe65ad-a8b3-45ea-8569-63d0cd4f282c/4DNFIAKX81VG.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFIT44VVVW-4DNFIAKX81VG
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 6, 39, 269000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'b8c140ac-4a19-11e7-9301-ef76b014c81a', 'HTTPHeaders': {'x-amzn-requestid': 'b8c140ac-4a19-11e7-9301-ef76b014c81a', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIT44VVVW-4DNFIAKX81VG'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIT44VVVW-4DNFIAKX81VG
# looking for upload key 011df823-c5b8-4c40-8cff-3076c10ba264/4DNFITCP371A.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key b088fef9-ddef-4ebd-9585-44adb1a4cbbb/4DNFI8RNXX1M.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFITCP371A-4DNFI8RNXX1M
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 7, 10, 549000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'cb66f796-4a19-11e7-ba58-ff7ef50a075e', 'HTTPHeaders': {'x-amzn-requestid': 'cb66f796-4a19-11e7-ba58-ff7ef50a075e', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFITCP371A-4DNFI8RNXX1M'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFITCP371A-4DNFI8RNXX1M
# looking for upload key f07548e6-0bee-44c0-8f0f-14bea7be50d6/4DNFISN3AKHC.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key f0d8d94e-623c-46a4-bfdd-c2f7177d10d5/4DNFIAH6JZ67.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFISN3AKHC-4DNFIAH6JZ67
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 7, 41, 748000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'ddffb52a-4a19-11e7-ba83-7d71a4c577fd', 'HTTPHeaders': {'x-amzn-requestid': 'ddffb52a-4a19-11e7-ba83-7d71a4c577fd', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFISN3AKHC-4DNFIAH6JZ67'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFISN3AKHC-4DNFIAH6JZ67
# looking for upload key 79354dad-e9c1-4454-b1e4-57d01d7d2e93/4DNFI3J4IX1I.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 63dd4627-e82d-41db-a603-bd523ade37b9/4DNFIHGZ1KCE.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFI3J4IX1I-4DNFIHGZ1KCE
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 8, 12, 972000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'f09ba7f0-4a19-11e7-a080-af18ccb2d9ec', 'HTTPHeaders': {'x-amzn-requestid': 'f09ba7f0-4a19-11e7-a080-af18ccb2d9ec', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFI3J4IX1I-4DNFIHGZ1KCE'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFI3J4IX1I-4DNFIHGZ1KCE
# looking for upload key 9e794355-84fa-4a0a-abca-6a877b263be9/4DNFIOPVUOVN.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 32e1237e-085e-47d4-be9c-94130c4b9b38/4DNFINNO28MX.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFIOPVUOVN-4DNFINNO28MX
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 8, 44, 121000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '032dd630-4a1a-11e7-99f4-771dfff11462', 'HTTPHeaders': {'x-amzn-requestid': '032dd630-4a1a-11e7-99f4-771dfff11462', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIOPVUOVN-4DNFINNO28MX'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIOPVUOVN-4DNFINNO28MX
# looking for upload key 72449155-08ec-4c51-b9b2-4f025af69fa2/4DNFIN2434H6.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 0bebe20b-0e26-4bf3-9aaf-5b926154cb30/4DNFI8QYAHID.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFIN2434H6-4DNFI8QYAHID
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 9, 15, 571000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '15ced0e3-4a1a-11e7-b8ae-8dccd5e85427', 'HTTPHeaders': {'x-amzn-requestid': '15ced0e3-4a1a-11e7-b8ae-8dccd5e85427', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIN2434H6-4DNFI8QYAHID'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIN2434H6-4DNFI8QYAHID
# looking for upload key 15d010ee-7670-4a43-848f-0d63aa6231b1/4DNFIRFLBVOM.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 2cfbd102-fe5d-4c6c-8eec-43b1b852586d/4DNFI9NZTPKM.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFIRFLBVOM-4DNFI9NZTPKM
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 9, 46, 926000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '289ad441-4a1a-11e7-b8ae-8dccd5e85427', 'HTTPHeaders': {'x-amzn-requestid': '289ad441-4a1a-11e7-b8ae-8dccd5e85427', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIRFLBVOM-4DNFI9NZTPKM'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIRFLBVOM-4DNFI9NZTPKM
# looking for upload key e3be2b3a-589b-459b-ad10-41259c190ad1/4DNFIR8UNEWP.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key b1701f1b-ddef-403a-8970-a54f1dfc0db1/4DNFITWTGWVB.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# about to start run hic-parta_4DNFIR8UNEWP-4DNFITWTGWVB
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 5, 14, 10, 18, 209000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '3b425fb0-4a1a-11e7-ba19-479f914e2955', 'HTTPHeaders': {'x-amzn-requestid': '3b425fb0-4a1a-11e7-ba19-479f914e2955', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIR8UNEWP-4DNFITWTGWVB'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_3:hic-parta_4DNFIR8UNEWP-4DNFITWTGWVB
# Done
