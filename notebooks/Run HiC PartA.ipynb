# %%
from core.utils import Tibanna
from core import ff_utils

#format for input json in hic-partA
'''
{
  "input_files": [
    {
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "object_key": "4DNFIFBK258N.fastq.gz",
      "uuid" : "06aa0af1-2ccf-4dfe-aa14-209b1bd2754d",
      "workflow_argument_name": "fastq1"
    },
    {
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "object_key": "4DNFINZVD2W3.fastq.gz",
      "uuid": "52646398-29d5-4200-b3b5-059ff5c40b82",
      "workflow_argument_name": "fastq2"
    },
    {
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "object_key": "4DNFIZQZ39L9.bwaIndex.tgz",
      "uuid": "1f53df95-4cf3-41cc-971d-81bb16c486dd",
      "workflow_argument_name": "bwa_index"
    }
        {
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "object_key": "4DNFI823LSII.chrom.sizes",
      "uuid": "4a6d10ee-2edb-4402-a98f-0edb1d58f5e9",
      "workflow_argument_name": "chrsizes"
    },
    {
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "object_key": "4DNFI823L888.fasta.gz",
      "uuid": "4a6d10ee-2edb-4402-a98f-0edb1d58ddd2",
      "workflow_argument_name": "reference_fasta"
    },
    {
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "object_key": "4DNFI823L812.txt",
      "uuid": "4a6d10ee-2edb-4402-a98f-0edb1d582084",
      "workflow_argument_name": "restriction_file"
    }
  ],
  "workflow_uuid": "02d636b9-d82d-4da9-950c-2ca994a0943e",
  "app_name": "hi-c-processing-parta/9",
  "parameters": {
    "nThreads": 8
  },
  "output_bucket": "elasticbeanstalk-fourfront-webprod-wfoutput-files",
  "_tibanna": {"env": "fourfront-webprod"}
}
'''


def make_input_file_json(obj_id, arg_name, tibanna):
    '''
    {
      "bucket_name": "%s",
      "object_key": "%s",
      "uuid" : "%s",
      "workflow_argument_name": "%s"
    }
    '''
    ff = ff_utils.fdn_connection(key=tibanna.ff_keys)
    metadata = ff_utils.get_metadata(obj_id, connection=ff)
    data = {}
    
    # just make sure the file is on s3, otherwise bail
    print("looking for upload key %s, on bucket %s" % 
          (metadata['upload_key'],
           tibanna.s3.outfile_bucket))
    if tibanna.s3.does_key_exist(metadata['upload_key']):
        data = {'bucket_name' : tibanna.s3.outfile_bucket,
                'object_key' : metadata['upload_key'].split('/')[1],
                'uuid' : metadata['uuid'],
                'workflow_argument_name': arg_name
                }
    return data
    
        
def make_hica_json(input_files, env, output_bucket, accession):
    input_json = {'input_files': input_files,
                  'output_bucket': output_bucket,
                  'workflow_uuid': "a9caf6f3-49e5-4c33-afab-9ec90d65faf3",
                  "app_name": "hi-c-processing-parta-juicer/5",
                  "parameters": {
                      "nsplit": 100
                      },
                  "_tibanna": {"env": env, "run_type": "hic-parta",
                               "run_id": accession}
                  }
    return input_json

# %%
from core.utils import run_workflow
from time import sleep


# hic-partA, paired files

# ('dcic:HIC034_SRR1658608_1', 'dcic:HIC034_SRR1658608_2')
# ('dcic:HIC034_SRR1658609_1', 'dcic:HIC034_SRR1658609_2'),
# ('dcic:HIC034_SRR1658610_1', 'dcic:HIC034_SRR1658610_2'),
# ('dcic:HIC034_SRR1658611_1', 'dcic:HIC034_SRR1658611_2'),
# ('dcic:HIC034_SRR1658612_1', 'dcic:HIC034_SRR1658612_2'),
# ('dcic:HIC034_SRR1658613_1', 'dcic:HIC034_SRR1658613_2'),]
paired_files = [
('dcic:HIC034_SRR1658614_1', 'dcic:HIC034_SRR1658614_2'),
('dcic:HIC034_SRR1658615_1', 'dcic:HIC034_SRR1658615_2'),
('dcic:HIC034_SRR1658616_1', 'dcic:HIC034_SRR1658616_2'),
('dcic:HIC034_SRR1658617_1', 'dcic:HIC034_SRR1658617_2'),
('dcic:HIC034_SRR1658618_1', 'dcic:HIC034_SRR1658618_2'),
('dcic:HIC034_SRR1658619_1', 'dcic:HIC034_SRR1658619_2'),
('dcic:HIC034_SRR1658620_1', 'dcic:HIC034_SRR1658620_2'),
('dcic:HIC034_SRR1658621_1', 'dcic:HIC034_SRR1658621_2'),
('dcic:HIC034_SRR1658622_1', 'dcic:HIC034_SRR1658622_2'),
('dcic:HIC034_SRR1658623_1', 'dcic:HIC034_SRR1658623_2'),
('dcic:HIC034_SRR1658624_1', 'dcic:HIC034_SRR1658624_2'),
('dcic:HIC035_SRR1658625_1', 'dcic:HIC035_SRR1658625_2'),
('dcic:HIC035_SRR1658626_1', 'dcic:HIC035_SRR1658626_2'),
('dcic:HIC035_SRR1658627_1', 'dcic:HIC035_SRR1658627_2'),
('dcic:HIC035_SRR1658628_1', 'dcic:HIC035_SRR1658628_2'),
('dcic:HIC035_SRR1658629_1', 'dcic:HIC035_SRR1658629_2'),
('dcic:HIC035_SRR1658630_1', 'dcic:HIC035_SRR1658630_2'),
('dcic:HIC035_SRR1658631_1', 'dcic:HIC035_SRR1658631_2'),
('dcic:HIC037_SRR1658636_1', 'dcic:HIC037_SRR1658636_2'),
('dcic:HIC037_SRR1658637_1', 'dcic:HIC037_SRR1658637_2'),
('dcic:HIC037_SRR1658638_1', 'dcic:HIC037_SRR1658638_2'),
('dcic:HIC037_SRR1658639_1', 'dcic:HIC037_SRR1658639_2'),
('dcic:HIC037_SRR1658640_1', 'dcic:HIC037_SRR1658640_2'),
('dcic:HIC037_SRR1658641_1', 'dcic:HIC037_SRR1658641_2'),
('dcic:HIC037_SRR1658642_1', 'dcic:HIC037_SRR1658642_2'),
('dcic:HIC037_SRR1658643_1', 'dcic:HIC037_SRR1658643_2')]


# testportal
env = 'fourfront-webdev'
tibanna = Tibanna(env=env)
outfiles = tibanna.s3.outfile_bucket
tibanna.s3.outfile_bucket = 'elasticbeanstalk-fourfront-webdev-files'

# todo need a function to determin this given fastq1
index = make_input_file_json('4DNFIZQZ39L9', 'bwa_index', tibanna)
chrsizes = make_input_file_json('4DNFI823LSII', 'chrsizes', tibanna)
ref = make_input_file_json('4DNFI823L888', 'reference_fasta', tibanna)
restrict = make_input_file_json('4DNFI823L811', 'restriction_file', tibanna)

for pair in paired_files:
    fastq1 = make_input_file_json(pair[0], 'fastq1', tibanna)
    fastq2 = make_input_file_json(pair[1], 'fastq2', tibanna)
    
     
    input_files = [fastq1, fastq2, index, chrsizes, ref, restrict]
    if all(input_files):
        name = fastq1['object_key'].split('.')[0] + "-" + fastq2['object_key'].split('.')[0]
        input_json = make_hica_json(input_files, env, outfiles, name)
        print(input_json)
        res = run_workflow(input_json)
        print(res)
        sleep(30)
    else:
        print("some files not found on s3.  Investigate this list %s" % input_files)
# Out:
# looking for upload key 1f53df95-4cf3-41cc-971d-81bb16c486dd/4DNFIZQZ39L9.bwaIndex.tgz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 4a6d10ee-2edb-4402-a98f-0edb1d58f5e9/4DNFI823LSII.chrom.sizes, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 4a6d10ee-2edb-4402-a98f-0edb1d58ddd2/4DNFI823L888.fasta.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 4a6d10ee-2edb-4402-a98f-0edb1d582083/4DNFI823L811.txt, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 1c94ab53-a6fd-4dd1-9850-f81ca8616068/4DNFIVY3BZMM.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key cf4fa989-499b-4063-8469-a3e2136c0596/4DNFIEFEXUXO.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'env': 'fourfront-webdev', 'run_id': u'4DNFIVY3BZMM-4DNFIEFEXUXO'}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1c94ab53-a6fd-4dd1-9850-f81ca8616068', 'object_key': u'4DNFIVY3BZMM.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'cf4fa989-499b-4063-8469-a3e2136c0596', 'object_key': u'4DNFIEFEXUXO.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# about to start run hic-parta_4DNFIVY3BZMM-4DNFIEFEXUXO
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 1, 15, 58, 47, 210000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'b94641b4-4704-11e7-82af-ade95c65548d', 'HTTPHeaders': {'x-amzn-requestid': 'b94641b4-4704-11e7-82af-ade95c65548d', 'content-length': '149', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIVY3BZMM-4DNFIEFEXUXO'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIVY3BZMM-4DNFIEFEXUXO
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'run_id': u'4DNFIVY3BZMM-4DNFIEFEXUXO', 'url': u'https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIVY3BZMM-4DNFIEFEXUXO', 'env': 'fourfront-webdev', 'run_name': u'hic-parta_4DNFIVY3BZMM-4DNFIEFEXUXO', 'response': {u'startDate': datetime.datetime(2017, 6, 1, 15, 58, 47, 210000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'b94641b4-4704-11e7-82af-ade95c65548d', 'HTTPHeaders': {'x-amzn-requestid': 'b94641b4-4704-11e7-82af-ade95c65548d', 'content-length': '149', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIVY3BZMM-4DNFIEFEXUXO'}}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1c94ab53-a6fd-4dd1-9850-f81ca8616068', 'object_key': u'4DNFIVY3BZMM.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'cf4fa989-499b-4063-8469-a3e2136c0596', 'object_key': u'4DNFIEFEXUXO.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# looking for upload key e5c763af-4913-4e0f-a15c-433fc2d32f92/4DNFI4UTQXGU.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key cbc3af92-680a-4225-bf6d-90da52d632d5/4DNFI9E5AM3U.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'env': 'fourfront-webdev', 'run_id': u'4DNFI4UTQXGU-4DNFI9E5AM3U'}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'e5c763af-4913-4e0f-a15c-433fc2d32f92', 'object_key': u'4DNFI4UTQXGU.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'cbc3af92-680a-4225-bf6d-90da52d632d5', 'object_key': u'4DNFI9E5AM3U.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# about to start run hic-parta_4DNFI4UTQXGU-4DNFI9E5AM3U
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 1, 15, 59, 18, 126000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'cbb334a8-4704-11e7-be04-57bc03d58bc8', 'HTTPHeaders': {'x-amzn-requestid': 'cbb334a8-4704-11e7-be04-57bc03d58bc8', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI4UTQXGU-4DNFI9E5AM3U'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI4UTQXGU-4DNFI9E5AM3U
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'run_id': u'4DNFI4UTQXGU-4DNFI9E5AM3U', 'url': u'https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI4UTQXGU-4DNFI9E5AM3U', 'env': 'fourfront-webdev', 'run_name': u'hic-parta_4DNFI4UTQXGU-4DNFI9E5AM3U', 'response': {u'startDate': datetime.datetime(2017, 6, 1, 15, 59, 18, 126000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'cbb334a8-4704-11e7-be04-57bc03d58bc8', 'HTTPHeaders': {'x-amzn-requestid': 'cbb334a8-4704-11e7-be04-57bc03d58bc8', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI4UTQXGU-4DNFI9E5AM3U'}}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'e5c763af-4913-4e0f-a15c-433fc2d32f92', 'object_key': u'4DNFI4UTQXGU.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'cbc3af92-680a-4225-bf6d-90da52d632d5', 'object_key': u'4DNFI9E5AM3U.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# looking for upload key 15c3846a-c7c7-47e8-a0f0-09e8e4a8c4d0/4DNFICZD91ZI.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 7ee01ee6-810d-472a-8cc5-e1a5ee28c14f/4DNFIDU76BTO.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'env': 'fourfront-webdev', 'run_id': u'4DNFICZD91ZI-4DNFIDU76BTO'}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'15c3846a-c7c7-47e8-a0f0-09e8e4a8c4d0', 'object_key': u'4DNFICZD91ZI.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'7ee01ee6-810d-472a-8cc5-e1a5ee28c14f', 'object_key': u'4DNFIDU76BTO.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# about to start run hic-parta_4DNFICZD91ZI-4DNFIDU76BTO
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 1, 15, 59, 49, 129000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'de2be80a-4704-11e7-8b13-e74ce02ad7f2', 'HTTPHeaders': {'x-amzn-requestid': 'de2be80a-4704-11e7-8b13-e74ce02ad7f2', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFICZD91ZI-4DNFIDU76BTO'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFICZD91ZI-4DNFIDU76BTO
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'run_id': u'4DNFICZD91ZI-4DNFIDU76BTO', 'url': u'https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFICZD91ZI-4DNFIDU76BTO', 'env': 'fourfront-webdev', 'run_name': u'hic-parta_4DNFICZD91ZI-4DNFIDU76BTO', 'response': {u'startDate': datetime.datetime(2017, 6, 1, 15, 59, 49, 129000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'de2be80a-4704-11e7-8b13-e74ce02ad7f2', 'HTTPHeaders': {'x-amzn-requestid': 'de2be80a-4704-11e7-8b13-e74ce02ad7f2', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFICZD91ZI-4DNFIDU76BTO'}}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'15c3846a-c7c7-47e8-a0f0-09e8e4a8c4d0', 'object_key': u'4DNFICZD91ZI.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'7ee01ee6-810d-472a-8cc5-e1a5ee28c14f', 'object_key': u'4DNFIDU76BTO.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# looking for upload key 408633c7-a0e2-4dea-b631-acffe0e2f56a/4DNFI2L4MQA4.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 374755ac-2324-4c25-a05d-a1c05f86ffe8/4DNFIEG1CJ5A.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'env': 'fourfront-webdev', 'run_id': u'4DNFI2L4MQA4-4DNFIEG1CJ5A'}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'408633c7-a0e2-4dea-b631-acffe0e2f56a', 'object_key': u'4DNFI2L4MQA4.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'374755ac-2324-4c25-a05d-a1c05f86ffe8', 'object_key': u'4DNFIEG1CJ5A.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# about to start run hic-parta_4DNFI2L4MQA4-4DNFIEG1CJ5A
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 1, 16, 0, 20, 93000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'f0a2c640-4704-11e7-b5ae-4758ad2d3037', 'HTTPHeaders': {'x-amzn-requestid': 'f0a2c640-4704-11e7-b5ae-4758ad2d3037', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI2L4MQA4-4DNFIEG1CJ5A'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI2L4MQA4-4DNFIEG1CJ5A
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'run_id': u'4DNFI2L4MQA4-4DNFIEG1CJ5A', 'url': u'https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI2L4MQA4-4DNFIEG1CJ5A', 'env': 'fourfront-webdev', 'run_name': u'hic-parta_4DNFI2L4MQA4-4DNFIEG1CJ5A', 'response': {u'startDate': datetime.datetime(2017, 6, 1, 16, 0, 20, 93000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'f0a2c640-4704-11e7-b5ae-4758ad2d3037', 'HTTPHeaders': {'x-amzn-requestid': 'f0a2c640-4704-11e7-b5ae-4758ad2d3037', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI2L4MQA4-4DNFIEG1CJ5A'}}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'408633c7-a0e2-4dea-b631-acffe0e2f56a', 'object_key': u'4DNFI2L4MQA4.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'374755ac-2324-4c25-a05d-a1c05f86ffe8', 'object_key': u'4DNFIEG1CJ5A.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# looking for upload key 3f2a5d03-3cdc-4296-869e-e9b65f4be115/4DNFIW7ZIRSJ.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key dcb3c7b1-02fc-4274-8344-9f161865a24e/4DNFI8I8OTDB.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'env': 'fourfront-webdev', 'run_id': u'4DNFIW7ZIRSJ-4DNFI8I8OTDB'}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'3f2a5d03-3cdc-4296-869e-e9b65f4be115', 'object_key': u'4DNFIW7ZIRSJ.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'dcb3c7b1-02fc-4274-8344-9f161865a24e', 'object_key': u'4DNFI8I8OTDB.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# about to start run hic-parta_4DNFIW7ZIRSJ-4DNFI8I8OTDB
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 1, 16, 0, 51, 57000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '03178147-4705-11e7-b769-639ced86bc7e', 'HTTPHeaders': {'x-amzn-requestid': '03178147-4705-11e7-b769-639ced86bc7e', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIW7ZIRSJ-4DNFI8I8OTDB'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIW7ZIRSJ-4DNFI8I8OTDB
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'run_id': u'4DNFIW7ZIRSJ-4DNFI8I8OTDB', 'url': u'https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIW7ZIRSJ-4DNFI8I8OTDB', 'env': 'fourfront-webdev', 'run_name': u'hic-parta_4DNFIW7ZIRSJ-4DNFI8I8OTDB', 'response': {u'startDate': datetime.datetime(2017, 6, 1, 16, 0, 51, 57000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '03178147-4705-11e7-b769-639ced86bc7e', 'HTTPHeaders': {'x-amzn-requestid': '03178147-4705-11e7-b769-639ced86bc7e', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIW7ZIRSJ-4DNFI8I8OTDB'}}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'3f2a5d03-3cdc-4296-869e-e9b65f4be115', 'object_key': u'4DNFIW7ZIRSJ.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'dcb3c7b1-02fc-4274-8344-9f161865a24e', 'object_key': u'4DNFI8I8OTDB.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# looking for upload key c30904c6-59d5-40a8-9b83-ea5ba45d8acf/4DNFIVK5KLYD.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key b9e8bc94-ea98-46e7-8966-7273d9659376/4DNFIT9DWUKX.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'env': 'fourfront-webdev', 'run_id': u'4DNFIVK5KLYD-4DNFIT9DWUKX'}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'c30904c6-59d5-40a8-9b83-ea5ba45d8acf', 'object_key': u'4DNFIVK5KLYD.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'b9e8bc94-ea98-46e7-8966-7273d9659376', 'object_key': u'4DNFIT9DWUKX.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# about to start run hic-parta_4DNFIVK5KLYD-4DNFIT9DWUKX
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 1, 16, 1, 21, 990000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '15862215-4705-11e7-b769-639ced86bc7e', 'HTTPHeaders': {'x-amzn-requestid': '15862215-4705-11e7-b769-639ced86bc7e', 'content-length': '149', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIVK5KLYD-4DNFIT9DWUKX'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIVK5KLYD-4DNFIT9DWUKX
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'run_id': u'4DNFIVK5KLYD-4DNFIT9DWUKX', 'url': u'https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIVK5KLYD-4DNFIT9DWUKX', 'env': 'fourfront-webdev', 'run_name': u'hic-parta_4DNFIVK5KLYD-4DNFIT9DWUKX', 'response': {u'startDate': datetime.datetime(2017, 6, 1, 16, 1, 21, 990000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '15862215-4705-11e7-b769-639ced86bc7e', 'HTTPHeaders': {'x-amzn-requestid': '15862215-4705-11e7-b769-639ced86bc7e', 'content-length': '149', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIVK5KLYD-4DNFIT9DWUKX'}}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'c30904c6-59d5-40a8-9b83-ea5ba45d8acf', 'object_key': u'4DNFIVK5KLYD.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'b9e8bc94-ea98-46e7-8966-7273d9659376', 'object_key': u'4DNFIT9DWUKX.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# looking for upload key d6dc1ef4-b38c-4ac5-ae09-fde15e457e50/4DNFIY36REX9.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key a5651f73-4aad-4e31-a167-58c8f64f9c76/4DNFIPNXCQ9F.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'env': 'fourfront-webdev', 'run_id': u'4DNFIY36REX9-4DNFIPNXCQ9F'}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'd6dc1ef4-b38c-4ac5-ae09-fde15e457e50', 'object_key': u'4DNFIY36REX9.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'a5651f73-4aad-4e31-a167-58c8f64f9c76', 'object_key': u'4DNFIPNXCQ9F.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# about to start run hic-parta_4DNFIY36REX9-4DNFIPNXCQ9F
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 1, 16, 1, 52, 994000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '2803903c-4705-11e7-9253-d5ed90e6b1a6', 'HTTPHeaders': {'x-amzn-requestid': '2803903c-4705-11e7-9253-d5ed90e6b1a6', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIY36REX9-4DNFIPNXCQ9F'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIY36REX9-4DNFIPNXCQ9F
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'run_id': u'4DNFIY36REX9-4DNFIPNXCQ9F', 'url': u'https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIY36REX9-4DNFIPNXCQ9F', 'env': 'fourfront-webdev', 'run_name': u'hic-parta_4DNFIY36REX9-4DNFIPNXCQ9F', 'response': {u'startDate': datetime.datetime(2017, 6, 1, 16, 1, 52, 994000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '2803903c-4705-11e7-9253-d5ed90e6b1a6', 'HTTPHeaders': {'x-amzn-requestid': '2803903c-4705-11e7-9253-d5ed90e6b1a6', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIY36REX9-4DNFIPNXCQ9F'}}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'd6dc1ef4-b38c-4ac5-ae09-fde15e457e50', 'object_key': u'4DNFIY36REX9.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'a5651f73-4aad-4e31-a167-58c8f64f9c76', 'object_key': u'4DNFIPNXCQ9F.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# looking for upload key d3c26303-63df-4f79-8f2a-8c6c613075f5/4DNFI9LWLVE2.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key d0f63edd-6a02-4540-ab15-63a0d507ce6e/4DNFIQ4ZHBGK.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'env': 'fourfront-webdev', 'run_id': u'4DNFI9LWLVE2-4DNFIQ4ZHBGK'}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'd3c26303-63df-4f79-8f2a-8c6c613075f5', 'object_key': u'4DNFI9LWLVE2.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'd0f63edd-6a02-4540-ab15-63a0d507ce6e', 'object_key': u'4DNFIQ4ZHBGK.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# about to start run hic-parta_4DNFI9LWLVE2-4DNFIQ4ZHBGK
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 1, 16, 2, 24, 177000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '3a98f231-4705-11e7-8f07-e58cb2ca047a', 'HTTPHeaders': {'x-amzn-requestid': '3a98f231-4705-11e7-8f07-e58cb2ca047a', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI9LWLVE2-4DNFIQ4ZHBGK'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI9LWLVE2-4DNFIQ4ZHBGK
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'run_id': u'4DNFI9LWLVE2-4DNFIQ4ZHBGK', 'url': u'https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI9LWLVE2-4DNFIQ4ZHBGK', 'env': 'fourfront-webdev', 'run_name': u'hic-parta_4DNFI9LWLVE2-4DNFIQ4ZHBGK', 'response': {u'startDate': datetime.datetime(2017, 6, 1, 16, 2, 24, 177000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '3a98f231-4705-11e7-8f07-e58cb2ca047a', 'HTTPHeaders': {'x-amzn-requestid': '3a98f231-4705-11e7-8f07-e58cb2ca047a', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI9LWLVE2-4DNFIQ4ZHBGK'}}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'd3c26303-63df-4f79-8f2a-8c6c613075f5', 'object_key': u'4DNFI9LWLVE2.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'd0f63edd-6a02-4540-ab15-63a0d507ce6e', 'object_key': u'4DNFIQ4ZHBGK.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# looking for upload key 3b32b27f-2190-4755-b0d3-238e6c39818c/4DNFIVARLIEL.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 45bf8114-65ee-4da1-95df-ea66d078960e/4DNFIII7S21P.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'env': 'fourfront-webdev', 'run_id': u'4DNFIVARLIEL-4DNFIII7S21P'}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'3b32b27f-2190-4755-b0d3-238e6c39818c', 'object_key': u'4DNFIVARLIEL.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'45bf8114-65ee-4da1-95df-ea66d078960e', 'object_key': u'4DNFIII7S21P.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# about to start run hic-parta_4DNFIVARLIEL-4DNFIII7S21P
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 1, 16, 2, 55, 357000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '4d2e7bec-4705-11e7-82af-ade95c65548d', 'HTTPHeaders': {'x-amzn-requestid': '4d2e7bec-4705-11e7-82af-ade95c65548d', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIVARLIEL-4DNFIII7S21P'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIVARLIEL-4DNFIII7S21P
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'run_id': u'4DNFIVARLIEL-4DNFIII7S21P', 'url': u'https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIVARLIEL-4DNFIII7S21P', 'env': 'fourfront-webdev', 'run_name': u'hic-parta_4DNFIVARLIEL-4DNFIII7S21P', 'response': {u'startDate': datetime.datetime(2017, 6, 1, 16, 2, 55, 357000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '4d2e7bec-4705-11e7-82af-ade95c65548d', 'HTTPHeaders': {'x-amzn-requestid': '4d2e7bec-4705-11e7-82af-ade95c65548d', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIVARLIEL-4DNFIII7S21P'}}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'3b32b27f-2190-4755-b0d3-238e6c39818c', 'object_key': u'4DNFIVARLIEL.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'45bf8114-65ee-4da1-95df-ea66d078960e', 'object_key': u'4DNFIII7S21P.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# looking for upload key 868e6527-5495-41fd-ad6f-9bcfd1de2df0/4DNFIF5VB6NK.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key be88968e-6c7d-42a8-be54-21ce1c8bb6a4/4DNFI9T1BJDX.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'env': 'fourfront-webdev', 'run_id': u'4DNFIF5VB6NK-4DNFI9T1BJDX'}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'868e6527-5495-41fd-ad6f-9bcfd1de2df0', 'object_key': u'4DNFIF5VB6NK.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'be88968e-6c7d-42a8-be54-21ce1c8bb6a4', 'object_key': u'4DNFI9T1BJDX.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# about to start run hic-parta_4DNFIF5VB6NK-4DNFI9T1BJDX
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 1, 16, 3, 26, 468000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '5fba1ab3-4705-11e7-bc43-9f0a74a99d27', 'HTTPHeaders': {'x-amzn-requestid': '5fba1ab3-4705-11e7-bc43-9f0a74a99d27', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIF5VB6NK-4DNFI9T1BJDX'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIF5VB6NK-4DNFI9T1BJDX
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'run_id': u'4DNFIF5VB6NK-4DNFI9T1BJDX', 'url': u'https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIF5VB6NK-4DNFI9T1BJDX', 'env': 'fourfront-webdev', 'run_name': u'hic-parta_4DNFIF5VB6NK-4DNFI9T1BJDX', 'response': {u'startDate': datetime.datetime(2017, 6, 1, 16, 3, 26, 468000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '5fba1ab3-4705-11e7-bc43-9f0a74a99d27', 'HTTPHeaders': {'x-amzn-requestid': '5fba1ab3-4705-11e7-bc43-9f0a74a99d27', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIF5VB6NK-4DNFI9T1BJDX'}}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'868e6527-5495-41fd-ad6f-9bcfd1de2df0', 'object_key': u'4DNFIF5VB6NK.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'be88968e-6c7d-42a8-be54-21ce1c8bb6a4', 'object_key': u'4DNFI9T1BJDX.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# looking for upload key f0fc8a1c-55f9-4c0e-af7c-976bc2d1200f/4DNFITGPJTAS.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 75c4a8f6-3bdd-49b2-ac0e-336ade46ba24/4DNFITRLBCFN.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# ...
# looking for upload key 44e538aa-0e1f-4721-be34-b1d080b3ef66/4DNFIZW9JOY1.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key dd3b4939-fced-4f00-978c-69e382bf9bd9/4DNFIPTCHIBN.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'env': 'fourfront-webdev', 'run_id': u'4DNFIZW9JOY1-4DNFIPTCHIBN'}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'44e538aa-0e1f-4721-be34-b1d080b3ef66', 'object_key': u'4DNFIZW9JOY1.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'dd3b4939-fced-4f00-978c-69e382bf9bd9', 'object_key': u'4DNFIPTCHIBN.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# about to start run hic-parta_4DNFIZW9JOY1-4DNFIPTCHIBN
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 1, 16, 10, 43, 942000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '647ba497-4706-11e7-8674-7108a479d7a9', 'HTTPHeaders': {'x-amzn-requestid': '647ba497-4706-11e7-8674-7108a479d7a9', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIZW9JOY1-4DNFIPTCHIBN'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIZW9JOY1-4DNFIPTCHIBN
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'run_id': u'4DNFIZW9JOY1-4DNFIPTCHIBN', 'url': u'https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIZW9JOY1-4DNFIPTCHIBN', 'env': 'fourfront-webdev', 'run_name': u'hic-parta_4DNFIZW9JOY1-4DNFIPTCHIBN', 'response': {u'startDate': datetime.datetime(2017, 6, 1, 16, 10, 43, 942000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '647ba497-4706-11e7-8674-7108a479d7a9', 'HTTPHeaders': {'x-amzn-requestid': '647ba497-4706-11e7-8674-7108a479d7a9', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIZW9JOY1-4DNFIPTCHIBN'}}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'44e538aa-0e1f-4721-be34-b1d080b3ef66', 'object_key': u'4DNFIZW9JOY1.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'dd3b4939-fced-4f00-978c-69e382bf9bd9', 'object_key': u'4DNFIPTCHIBN.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# looking for upload key 3316bd3b-9329-44c3-b708-3ceef0022904/4DNFI9DO1YH1.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key c3c79f5b-023c-466f-a37e-968e30bd15b7/4DNFIB8AUUCG.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'env': 'fourfront-webdev', 'run_id': u'4DNFI9DO1YH1-4DNFIB8AUUCG'}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'3316bd3b-9329-44c3-b708-3ceef0022904', 'object_key': u'4DNFI9DO1YH1.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'c3c79f5b-023c-466f-a37e-968e30bd15b7', 'object_key': u'4DNFIB8AUUCG.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# about to start run hic-parta_4DNFI9DO1YH1-4DNFIB8AUUCG
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 1, 16, 11, 16, 467000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '77dfa2aa-4706-11e7-9362-3fea5261dcf1', 'HTTPHeaders': {'x-amzn-requestid': '77dfa2aa-4706-11e7-9362-3fea5261dcf1', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI9DO1YH1-4DNFIB8AUUCG'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI9DO1YH1-4DNFIB8AUUCG
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'run_id': u'4DNFI9DO1YH1-4DNFIB8AUUCG', 'url': u'https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI9DO1YH1-4DNFIB8AUUCG', 'env': 'fourfront-webdev', 'run_name': u'hic-parta_4DNFI9DO1YH1-4DNFIB8AUUCG', 'response': {u'startDate': datetime.datetime(2017, 6, 1, 16, 11, 16, 467000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '77dfa2aa-4706-11e7-9362-3fea5261dcf1', 'HTTPHeaders': {'x-amzn-requestid': '77dfa2aa-4706-11e7-9362-3fea5261dcf1', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFI9DO1YH1-4DNFIB8AUUCG'}}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'3316bd3b-9329-44c3-b708-3ceef0022904', 'object_key': u'4DNFI9DO1YH1.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'c3c79f5b-023c-466f-a37e-968e30bd15b7', 'object_key': u'4DNFIB8AUUCG.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# looking for upload key 65a8b56e-5664-4116-be04-c202630b85ba/4DNFIX5SUONU.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# looking for upload key 5ccf4483-5ac6-4800-a56a-3e62c8f2e6f8/4DNFILM4KI4B.fastq.gz, on bucket elasticbeanstalk-fourfront-webdev-files
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'env': 'fourfront-webdev', 'run_id': u'4DNFIX5SUONU-4DNFILM4KI4B'}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'65a8b56e-5664-4116-be04-c202630b85ba', 'object_key': u'4DNFIX5SUONU.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'5ccf4483-5ac6-4800-a56a-3e62c8f2e6f8', 'object_key': u'4DNFILM4KI4B.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
# about to start run hic-parta_4DNFIX5SUONU-4DNFILM4KI4B
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 6, 1, 16, 11, 47, 552000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '8a69ba30-4706-11e7-8c20-a5ea43fb8538', 'HTTPHeaders': {'x-amzn-requestid': '8a69ba30-4706-11e7-8c20-a5ea43fb8538', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIX5SUONU-4DNFILM4KI4B'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIX5SUONU-4DNFILM4KI4B
# {'parameters': {'nsplit': 100}, '_tibanna': {'run_type': 'hic-parta', 'run_id': u'4DNFIX5SUONU-4DNFILM4KI4B', 'url': u'https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIX5SUONU-4DNFILM4KI4B', 'env': 'fourfront-webdev', 'run_name': u'hic-parta_4DNFIX5SUONU-4DNFILM4KI4B', 'response': {u'startDate': datetime.datetime(2017, 6, 1, 16, 11, 47, 552000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '8a69ba30-4706-11e7-8c20-a5ea43fb8538', 'HTTPHeaders': {'x-amzn-requestid': '8a69ba30-4706-11e7-8c20-a5ea43fb8538', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_sbg_workflow_2:hic-parta_4DNFIX5SUONU-4DNFILM4KI4B'}}, 'output_bucket': 'elasticbeanstalk-fourfront-webdev-wfoutput', 'input_files': [{'workflow_argument_name': 'fastq1', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'65a8b56e-5664-4116-be04-c202630b85ba', 'object_key': u'4DNFIX5SUONU.fastq.gz'}, {'workflow_argument_name': 'fastq2', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'5ccf4483-5ac6-4800-a56a-3e62c8f2e6f8', 'object_key': u'4DNFILM4KI4B.fastq.gz'}, {'workflow_argument_name': 'bwa_index', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'1f53df95-4cf3-41cc-971d-81bb16c486dd', 'object_key': u'4DNFIZQZ39L9.bwaIndex.tgz'}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}, {'workflow_argument_name': 'reference_fasta', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58ddd2', 'object_key': u'4DNFI823L888.fasta.gz'}, {'workflow_argument_name': 'restriction_file', 'bucket_name': 'elasticbeanstalk-fourfront-webdev-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d582083', 'object_key': u'4DNFI823L811.txt'}], 'workflow_uuid': 'a9caf6f3-49e5-4c33-afab-9ec90d65faf3', 'app_name': 'hi-c-processing-parta-juicer/5'}
