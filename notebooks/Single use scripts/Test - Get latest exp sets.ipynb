# %%
from core.utils import Tibanna
from core import ff_utils


# for a given experiment set and some parameters like instrument
# print set of files and their partA hic workflow status
# if there are one that are running report the number of running cases
# if there are file pairs that don't have a corresponding part A, report them separately

env = 'fourfront-webprod'
tibanna = Tibanna(env=env)

file_not_found = 0
deleted = 0
uploading = 0
success = 0
patch_problem = 0
ff = ff_utils.fdn_connection(key=tibanna.ff_keys)
urlm = '/search/?award.project=4DN&experiments_in_set.experiment_type=in%20situ%20Hi-C&experiments_in_set.experiment_type=dilution%20Hi-C&experiments_in_set.experiment_type=capture%20Hi-C&experiments_in_set.experiment_type=DNase%20Hi-C&experiments_in_set.experiment_type=micro-C&experiments_in_set.experiment_type=CHIA-pet&experiments_in_set.experiment_type=TrAC-loop&experiments_in_set.experiment_type=PLAC-seq&experimentset_type=replicate&type=ExperimentSetReplicate&sort=-date_created'
set_resp = ff_utils.get_metadata(urlm, connection=ff)

# %%
my_sets = set_resp['@graph']
my_sets = [i for i in my_sets if i['status'] != 'deleted']
print(len(my_sets))
for i in my_sets:
    print '"'+i['aliases'][0]+'",'
# Out:
# 48
# "ruan-lab:HFFc6_CTCF",
# "zhaolab:Experiment_TrACloop_h1wa01",
# "zhaolab:Experiment_TrACloop_gm12878",
# "disteche_lab:DNaseHiC-WG-F1-brain_repset",
# "disteche_lab:insituDNaseHiC-WG-Patski-Del-Ds-TR_repset",
# "disteche_lab:insituDNaseHiC-WG-Patski-Inv-5'-Ds-TR_repset",
# "disteche_lab:insituDNaseHiC-WG-Patski-Inv-Dxz4_repset",
# "disteche_lab:insituDNaseHiC-WG-Patski-Del-Dxz4_repset",
# "disteche_lab:insituDNaseHiC-WG-Patski-Del-hinge_repset",
# "disteche_lab:insituDNaseHiC-WG-Patski-WT_repset",
# "ruan-lab:H1_CTCF",
# "ren:HFFc6_H3K4me3_PLACseq",
# "ren:H1_H3K4me3_PLACseq",
# "ruan-lab:GM12878_RNAPII",
# "ruan-lab:GM12878_CTCF",
# "chuck-murry-lab:fetal_heart_insitu_dnase_hic",
# "chuck-murry-lab:rues2_cm_insitu_dnase_hic",
# "chuck-murry-lab:rues2_cp_insitu_dnase_hic",
# "chuck-murry-lab:rues2_mes_insitu_dnase_hic",
# "chuck-murry-lab:rues2_esc_insitu_dnase_hic",
# "dekker:h1_microc_repset",
# "dekker:hffc6_microc_repset",
# "dekker-lab:ExperimentSet_U54_HFFc6-FA-DpnII",
# ...

# %%
NEW LIST

# "ruan-lab:HFFc6_CTCF",

# "kaufman:set2_MEF_ nonXL_nucleolar_umass",
# "kaufman:set1_MEF_nonXL_ genomic_umass",
# "yue-lab:HFFC6_ChIPseq_input",

# "zhaolab:Experiment_TrACloop_h1wa01",
# "zhaolab:Experiment_TrACloop_gm12878",


"disteche_lab:DNaseHiC-WG-F1-brain_repset",
"disteche_lab:insituDNaseHiC-WG-Patski-Del-Ds-TR_repset",
"disteche_lab:insituDNaseHiC-WG-Patski-Inv-5'-Ds-TR_repset",
"disteche_lab:insituDNaseHiC-WG-Patski-Inv-Dxz4_repset",
"disteche_lab:insituDNaseHiC-WG-Patski-Del-Dxz4_repset",
"disteche_lab:insituDNaseHiC-WG-Patski-Del-hinge_repset",
"disteche_lab:insituDNaseHiC-WG-Patski-WT_repset",




"ruan-lab:H1_CTCF",

ruan-lab:H1_CTCF
[u'human']
/files-fastq/4DNFISTNZMGV/ 4DNFIFADHPSI 0.8
/files-fastq/4DNFIWVP3FYL/ 4DNFIWIWCZA2 35.6
/files-fastq/4DNFI61TSIX2/ 4DNFIF5ZRDYC 0.8
[u'ruan-lab:H1_CTCF_rep2_hiseq_fastq_R1'] larger than 42GB, skipping, please use another script

"ren:HFFc6_H3K4me3_PLACseq",
"ren:H1_H3K4me3_PLACseq",


"ruan-lab:GM12878_RNAPII",
ruan-lab:GM12878_RNAPII
[u'human']
/files-fastq/4DNFI49YARYL/ 4DNFIVZQY9UE 1.6
[u'ruan-lab:GM12878_RNAPII_rep1_hiseq_fastq_R1'] larger than 42GB, skipping, please use another script
/files-fastq/4DNFIC39YRWS/ 4DNFI8R49IG2 2.1
[u'ruan-lab:GM12878_RNAPII_rep2_hiseq_fastq_R1'] larger than 42GB, skipping, please use another script
/files-fastq/4DNFIEEWE1R4/ 4DNFIQ51QR18 3.3
[u'ruan-lab:GM12878_RNAPII_rep3_hiseq_fastq_R1'] larger than 42GB, skipping, please use another script



"ruan-lab:GM12878_CTCF",

"chuck-murry-lab:fetal_heart_rna_seq",
"chuck-murry-lab:fetal_heart_insitu_dnase_hic",
# "chuck-murry-lab:rues2_cm_insitu_dnase_hic",
# "chuck-murry-lab:rues2_cp_insitu_dnase_hic",
# "chuck-murry-lab:rues2_mes_insitu_dnase_hic",
# "chuck-murry-lab:rues2_esc_insitu_dnase_hic",



# "dekker:h1_microc_repset",
# "dekker:hffc6_microc_repset",
# "dekker-lab:ExperimentSet_U54_HFFc6-FA-DpnII",

# "dekker-lab:ExperimentSet_U54_U54-h1ESC-Maehr-DpnII-FA",
# "dekker-lab:ExperimentSet_U54_U54-HFF-beads-NcoI-FA",
# "dekker-lab:ExperimentSet_U54_U54-h1ESC-Maehr-HindIII-FA",
# "dekker-lab:ExperimentSet_U54_U54-HFF-beads-HindIII-FA-Technicalreplicateset",
# "dekker-lab:ExperimentSet_U54_U54-h1ESC-Maehr-NcoI-FA",
# "dekker-lab:ExperimentSet_U54_U54-HFF-plate-HindIII-FA",
# "dekker-lab:ExperimentSet_U54_U54-HFF-beads-MboI-FA",
# "dekker-lab:ExperimentSet_U54_U54-HFF-beads-DpnII-FA-Technicalreplicateset",


"ren:DKO_D25_HiC",
"ren:DKO_D15_HiC",
"ren:DKO_D0_HiC",
"ren:E14_D25_HiC",
"ren:E14_D15_HiC",
"ren:E14_D0_HiC",
"dekker-lab:ExperimentSet_U54_U54-HFF-p45-FA-HindIII-Technicalreplicateset",
"dekker-lab:ExperimentSet_U54_U54-ESC4DN-FA-DpnII-2017524",

"ren:HG00514_repset",
"ren:HG00513_repset",
"ren:HG00512_repset",
"ren:HG00733_repset",
"ren:HG00732_repset",
"ren:HG00731_repset",
"ren:GM19240_repset",
"ren:GM19239_repset",
"ren:GM19238_repset",





DELETE THIS ONES


# "chuck-murry-lab:rues2_cm_rna_seq",
# "chuck-murry-lab:rues2_cp_rna_seq",
# "chuck-murry-lab:rues2_mes_rna_seq",
# "chuck-murry-lab:rues2_esc_rna_seq",

"yue-lab:HFFC6_H3K4me3",
"yue-lab:HFFC6_H3K4me1",

# "yue-lab:HFFC6_ChIPseq_input",



Think about this

# "guttman-lab:Experiment_DNA_SPRITE-HFFc6-01",

# "kaufman:set2_MEF_ nonXL_nucleolar_umass",
# "kaufman:set1_MEF_nonXL_ genomic_umass",
# "kaufman:set8_H1_XL_nucleolar",
# "kaufman:set7_H1_XL_ genomic",
# "kaufman:set6_HFFc6_XL_nucleolar",
# "kaufman:set5_HFFc6_ XL_genomic",
# "kaufman:set4_MEF_XL_nucleolar",
# "kaufman:set3_MEF_XL_ genomic",
# "kaufman:set2_MEF_ nonXL_nucleolar",
# "kaufman:set1_MEF_nonXL_ genomic",
# Out:
#   File "<ipython-input-10-dcd7ed3aeb7d>", line 1
#     NEW LIST
#            ^
# SyntaxError: invalid syntax

# %%
"henikoff_lab:cutnrun_H1_H2AZ_3min_repset2",
"henikoff_lab:cutnrun_H1_K27a_3min_repset2",
"henikoff_lab:cutnrun_K562_IG_3min_repset",
"henikoff_lab:cutnrun_K562_K27a_3min_repset",
"henikoff_lab:cutnrun_K562_K4m1_3min_repset",
"henikoff_lab:cutnrun_K562_H2AZ_3min_repset",
"henikoff_lab:cutnrun_K562_K27m_3min_repset",
"henikoff_lab:cutnrun_K562_K4m3_3min_repset",
"henikoff_lab:cutnrun_K562_K4m2_3min_repset",
"henikoff_lab:cutnrun_K562_K27a_1min_repset",
"henikoff_lab:cutnrun_K562_CTCF_5min_repset",
"henikoff_lab:cutnrun_H1_IgG_3min_repset",
"henikoff_lab:cutnrun_H1_NPAT_3min_repset",
"henikoff_lab:cutnrun_H1_H2AZ_3min_repset",
"henikoff_lab:cutnrun_H1_K27m_3min_repset",
"henikoff_lab:cutnrun_H1_K4m3_3min_repset",
"henikoff_lab:cutnrun_H1_K4m1_3min_repset",
"henikoff_lab:cutnrun_H1_Ezh2_3min_repset",
"henikoff_lab:cutnrun_H1_Sz12_3min_repset",
"henikoff_lab:cutnrun_H1_CBX7_3min_repset",
"henikoff_lab:cutnrun_H1_R1B_3min_repset",
"henikoff_lab:cutnrun_H1_K27m_9min_repset",
"henikoff_lab:cutnrun_H1_K4m2_3min_repset",
"henikoff_lab:cutnrun_H1_K4m2_1min_repset",
"henikoff_lab:cutnrun_H1_K27a_9min_repset",
"henikoff_lab:cutnrun_H1_K27a_3min_repset",
"henikoff_lab:cutnrun_H1_K27a_20sec_repset",
"henikoff_lab:cutnrun_H1_CTCF_9min_repset",
"henikoff_lab:cutnrun_H1_CTCF_20sec_repset",


# "ruan-lab:HFFc6_CTCF",
# "kaufman:set2_MEF_ nonXL_nucleolar_umass",
# "kaufman:set1_MEF_nonXL_ genomic_umass",
# "yue-lab:HFFC6_ChIPseq_input",
# "zhaolab:Experiment_TrACloop_h1wa01",
# "zhaolab:Experiment_TrACloop_gm12878",
# "guttman-lab:Experiment_DNA_SPRITE-HFFc6-01",
# "kaufman:set8_H1_XL_nucleolar",
# "kaufman:set7_H1_XL_ genomic",
# "kaufman:set6_HFFc6_XL_nucleolar",
# "kaufman:set5_HFFc6_ XL_genomic",
# "kaufman:set4_MEF_XL_nucleolar",
# "kaufman:set3_MEF_XL_ genomic",
# "kaufman:set2_MEF_ nonXL_nucleolar",
# "kaufman:set1_MEF_nonXL_ genomic",


"disteche_lab:DNaseHiC-WG-F1-brain_repset",
"disteche_lab:ATACseq-Patski-2-4clone_repset",
"disteche_lab:ATACseq-Patski-Inv-Dxz4_repset",
"disteche_lab:ATACseq-Patski-Del-hinge_repset",
"disteche_lab:ATACseq-Patski-WT_repset",
"disteche_lab:Input-DNA-Patski-Del-hinge_repset",
"disteche_lab:Input-DNA-Patski-WT_repset",
"disteche_lab:CTCF-ChIPseq-Patski-2-4clone_repset",
"disteche_lab:CTCF-ChIPSeq-Patski-Inv-Dxz4_repset",
"disteche_lab:CTCF-ChIPseq-Patski-Del-hinge_repset",
"disteche_lab:CTCF-ChIPSeq-Patski-WT_repset",
"disteche_lab:RNAseq-Patski-2-4_repset",
"disteche_lab:RNAseq-Patski-Inv-Dxz4-cloneb_repset",
"disteche_lab:RNAseq-Patski-Inv-Dxz4-clonea_repset",
"disteche_lab:RNAseq-Patski-Del-Dxz4_repset",
"disteche_lab:RNAseq-Patski-Del-Ds-TR_repset",
"disteche_lab:RNAseq-Patski-Del-hinge-4u5aza_repset",
"disteche_lab:RNAseq-Patski-Del-hinge-0u5aza_repset",
"disteche_lab:RNAseq-Patski-Del-hinge-cloneb_repset",
"disteche_lab:RNAseq-Patski-Del-hinge-clonea_repset",
"disteche_lab:RNAseq-Patski-WT-4u5aza_repset",
"disteche_lab:RNAseq-Patski-WT-0u5aza_repset",
"disteche_lab:RNAseq-Patski-WT_repset",
"disteche_lab:insituDNaseHiC-WG-Patski-Del-Ds-TR_repset",
"disteche_lab:insituDNaseHiC-WG-Patski-Inv-5'-Ds-TR_repset",
"disteche_lab:insituDNaseHiC-WG-Patski-Inv-Dxz4_repset",
"disteche_lab:insituDNaseHiC-WG-Patski-Del-Dxz4_repset",
"disteche_lab:insituDNaseHiC-WG-Patski-Del-hinge_repset",
"disteche_lab:insituDNaseHiC-WG-Patski-WT_repset",
"gilbert-lab:HFFc6_L_phase_R3and4",
"gilbert-lab:HFFc6_E_phase_R3andR4",
"shendure:h1esc_scihi-c_repset",
"shendure:hff_scihi-c_repset",
"shendure:gm_scihi-c_repset",
"gilbert-lab:H1_16fRepli-Seq_R1_P17",
"gilbert-lab:H1_16fRepli-Seq_R1_P16",
"gilbert-lab:H1_16fRepli-Seq_R1_P15",
"gilbert-lab:H1_16fRepli-Seq_R1_P14",
"gilbert-lab:H1_16fRepli-Seq_R1_P13",
"gilbert-lab:H1_16fRepli-Seq_R1_P12",
"gilbert-lab:H1_16fRepli-Seq_R1_P11",
"gilbert-lab:H1_16fRepli-Seq_R1_P10",
"gilbert-lab:H1_16fRepli-Seq_R1_P9",
"gilbert-lab:H1_16fRepli-Seq_R1_P8",
"gilbert-lab:H1_16fRepli-Seq_R1_P7",
"gilbert-lab:H1_16fRepli-Seq_R1_P6",
"gilbert-lab:H1_16fRepli-Seq_R1_P5",
"gilbert-lab:H1_16fRepli-Seq_R1_P4",
"gilbert-lab:H1_16fRepli-Seq_R1_P3",
"gilbert-lab:H1_16fRepli-Seq_R1_P2",
"gilbert-lab:H1_16fRepli-Seq_R1_G1",


"ruan-lab:H1_CTCF",

ruan-lab:H1_CTCF
[u'human']
/files-fastq/4DNFISTNZMGV/ 4DNFIFADHPSI 0.8
/files-fastq/4DNFIWVP3FYL/ 4DNFIWIWCZA2 35.6
/files-fastq/4DNFI61TSIX2/ 4DNFIF5ZRDYC 0.8
[u'ruan-lab:H1_CTCF_rep2_hiseq_fastq_R1'] larger than 42GB, skipping, please use another script


"yue-lab:HFFC6_H3K27me3",
"yue-lab:HFFC6_H3K27ac",
"yue-lab:HFFC6_H3K4me3",
"yue-lab:HFFC6_H3K4me1",
"ren:HFFc6_H3K4me3_PLACseq",
"ren:H1_H3K4me3_PLACseq",


"ruan-lab:GM12878_RNAPII",
ruan-lab:GM12878_RNAPII
[u'human']
/files-fastq/4DNFI49YARYL/ 4DNFIVZQY9UE 1.6
[u'ruan-lab:GM12878_RNAPII_rep1_hiseq_fastq_R1'] larger than 42GB, skipping, please use another script
/files-fastq/4DNFIC39YRWS/ 4DNFI8R49IG2 2.1
[u'ruan-lab:GM12878_RNAPII_rep2_hiseq_fastq_R1'] larger than 42GB, skipping, please use another script
/files-fastq/4DNFIEEWE1R4/ 4DNFIQ51QR18 3.3
[u'ruan-lab:GM12878_RNAPII_rep3_hiseq_fastq_R1'] larger than 42GB, skipping, please use another script



"ruan-lab:GM12878_CTCF",
"ana-pombo-lab:GAM_H1hESC",


"chuck-murry-lab:fetal_heart_rna_seq",
# "chuck-murry-lab:rues2_cm_rna_seq",
# "chuck-murry-lab:rues2_cp_rna_seq",
# "chuck-murry-lab:rues2_mes_rna_seq",
# "chuck-murry-lab:rues2_esc_rna_seq",
# "chuck-murry-lab:rues2_cm_atac_seq",
# "chuck-murry-lab:rues2_cp_atac_seq",
# "chuck-murry-lab:rues2_mes_atac_seq",
# "chuck-murry-lab:rues2_esc_atac_seq",
"chuck-murry-lab:fetal_heart_insitu_dnase_hic",
# "chuck-murry-lab:rues2_cm_insitu_dnase_hic",
# "chuck-murry-lab:rues2_cp_insitu_dnase_hic",
# "chuck-murry-lab:rues2_mes_insitu_dnase_hic",
# "chuck-murry-lab:rues2_esc_insitu_dnase_hic",


# "vanSteensel-lab:HFFc6_Dam",
# "vanSteensel-lab:HFFc6_LmnB1",
# "vanSteensel-lab:H1_Dam",
# "vanSteensel-lab:H1_LmnB1",
# "dekker:h1_microc_repset",
# "dekker:hffc6_microc_repset",
# "dekker-lab:ExperimentSet_U54_HFFc6-FA-DpnII",


# "misteli:1sub_006",
# "misteli:1sub_005",
# "misteli:1sub_004",
# "misteli:1sub_003",
# "misteli:1sub_002",


# "dekker-lab:ExperimentSet_U54_U54-H1ESC-4DN-Maehr-ATAC-Seq",
# "dekker-lab:ExperimentSet_U54_U54-h1ESC-Maehr-DpnII-FA",
# "dekker-lab:ExperimentSet_U54_U54-HFF-beads-NcoI-FA",
# "dekker-lab:ExperimentSet_U54_U54-h1ESC-Maehr-HindIII-FA",
# "dekker-lab:ExperimentSet_U54_U54-HFF-beads-HindIII-FA-Technicalreplicateset",
# "dekker-lab:ExperimentSet_U54_U54-h1ESC-Maehr-NcoI-FA",
# "dekker-lab:ExperimentSet_U54_U54-HFF-plate-HindIII-FA",
# "dekker-lab:ExperimentSet_U54_U54-HFF-beads-MboI-FA",
# "dekker-lab:ExperimentSet_U54_U54-HFF-beads-DpnII-FA-Technicalreplicateset",




"ren:DKO_D25_HiC",
"ren:DKO_D15_HiC",
"ren:DKO_D0_HiC",
"ren:E14_D25_HiC",
"ren:E14_D15_HiC",
"ren:E14_D0_HiC",
"dekker-lab:ExperimentSet_U54_U54-HFF-p45-FA-HindIII-Technicalreplicateset",
"gilbert-lab:HEK293_L_phase",
"gilbert-lab:HEK293_E_phase",
"gilbert-lab:U2OS_L_phase",
"gilbert-lab:U2OS_E_phase",
"gilbert-lab:HCT116_L_phase",
"gilbert-lab:HCT116_E_phase",
"gilbert-lab:K562_L_phase",
"gilbert-lab:K562_E_phase",
"gilbert-lab:F121-9_L_phase",
"gilbert-lab:F121-9_E_phase",
"gilbert-lab:H9_L_phase",
"gilbert-lab:H9_E_phase",
"gilbert-lab:RPEhTERT_L_phase",
"gilbert-lab:RPEhTERT_E_phase",
"gilbert-lab:HFFc6_L_phase",
"gilbert-lab:HFFc6_E_phase",
"gilbert-lab:IMR90_L_phase",
"gilbert-lab:IMR90_E_phase",
"gilbert-lab:H1_L_phase",
"gilbert-lab:H1_E_phase",
"gilbert-lab:GM12878_L_phase",
"gilbert-lab:GM12878_E_phase",
"dekker-lab:ExperimentSet_U54_U54-HFFc6-NS-ATAC",
"dekker-lab:ExperimentSet_U54_U54-ESC4DN-FA-DpnII-2017524",
"dcic:Jin_imr90_hic",
"dcic:Selvaraj_gm12878_hic",


"dekker-lab:ExperimentSet_Encode_SK-N-DZ-FA-HindIII-dimethylsulfoxide",
"dekker-lab:ExperimentSet_Encode_A549-FA-HindIII",
"dekker-lab:ExperimentSet_Encode_SK-N-DZ-FA-HindIII",
"dekker-lab:ExperimentSet_Encode_T47D-FA-HindIII",
"dekker-lab:ExperimentSet_Encode_SK-N-MC-FA-HindIII",
"dekker-lab:ExperimentSet_Encode_Caki2-FA-HindIII",
"dekker-lab:ExperimentSet_Encode_SJCRH30-FA-HindIII",
"dekker-lab:ExperimentSet_Encode_LNCaPcloneFGC-FA-HindIII",
"dekker-lab:ExperimentSet_Encode_G401-FA-HindIII",
"dekker-lab:ExperimentSet_Encode_Panc1-FA-HindIII",
"dekker-lab:ExperimentSet_Encode_SK-MEL-5-FA-HindIII",
"dekker-lab:ExperimentSet_Encode_NCI-H460-FA-HindIII",
"dekker-lab:ExperimentSet_Encode_RPMI-7951-FA-HindIII",
"ren:HG00514_repset",
"ren:HG00513_repset",
"ren:HG00512_repset",
"ren:HG00733_repset",
"ren:HG00732_repset",
"ren:HG00731_repset",
"ren:GM19240_repset",
"ren:GM19239_repset",
"ren:GM19238_repset",
