# %%
from core.utils import Tibanna
from core import ff_utils

#format for input json in hic-partA
def make_input_file_json(obj_id, arg_name, tibanna):
    '''
    {
      "bucket_name": "%s",
      "object_key": "%s",
      "uuid" : "%s",
      "workflow_argument_name": "%s"
    }
    '''
    ff = ff_utils.fdn_connection(key=tibanna.ff_keys)
    metadata = ff_utils.get_metadata(obj_id, connection=ff)
    data = {}
    
    # just make sure the file is on s3, otherwise bail
    print("looking for upload key %s, on bucket %s" % 
          (metadata['upload_key'],
           tibanna.s3.outfile_bucket))
    if tibanna.s3.does_key_exist(metadata['upload_key']):
        data = {'bucket_name' : tibanna.s3.outfile_bucket,
                'object_key' : metadata['upload_key'].split('/')[1],
                'uuid' : metadata['uuid'],
                'workflow_argument_name': arg_name
                }
    return data
    

def make_hic1_json(input_files, env, output_bucket, accession):
    input_json = {'input_files': input_files,
                  'output_bucket': output_bucket,
                  'workflow_uuid': "3feedadc-50f9-4bb4-919b-09a8b731d0cc",
                  "app_name": "bwa-mem",
                  "parameters": {
                      "nThreads": 16
                      },
                  "config": {
                        "ebs_type": "io1",
                        "json_bucket": "4dn-aws-pipeline-run-json",
                        "ebs_iops": 500,
                        "shutdown_min": 30,
                        "s3_access_arn": "arn:aws:iam::643366669028:instance-profile/S3_access",
                        "ami_id": "ami-cfb14bb5",
                        "copy_to_s3": True,
                        "launch_instance": True,
                        "password": "dragonfly",
                        "log_bucket": "tibanna-output",
                        "script_url": "https://raw.githubusercontent.com/4dn-dcic/tibanna/master/awsf/",
                        "key_name": ""
                    },
                  "_tibanna": {"env": env, "run_type": "bwa-mem",
                               "run_id": accession},
                  "tag": "0.2.5"
                  }
    return input_json

# %%
from tasks import run_md5
from tasks import run_fastqc
from invoke import run
import time
from datetime import datetime

# for a given experiment set and some parameters like instrument
# print set of files and their partA hic workflow status
# if there are one that are running report the number of running cases
# if there are file pairs that don't have a corresponding part A, report them separately



exclude_miseq = True

wf_md5 = "md5"
wf_fastqc = "fastqc-0-11-4-1"
wf_partA = "bwa-mem 0.2.5"

env = 'fourfront-webprod'
tibanna = Tibanna(env=env)

run_md_qc = raw_input("Do you wanna run md5 and/or fastqc if missing? (md5/qc/all/none)")

# status for completion
# there are two flavors of complete signals, before it was output_file_transfer_finished, not it is complete.
# old completed wf runs have former one.
status_done = ['complete', 'output_file_transfer_finished']
status_good = ['uploaded', 'released', 'released to project']
ff = ff_utils.fdn_connection(key=tibanna.ff_keys)

################
##ADD TO WORKFLOW
# wfr_time = datetime.strptime(wfr_data['date_created'],'%Y-%m-%dT%H:%M:%S.%f+00:00')
# run_hours = int((datetime.now()-wfr_time).total_seconds()/3600)
################

def summarize_file(file_resp):
    qc = False
    file_id = file_resp['accession']
    sequencer = file_resp.get('instrument')
    relations = file_resp.get('related_files')
    status = file_resp.get('status')
    workflows = file_resp.get('workflow_run_inputs')
    first_alias = file_resp.get('aliases',[None])[0]
    pair_no = file_resp.get('paired_end')
    # get related file
    paired_file = ''
    for relation in relations:
        if relation['relationship_type'] == 'paired with':
            paired_file = relation['file']['accession']
    
    # is there a qc?
    if file_resp.get('quality_metric'):
        qc = True
        
    # Check workflows for qc fastqc workflow partA
    last_part_A = ''
    last_part_A_status = 'did_not_run'
    md5_status = 'did_not_run'
    fastqc_status = 'did_not_run'
    # Assumes workflow_runs come in time ordered list, and grabs the last ones for each wf run
    if workflows:
        for a_wfr in workflows:
            wfr_resp = ff_utils.get_metadata(a_wfr['uuid'], connection=ff)  
            wfr_name = wfr_resp['display_title']
            if wfr_name.startswith(wf_md5):
                md5_status = wfr_resp.get('run_status')     
            elif wfr_name.startswith(wf_fastqc):
                fastqc_status = wfr_resp.get('run_status')     
            elif wfr_name.startswith(wf_partA):
                last_part_A=wfr_resp['uuid']
                last_part_A_status = wfr_resp.get('run_status')  
                
    # Check for md5 and fastqc, and if not complete, run or report it. 
    # if exclude miseq is on, do this only if sequencer is not miseq
    if not exclude_miseq or sequencer != "Illumina MiSeq":
        # check if md5 step is completed properly
        
        if status not in status_good or md5_status not in status_done:
            # if not, shall we run it?
            if run_md_qc in ['md5', 'all']:
                print 'md5 running for', file_resp['accession']
                code_md5= "invoke run_md5 " + env + " " + file_resp['accession'] + " " + file_resp['uuid']
                run(code_md5)
                print ''
                time.sleep(10)
            # user does not want it to be run, so just report
            else:
                print 'md5 run missing for', file_resp['accession']
        # check fastqc if md5 is fine
        else:

            if not qc or fastqc_status not in status_done:
                # if not, shall we run it?
                if run_md_qc in ['qc', 'all']:
                    print 'fastqc running for', file_resp['accession']
                    code_qc= "invoke run_fastqc " + env + " " + file_resp['accession'] + " " + file_resp['uuid']
                    run(code_qc)
                    print ''    
                    time.sleep(10)
                # user does not want it to be run, so just report
                else:
                    print 'fastqc run missing for', file_resp['accession'], fastqc_status
                    print 
   
    # return a small report
    return {'file': file_id,
            'alias': first_alias,
            'sequencer': sequencer,
            'pair_no': pair_no,
            'paired_file': paired_file,
            'file_status': status,
            'qc': qc,
            'md5_status': md5_status,
            'fastqc_status': fastqc_status,
            'last_part_A': last_part_A,
            'last_part_A_status': last_part_A_status
           }


def get_file_list(my_rep_set):

    rep_resp = ff_utils.get_metadata(my_rep_set, connection=ff)['experiments_in_set']
    report = []
    enzymes = []
    organisms = []
    for exp in rep_resp:
        exp_resp = ff_utils.get_metadata(exp, connection=ff)

        if not organisms:
            biosample = ff_utils.get_metadata(exp_resp['biosample'], connection=ff, frame='embedded')      
            organisms = list(set([bs['individual']['organism']['display_title'] for bs in  biosample['biosource']]))
            print organisms

        exp_files = exp_resp['files']
        enzyme = exp_resp.get('digestion_enzyme')
        enzymes.append(enzyme)
        for fastq_file in exp_files:
            file_resp = ff_utils.get_metadata(fastq_file, connection=ff, frame='embedded')  
            #Some checks before running
            #check if status is deleted
            if file_resp['status'] == 'deleted':
                continue
            #if no uploaded file in the file item report and skip
            if not file_resp.get('filename'):
                print file_resp['accession'], "does not have a file"
                continue
            # check if file is in s3
            head_info = tibanna.s3.does_key_exist(file_resp['upload_key'], tibanna.s3.raw_file_bucket)
            if not head_info:
                print file_resp['accession'], "does not have a file in S3"
                continue

            # skip pair no 2
            if file_resp.get('paired_end')=='2':
                continue 

            # if the file size is more than 42 GB do not run
            file_size = head_info['ContentLength']
            if file_size > 45097156608:
                print file_resp['aliases'], 'larger than 42GB, skipping, please use another script'
                continue
            filesize = round(head_info['ContentLength']/1073741824.0,1)

            file_info = summarize_file(file_resp)

            # check for miseq
            if exclude_miseq:
                if file_info['sequencer'] == 'Illumina MiSeq':
                    continue
            paired_file = file_info['paired_file']
            pair_file_resp = ff_utils.get_metadata(paired_file, connection=ff, frame='embedded')
            pair_file_info = summarize_file(pair_file_resp)
            print fastq_file,paired_file, filesize

            # check consistency of paired file info
            # status differences gives error but there are multiple statuses that indicate complete
            # TODO fix it
            pairs_inconsistent = ""
            check_items = [ i for i in file_info.keys() if i not in ['file', 'paired_file', 'pair_no', 'alias']]
            for check_item in check_items:
                try:
                    assert file_info[check_item] == pair_file_info[check_item]
                except AssertionError:
                    print check_item, "not the same between pair", fastq_file, 'and', paired_file
                    pairs_inconsistent += check_item + ', '
            wf_check = ''
            # check if md5 and qc are okay
            for info in [file_info, pair_file_info]:
                if (info['md5_status'] in status_done and info['file_status'] in status_good and
                    info['fastqc_status'] in status_done and info['qc'] == True):
                    wf_check += '+'
            rep = {"consistency": pairs_inconsistent,  
                   "file1": file_info['alias'],
                   "file2": pair_file_info['alias'],
                   "const_check": pairs_inconsistent,
                   "wf_check": wf_check, 
                   "partA_wf": file_info['last_part_A'], 
                   "partA_status": file_info['last_part_A_status']
                   }
            # status differences gives error but there are multiple statuses that indicate complete
            # TODO fix it
            report.append(rep)
            if rep.get('const_check'):
                print rep['const_check']
    
    return my_rep_set, organisms, report
# Out:
# Do you wanna run md5 and/or fastqc if missing? (md5/qc/all/none)

# %%
all_reports = []
rest = ['4DNESCQ7ZD21',
'4DNESUZ3Y5GY',
'4DNESIV168N6',
'4DNESR9S8R38',
'4DNESO1IVQSC',
'4DNESNPHX8LY',
'4DNESOOCOBBA']
for a_set in rest:
    rep = get_file_list(a_set)
    if rep:
        all_reports.append(rep)
print 'done'
# Out:
# [u'human']
# fastqc run missing for 4DNFIFF7K2ZC did_not_run
#
# fastqc run missing for 4DNFIEPLTDNG did_not_run
#
# /files-fastq/4DNFIFF7K2ZC/ 4DNFIEPLTDNG 1.2
# fastqc run missing for 4DNFIWB5O95D did_not_run
#
# fastqc run missing for 4DNFIJ95LUGK did_not_run
#
# /files-fastq/4DNFIWB5O95D/ 4DNFIJ95LUGK 24.6
# fastqc run missing for 4DNFIOOZOF4F did_not_run
#
# fastqc run missing for 4DNFIJ4JO7H2 did_not_run
#
# /files-fastq/4DNFIOOZOF4F/ 4DNFIJ4JO7H2 0.8
# fastqc run missing for 4DNFIB734M8W did_not_run
#
# fastqc run missing for 4DNFIPG8BLCU did_not_run
#
# /files-fastq/4DNFIB734M8W/ 4DNFIPG8BLCU 26.0
# [u'human']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-69f281148aaa> in <module>()
#       8 '4DNESOOCOBBA']
#       9 for a_set in rest:
# ---> 10     rep = get_file_list(a_set)
#      11     if rep:
#      12         all_reports.append(rep)
#
# <ipython-input-6-d9d3584d7629> in get_file_list(my_rep_set)
#     164             filesize = round(head_info['ContentLength']/1073741824.0,1)
#     165
# --> 166             file_info = summarize_file(file_resp)
#     167
#     168             # check for miseq
#
# <ipython-input-6-d9d3584d7629> in summarize_file(file_resp)
#      47     # get related file
#      48     paired_file = ''
# ---> 49     for relation in relations:
#      50         if relation['relationship_type'] == 'paired with':
#      51             paired_file = relation['file']['accession']
#
# TypeError: 'NoneType' object is not iterable

# %%
pairs_completed = []
pairs_running = []
pairs_did_not_run = []
pairs_ready_to_run = []
pairs_qcmd_problem = []

all_num= 0
for name, org, report in all_reports: 
    all_num += len(report)
    
    # 1 completed pairs
    pairs_completed.extend([[name,org,i] for i in report if i['partA_status']=='complete'])
    # 2 running pairs
    pairs_running.extend([[name, org, i] for i in report if i['partA_status'] not in ['complete','did_not_run']])
    # 3 no run pairs
    pairs_did_not_run.extend([[name, org, i] for i in report if i['partA_status']=='did_not_run'])
                             
                            
# 3a no run pairs with fine qc md5
pairs_ready_to_run = [[i[0], i[1], i[2]['file1'], i[2]['file2']] for i in pairs_did_not_run if i[2]['wf_check'] == '++']
# 3b no run pairs with problematic qc md5
pairs_qcmd_problem = [[i[0], i[1], i[2]['file1'], i[2]['file2']] for i in pairs_did_not_run if i[2]['wf_check'] != '++']

# # 2 running pairs to run again
# rerun_running_pairs = [(i['file1'], i['file2']) for i in report if i['partA_status'] not in ['complete','did_not_run']]

# rerun_started_pairs = [(i['file1'], i['file2']) for i in report if i['partA_status']=='started']

print "{}/{} pairs completed partA".format(all_num, len(pairs_completed))
print "{}/{} pairs still running partA".format(all_num, len(pairs_running))

print '1) ready to run (pairs_ready_to_run)'
print len(pairs_ready_to_run)
for n,o,a,b in pairs_ready_to_run:
    print n,o,a,b
print ""

print '2) problematics ones (pairs_qcmd_problem)'
for n,o,a,b in pairs_qcmd_problem:
    print n,o,a,b
print ""


print "DONE"
# Out:
# 30/0 pairs completed partA
# 30/0 pairs still running partA
# 1) ready to run (pairs_ready_to_run)
# 30
# dekker:h1_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T1_U54-H1ESC4DN-FA-DSG-MNase-R1-T1_S7_L007_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T1_U54-H1ESC4DN-FA-DSG-MNase-R1-T1_S7_L007_R2_001
# dekker:h1_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T1_U54-H1ESC4DN-FA-DSG-MNase-R1-T1_S22_L005_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T1_U54-H1ESC4DN-FA-DSG-MNase-R1-T1_S22_L005_R2_001
# dekker:h1_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T1_U54-H1ESC4DN-FA-DSG-MNase-R1-T1_S33_L008_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T1_U54-H1ESC4DN-FA-DSG-MNase-R1-T1_S33_L008_R2_001
# dekker:h1_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T2_U54-H1ESC4DN-FA-DSG-MNase-R1-T2_S8_L008_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T2_U54-H1ESC4DN-FA-DSG-MNase-R1-T2_S8_L008_R2_001
# dekker:h1_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T2_U54-H1ESC4DN-FA-DSG-MNase-R1-T2_S23_L006_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T2_U54-H1ESC4DN-FA-DSG-MNase-R1-T2_S23_L006_R2_001
# dekker:h1_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T2_U54-H1ESC4DN-FA-DSG-MNase-R1-T2_S34_L008_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T2_U54-H1ESC4DN-FA-DSG-MNase-R1-T2_S34_L008_R2_001
# dekker:h1_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T3_U54-H1ESC4DN-FA-DSG-MNase-R1-T3_S1_L001_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T3_U54-H1ESC4DN-FA-DSG-MNase-R1-T3_S1_L001_R2_001
# dekker:h1_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T3_U54-H1ESC4DN-FA-DSG-MNase-R1-T3_S24_L007_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T3_U54-H1ESC4DN-FA-DSG-MNase-R1-T3_S24_L007_R2_001
# dekker:h1_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T3_U54-H1ESC4DN-FA-DSG-MNase-R1-T3_S35_L008_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T3_U54-H1ESC4DN-FA-DSG-MNase-R1-T3_S35_L008_R2_001
# dekker:h1_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T4_U54-H1ESC4DN-FA-DSG-MNase-R1-T4_S6_L006_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T4_U54-H1ESC4DN-FA-DSG-MNase-R1-T4_S6_L006_R2_001
# dekker:h1_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T4_U54-H1ESC4DN-FA-DSG-MNase-R1-T4_S21_L004_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T4_U54-H1ESC4DN-FA-DSG-MNase-R1-T4_S21_L004_R2_001
# dekker:h1_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T4_U54-H1ESC4DN-FA-DSG-MNase-R1-T4_S32_L008_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-H1ESC4DN-FA-DSG-MNase-R1-T4_U54-H1ESC4DN-FA-DSG-MNase-R1-T4_S32_L008_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T1_U54-HFFc64DN-FA-DSG-MNase-R1-T1_S6_L006_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T1_U54-HFFc64DN-FA-DSG-MNase-R1-T1_S6_L006_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T1_U54-HFFc64DN-FA-DSG-MNase-R1-T1_S4_L004_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T1_U54-HFFc64DN-FA-DSG-MNase-R1-T1_S4_L004_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T1_U54-HFFc64DN-FA-DSG-MNase-R1-T1_S6_L002_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T1_U54-HFFc64DN-FA-DSG-MNase-R1-T1_S6_L002_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T2_U54-HFFc64DN-FA-DSG-MNase-R1-T2_S7_L007_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T2_U54-HFFc64DN-FA-DSG-MNase-R1-T2_S7_L007_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T2_U54-HFFc64DN-FA-DSG-MNase-R1-T2_S5_L005_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T2_U54-HFFc64DN-FA-DSG-MNase-R1-T2_S5_L005_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T2_U54-HFFc64DN-FA-DSG-MNase-R1-T2_S7_L002_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T2_U54-HFFc64DN-FA-DSG-MNase-R1-T2_S7_L002_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T3_U54-HFFc64DN-FA-DSG-MNase-R1-T3_S02_L002_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T3_U54-HFFc64DN-FA-DSG-MNase-R1-T3_S02_L002_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T3_U54-HFFc64DN-FA-DSG-MNase-R1-T3_S25_L008_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T3_U54-HFFc64DN-FA-DSG-MNase-R1-T3_S25_L008_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T3_U54-HFFc64DN-FA-DSG-MNase-R1-T3_S2_L002_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T3_U54-HFFc64DN-FA-DSG-MNase-R1-T3_S2_L002_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T4_U54-HFFc64DN-FA-DSG-MNase-R1-T4_S3_L003_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T4_U54-HFFc64DN-FA-DSG-MNase-R1-T4_S3_L003_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T4_U54-HFFc64DN-FA-DSG-MNase-R1-T4_S1_L001_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T4_U54-HFFc64DN-FA-DSG-MNase-R1-T4_S1_L001_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T4_U54-HFFc64DN-FA-DSG-MNase-R1-T4_S3_L002_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T4_U54-HFFc64DN-FA-DSG-MNase-R1-T4_S3_L002_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T5_U54-HFFc64DN-FA-DSG-MNase-R1-T5_S4_L004_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T5_U54-HFFc64DN-FA-DSG-MNase-R1-T5_S4_L004_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T5_U54-HFFc64DN-FA-DSG-MNase-R1-T5_S2_L002_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T5_U54-HFFc64DN-FA-DSG-MNase-R1-T5_S2_L002_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T5_U54-HFFc64DN-FA-DSG-MNase-R1-T5_S4_L002_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T5_U54-HFFc64DN-FA-DSG-MNase-R1-T5_S4_L002_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T6_U54-HFFc64DN-FA-DSG-MNase-R1-T6_S5_L005_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T6_U54-HFFc64DN-FA-DSG-MNase-R1-T6_S5_L005_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T6_U54-HFFc64DN-FA-DSG-MNase-R1-T6_S3_L003_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T6_U54-HFFc64DN-FA-DSG-MNase-R1-T6_S3_L003_R2_001
# dekker:hffc6_microc_repset [u'human'] dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T6_U54-HFFc64DN-FA-DSG-MNase-R1-T6_S5_L002_R1_001 dekker-lab:SeqencingFile_U54-Micro-C_U54-HFFc64DN-FA-DSG-MNase-R1-T6_U54-HFFc64DN-FA-DSG-MNase-R1-T6_S5_L002_R2_001
#
# 2) problematics ones (pairs_qcmd_problem)
#
# DONE

# %%
from core.utils import Tibanna
from core.utils import run_workflow
import time

paired_files = pairs_ready_to_run

env = 'fourfront-webprod'
tibanna = Tibanna(env=env)
outfiles = tibanna.s3.outfile_bucket
tibanna.s3.outfile_bucket = 'elasticbeanstalk-fourfront-webprod-files'
index_h = make_input_file_json('4DNFIZQZ39L9', 'bwa_index', tibanna)
index_m = make_input_file_json('4DNFI823LSI8', 'bwa_index', tibanna)

for set_name, organisms, f1,f2 in paired_files: 

    # find the correct index
    if organisms == ['human']:
        index = index_h
    elif organisms == ['mouse']:
        #index = index_m
        continue
    else:
        continue

    fastq1 = make_input_file_json(f1, 'fastq1', tibanna)
    fastq2 = make_input_file_json(f2, 'fastq2', tibanna)

    input_files = [fastq1, fastq2, index]
    if all(input_files):
        name = fastq1['object_key'].split('.')[0] + "-" + fastq2['object_key'].split('.')[0]
        input_json = make_hic1_json(input_files, env, outfiles, name)
        # print input_json
        res = run_workflow(input_json)
    else:
        print("some files not found on s3.  Investigate this list %s" % input_files)
    time.sleep(2)
    #a = raw_input("Press Enter to continue...")

print('Done')
# Out:
# looking for upload key 1f53df95-4cf3-41cc-971d-81bb16c486dd/4DNFIZQZ39L9.bwaIndex.tgz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 4a6d10ee-2edb-4402-a98f-0edb1d58f5e1/4DNFI823LSI8.bwaIndex.tgz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 9bf9729c-2ff3-4a3b-a33c-0528326fe65b/4DNFITHCIIBX.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 08aec878-b59a-4f26-b07a-819dd29e252f/4DNFID2ZCDGF.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFITHCIIBX-4DNFID2ZCDGF
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 24, 23, 648000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '42c42746-fbab-11e7-a82d-8186db427310', 'HTTPHeaders': {'x-amzn-requestid': '42c42746-fbab-11e7-a82d-8186db427310', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFITHCIIBX-4DNFID2ZCDGF'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFITHCIIBX-4DNFID2ZCDGF
# looking for upload key a7c2499e-da5c-41d2-acf8-f1df5540bab8/4DNFIYPZEW62.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key a93d94cd-ebcc-4db7-8efa-b5a69bc1a93b/4DNFIS85NTGH.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIYPZEW62-4DNFIS85NTGH
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 24, 29, 401000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '4630c4c5-fbab-11e7-a82d-8186db427310', 'HTTPHeaders': {'x-amzn-requestid': '4630c4c5-fbab-11e7-a82d-8186db427310', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIYPZEW62-4DNFIS85NTGH'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIYPZEW62-4DNFIS85NTGH
# looking for upload key 64081342-9423-46b6-b656-317d24209a00/4DNFIBCP22ZD.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key da85e3fc-fef4-4aa5-a2de-1eff0dd1e2da/4DNFI4JPLLJ2.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIBCP22ZD-4DNFI4JPLLJ2
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 24, 36, 746000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '4a93f7ad-fbab-11e7-8ff3-5522ef16ebae', 'HTTPHeaders': {'x-amzn-requestid': '4a93f7ad-fbab-11e7-8ff3-5522ef16ebae', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIBCP22ZD-4DNFI4JPLLJ2'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIBCP22ZD-4DNFI4JPLLJ2
# looking for upload key 093aa07b-4b8f-4a8f-9cb1-d38ff27a1847/4DNFIGLO7TEA.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 144e8067-4773-498a-bead-5d609feac324/4DNFITX2GCNC.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIGLO7TEA-4DNFITX2GCNC
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 24, 44, 959000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '4f73fbc1-fbab-11e7-ac30-ffad081ee10f', 'HTTPHeaders': {'x-amzn-requestid': '4f73fbc1-fbab-11e7-ac30-ffad081ee10f', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIGLO7TEA-4DNFITX2GCNC'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIGLO7TEA-4DNFITX2GCNC
# looking for upload key b3466060-7c0a-47ba-8d9c-8db82ec46117/4DNFI8CNEAQE.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 550a5b1b-aeae-4120-96dd-fc8c90b89709/4DNFIPWY7VVZ.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFI8CNEAQE-4DNFIPWY7VVZ
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 24, 53, 782000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '54bad891-fbab-11e7-8faf-1d982da0c84e', 'HTTPHeaders': {'x-amzn-requestid': '54bad891-fbab-11e7-8faf-1d982da0c84e', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFI8CNEAQE-4DNFIPWY7VVZ'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFI8CNEAQE-4DNFIPWY7VVZ
# looking for upload key 716553a8-8a4a-44b1-8b58-6002ba54b735/4DNFIGFCD6EA.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key fde3c8d3-cbe1-470f-a896-d9c670ea923b/4DNFI3COYVZO.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIGFCD6EA-4DNFI3COYVZO
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 25, 4, 328000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '5b025c18-fbab-11e7-815b-21d2a1a79bb4', 'HTTPHeaders': {'x-amzn-requestid': '5b025c18-fbab-11e7-815b-21d2a1a79bb4', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIGFCD6EA-4DNFI3COYVZO'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIGFCD6EA-4DNFI3COYVZO
# looking for upload key 0b0adc89-3220-4683-b849-3cfe6a93567d/4DNFIGSUOI4Z.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 20a4d5a8-16ea-4274-a3aa-432cdc0ce71a/4DNFID35MVU8.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIGSUOI4Z-4DNFID35MVU8
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 25, 14, 683000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '61308b52-fbab-11e7-b360-2522a25b1fde', 'HTTPHeaders': {'x-amzn-requestid': '61308b52-fbab-11e7-b360-2522a25b1fde', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIGSUOI4Z-4DNFID35MVU8'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIGSUOI4Z-4DNFID35MVU8
# looking for upload key 1a58a3ab-0cc9-445c-930b-040cbedac2d3/4DNFI8EZ9CRP.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 8a0d1ace-30fe-47e3-a4ce-6d59750e7ad4/4DNFIYNONVYR.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFI8EZ9CRP-4DNFIYNONVYR
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 25, 22, 951000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '661e2413-fbab-11e7-8cba-999e453cf0ea', 'HTTPHeaders': {'x-amzn-requestid': '661e2413-fbab-11e7-8cba-999e453cf0ea', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFI8EZ9CRP-4DNFIYNONVYR'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFI8EZ9CRP-4DNFIYNONVYR
# looking for upload key 84b4aa07-d088-4d7a-b14d-3ff9bea5d039/4DNFIUO8C231.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key c14f911b-0a0e-4c7b-b66c-63670af3da1e/4DNFI4J6LQYN.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIUO8C231-4DNFI4J6LQYN
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 25, 31, 969000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '6b7d90c7-fbab-11e7-b40b-1bdeecf79fe7', 'HTTPHeaders': {'x-amzn-requestid': '6b7d90c7-fbab-11e7-b40b-1bdeecf79fe7', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIUO8C231-4DNFI4J6LQYN'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIUO8C231-4DNFI4J6LQYN
# looking for upload key b62dd44f-3ef0-4f9b-a5b9-128db7bc133a/4DNFI9K4GV7L.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 20f5978a-3a89-496c-b865-e29c0c15e36a/4DNFIV6WM35F.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFI9K4GV7L-4DNFIV6WM35F
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 25, 40, 749000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '70b8ae15-fbab-11e7-9602-934e364ef62e', 'HTTPHeaders': {'x-amzn-requestid': '70b8ae15-fbab-11e7-9602-934e364ef62e', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFI9K4GV7L-4DNFIV6WM35F'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFI9K4GV7L-4DNFIV6WM35F
# looking for upload key bfa406f2-7273-4874-b5b9-ce503062bc60/4DNFI7GJ6O94.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 903ed07d-9b8b-4e97-871d-dced846a8fdb/4DNFIJTPDVEI.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFI7GJ6O94-4DNFIJTPDVEI
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 25, 52, 590000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '77c8638a-fbab-11e7-9602-934e364ef62e', 'HTTPHeaders': {'x-amzn-requestid': '77c8638a-fbab-11e7-9602-934e364ef62e', 'content-length': '147', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFI7GJ6O94-4DNFIJTPDVEI'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFI7GJ6O94-4DNFIJTPDVEI
# looking for upload key 423cdec9-09ff-4bc0-88fe-0f5730f22d1b/4DNFI2T8FS1E.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 61ed102e-9128-4260-aaf5-76f094e4fc7d/4DNFIFLLEUY1.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFI2T8FS1E-4DNFIFLLEUY1
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 26, 0, 931000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '7cc14611-fbab-11e7-a5c2-fb1c0f03cfe4', 'HTTPHeaders': {'x-amzn-requestid': '7cc14611-fbab-11e7-a5c2-fb1c0f03cfe4', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFI2T8FS1E-4DNFIFLLEUY1'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFI2T8FS1E-4DNFIFLLEUY1
# looking for upload key f4a77856-99e1-4a94-9b5e-ba44805aed13/4DNFIVHI87CC.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key fa990478-a426-4231-99c3-81a2927f488a/4DNFIKQJY7L2.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIVHI87CC-4DNFIKQJY7L2
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 26, 10, 316000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '825817b0-fbab-11e7-8774-1569444aa711', 'HTTPHeaders': {'x-amzn-requestid': '825817b0-fbab-11e7-8774-1569444aa711', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIVHI87CC-4DNFIKQJY7L2'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIVHI87CC-4DNFIKQJY7L2
# looking for upload key 5e9b41a4-baa6-4c99-8f1d-c5dc3caa1692/4DNFIAP8BN78.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 93c9ae5d-f386-409b-b0e8-b0d8b5ac8d4d/4DNFILEPLJNY.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIAP8BN78-4DNFILEPLJNY
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 26, 20, 301000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '884bae56-fbab-11e7-a8a7-775c629ccf45', 'HTTPHeaders': {'x-amzn-requestid': '884bae56-fbab-11e7-a8a7-775c629ccf45', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIAP8BN78-4DNFILEPLJNY'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIAP8BN78-4DNFILEPLJNY
# looking for upload key 5ce0a4f9-568d-43f3-a6c3-ab15e58767d0/4DNFIXXU98YU.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 0a216041-41e7-4c22-82ab-1befef46e90b/4DNFIINDPXJJ.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIXXU98YU-4DNFIINDPXJJ
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 26, 31, 317000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '8edd8113-fbab-11e7-a2bf-f1bfec03b036', 'HTTPHeaders': {'x-amzn-requestid': '8edd8113-fbab-11e7-a2bf-f1bfec03b036', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIXXU98YU-4DNFIINDPXJJ'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIXXU98YU-4DNFIINDPXJJ
# looking for upload key a779899e-c02f-4c0a-8e3c-58893a097b24/4DNFIXALIKQL.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 09f5c334-16d0-4775-b23c-69a292a6643e/4DNFIZVMNX8Y.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIXALIKQL-4DNFIZVMNX8Y
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 26, 41, 285000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '94cf4435-fbab-11e7-854e-6b76a7acfb41', 'HTTPHeaders': {'x-amzn-requestid': '94cf4435-fbab-11e7-854e-6b76a7acfb41', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIXALIKQL-4DNFIZVMNX8Y'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIXALIKQL-4DNFIZVMNX8Y
# looking for upload key 85ac26b2-a237-459f-b921-c530fc92e3e6/4DNFIZHLTFWN.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 099f0a82-314a-4546-89f8-c0d0a1856a6a/4DNFI6XT2LSJ.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIZHLTFWN-4DNFI6XT2LSJ
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 26, 50, 813000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '9a7c0d89-fbab-11e7-992e-3b39bcb66436', 'HTTPHeaders': {'x-amzn-requestid': '9a7c0d89-fbab-11e7-992e-3b39bcb66436', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIZHLTFWN-4DNFI6XT2LSJ'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIZHLTFWN-4DNFI6XT2LSJ
# looking for upload key b1483003-83f3-4087-a9e0-7525088becf4/4DNFIAQPZGR9.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key aff98f19-902d-41d6-9c9b-75ef99e67182/4DNFIDTB4DYO.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIAQPZGR9-4DNFIDTB4DYO
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 27, 3, 58000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'a1c745d4-fbab-11e7-ab03-d3355b7c65fd', 'HTTPHeaders': {'x-amzn-requestid': 'a1c745d4-fbab-11e7-ab03-d3355b7c65fd', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIAQPZGR9-4DNFIDTB4DYO'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIAQPZGR9-4DNFIDTB4DYO
# looking for upload key 84f81f50-16c8-48af-b7a5-c969675cd45a/4DNFIGWJ2J1L.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 1131e970-640a-464e-9d4a-c9d9f2fabe8a/4DNFICXSVGNT.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIGWJ2J1L-4DNFICXSVGNT
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 27, 10, 804000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'a6675afb-fbab-11e7-a5c0-a3fd79e845f5', 'HTTPHeaders': {'x-amzn-requestid': 'a6675afb-fbab-11e7-a5c0-a3fd79e845f5', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIGWJ2J1L-4DNFICXSVGNT'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIGWJ2J1L-4DNFICXSVGNT
# looking for upload key 91698a1c-1f0b-469c-b856-57853814b069/4DNFI1OXYULK.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 72367afc-426b-4e00-8ad0-7fe497c171bd/4DNFIECD3OLE.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFI1OXYULK-4DNFIECD3OLE
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 27, 20, 43000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'abe8ce8d-fbab-11e7-9ccd-2f241379d3dc', 'HTTPHeaders': {'x-amzn-requestid': 'abe8ce8d-fbab-11e7-9ccd-2f241379d3dc', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFI1OXYULK-4DNFIECD3OLE'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFI1OXYULK-4DNFIECD3OLE
# looking for upload key fca7e917-312f-4faf-8e7c-033d53f43fde/4DNFIG77YD16.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key a6e540d3-0ef0-40d3-80ec-320b9c8e651a/4DNFIFW1UDK9.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIG77YD16-4DNFIFW1UDK9
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 27, 30, 777000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'b24e13b5-fbab-11e7-be02-9f550f0d9269', 'HTTPHeaders': {'x-amzn-requestid': 'b24e13b5-fbab-11e7-be02-9f550f0d9269', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIG77YD16-4DNFIFW1UDK9'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIG77YD16-4DNFIFW1UDK9
# looking for upload key 91933432-b744-4c91-b890-155ec43461fd/4DNFIR2ZNDZY.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key ad870f62-f53e-49a7-b4e4-c3075a14bbeb/4DNFIF19ESZV.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIR2ZNDZY-4DNFIF19ESZV
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 27, 40, 510000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'b81b855c-fbab-11e7-b577-898d6e3b2fd3', 'HTTPHeaders': {'x-amzn-requestid': 'b81b855c-fbab-11e7-b577-898d6e3b2fd3', 'content-length': '147', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIR2ZNDZY-4DNFIF19ESZV'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIR2ZNDZY-4DNFIF19ESZV
# looking for upload key 0509b918-c704-4d06-847c-7a4ab68a24e1/4DNFIHLGKEWE.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 3af30ed0-30ed-4e82-bd57-dcae68e616e4/4DNFIJI5FBMA.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIHLGKEWE-4DNFIJI5FBMA
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 27, 50, 561000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'be18b95b-fbab-11e7-91ac-f1f39850011d', 'HTTPHeaders': {'x-amzn-requestid': 'be18b95b-fbab-11e7-91ac-f1f39850011d', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIHLGKEWE-4DNFIJI5FBMA'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIHLGKEWE-4DNFIJI5FBMA
# looking for upload key 6f39097b-579c-473d-9974-b1bc89228bf9/4DNFI4PTEG9X.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 6498cc4f-77a6-42e2-87a8-e0b244e29508/4DNFIVAZ44PT.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFI4PTEG9X-4DNFIVAZ44PT
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 28, 3, 310000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'c5b237f8-fbab-11e7-a82d-8186db427310', 'HTTPHeaders': {'x-amzn-requestid': 'c5b237f8-fbab-11e7-a82d-8186db427310', 'content-length': '147', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFI4PTEG9X-4DNFIVAZ44PT'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFI4PTEG9X-4DNFIVAZ44PT
# looking for upload key 8f6966cb-d99a-4d7e-af38-8f5dff3a2cd9/4DNFIQWDFUI7.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key cf38b991-50b1-488c-8b08-e7e98732db81/4DNFIVWCHMEG.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIQWDFUI7-4DNFIVWCHMEG
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 28, 13, 467000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'cbbf9867-fbab-11e7-9506-4fec2ef251b8', 'HTTPHeaders': {'x-amzn-requestid': 'cbbf9867-fbab-11e7-9506-4fec2ef251b8', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIQWDFUI7-4DNFIVWCHMEG'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIQWDFUI7-4DNFIVWCHMEG
# looking for upload key 6e30e84b-4f4f-40c8-9b8e-8bc86b12c370/4DNFIB2BJTO3.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 39919d6c-acaa-4611-962c-4a2ae2baa920/4DNFIJ9JKURX.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIB2BJTO3-4DNFIJ9JKURX
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 28, 23, 576000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'd1c70602-fbab-11e7-91ac-f1f39850011d', 'HTTPHeaders': {'x-amzn-requestid': 'd1c70602-fbab-11e7-91ac-f1f39850011d', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIB2BJTO3-4DNFIJ9JKURX'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIB2BJTO3-4DNFIJ9JKURX
# looking for upload key 3dabfa7f-700f-4dfc-998b-d9de4e8ac7f0/4DNFIGMXLQMY.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key a34868ac-a41b-4070-8c1a-3513331d6908/4DNFI25ACLC5.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIGMXLQMY-4DNFI25ACLC5
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 28, 34, 218000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'd81e4103-fbab-11e7-ae6f-15b07b63c40c', 'HTTPHeaders': {'x-amzn-requestid': 'd81e4103-fbab-11e7-ae6f-15b07b63c40c', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIGMXLQMY-4DNFI25ACLC5'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIGMXLQMY-4DNFI25ACLC5
# looking for upload key 7364cc51-c20c-4073-8270-dae2047d171f/4DNFIM13CH83.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 7a629467-ceb4-43fb-84ef-0da236fcff94/4DNFIDXR4P6N.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIM13CH83-4DNFIDXR4P6N
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 28, 45, 885000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'df12cc8a-fbab-11e7-a599-438f475cdefa', 'HTTPHeaders': {'x-amzn-requestid': 'df12cc8a-fbab-11e7-a599-438f475cdefa', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIM13CH83-4DNFIDXR4P6N'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIM13CH83-4DNFIDXR4P6N
# looking for upload key 9569c13e-cdea-434d-a25e-791d116d5e1f/4DNFIMCOCQVH.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 869cc8a4-f967-4a88-b57a-6ec2d0fce2ae/4DNFIXFLLLY4.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIMCOCQVH-4DNFIXFLLLY4
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 28, 56, 835000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'e59843ca-fbab-11e7-91ac-f1f39850011d', 'HTTPHeaders': {'x-amzn-requestid': 'e59843ca-fbab-11e7-91ac-f1f39850011d', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIMCOCQVH-4DNFIXFLLLY4'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIMCOCQVH-4DNFIXFLLLY4
# looking for upload key 98e09559-d46d-43fe-ad31-7806c344174b/4DNFIB6XAMH2.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 0fd54096-e4f7-4e63-8051-2a4cc25d4f89/4DNFINLULR9B.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIB6XAMH2-4DNFINLULR9B
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 1, 17, 12, 29, 10, 773000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'ede81a1e-fbab-11e7-b26d-cb6eb901f7ad', 'HTTPHeaders': {'x-amzn-requestid': 'ede81a1e-fbab-11e7-b26d-cb6eb901f7ad', 'content-length': '148', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIB6XAMH2-4DNFINLULR9B'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_new_pony:bwa-mem_4DNFIB6XAMH2-4DNFINLULR9B
# Done
