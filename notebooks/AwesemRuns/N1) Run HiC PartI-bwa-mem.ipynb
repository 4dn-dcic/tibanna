# %%
from core.utils import Tibanna
from core import ff_utils

#format for input json in hic-partA
def make_input_file_json(obj_id, arg_name, tibanna):
    '''
    {
      "bucket_name": "%s",
      "object_key": "%s",
      "uuid" : "%s",
      "workflow_argument_name": "%s"
    }
    '''
    ff = ff_utils.fdn_connection(key=tibanna.ff_keys)
    metadata = ff_utils.get_metadata(obj_id, connection=ff)
    data = {}
    
    # just make sure the file is on s3, otherwise bail
    print("looking for upload key %s, on bucket %s" % 
          (metadata['upload_key'],
           tibanna.s3.outfile_bucket))
    if tibanna.s3.does_key_exist(metadata['upload_key']):
        data = {'bucket_name' : tibanna.s3.outfile_bucket,
                'object_key' : metadata['upload_key'].split('/')[1],
                'uuid' : metadata['uuid'],
                'workflow_argument_name': arg_name
                }
    return data
    

def make_hic1_json(input_files, env, output_bucket, accession):
    input_json = {'input_files': input_files,
                  'output_bucket': output_bucket,
                  'workflow_uuid': "3feedadc-50f9-4bb4-919b-09a8b731d0cc",
                  "app_name": "bwa-mem",
                  "parameters": {
                      "nThreads": 16
                      },
                  "config": {
                        "ebs_type": "io1",
                        "json_bucket": "4dn-aws-pipeline-run-json",
                        "ebs_iops": 500,
                        "shutdown_min": 30,
                        "s3_access_arn": "arn:aws:iam::643366669028:instance-profile/S3_access",
                        "ami_id": "ami-cfb14bb5",
                        "copy_to_s3": True,
                        "launch_instance": True,
                        "password": "dragonfly",
                        "log_bucket": "tibanna-output",
                        "script_url": "https://raw.githubusercontent.com/4dn-dcic/tibanna/master/awsf/",
                        "key_name": "4dn-encode"
                    },
                  "_tibanna": {"env": env, "run_type": "bwa-mem",
                               "run_id": accession},
                  "tag": "0.2.5"
                  }
    return input_json

# %%
from tasks import run_md5
from tasks import run_fastqc
from invoke import run
import time
from datetime import datetime

# for a given experiment set and some parameters like instrument
# print set of files and their partA hic workflow status
# if there are one that are running report the number of running cases
# if there are file pairs that don't have a corresponding part A, report them separately



exclude_miseq = True

wf_md5 = "md5"
wf_fastqc = "fastqc-0-11-4-1"
wf_partA = "bwa-mem 0.2.5"

env = 'fourfront-webprod'
tibanna = Tibanna(env=env)

run_md_qc = raw_input("Do you wanna run md5 and/or fastqc if missing? (md5/qc/all/none)")

# status for completion
# there are two flavors of complete signals, before it was output_file_transfer_finished, not it is complete.
# old completed wf runs have former one.
status_done = ['complete', 'output_file_transfer_finished']
status_good = ['uploaded', 'released', 'released to project']
ff = ff_utils.fdn_connection(key=tibanna.ff_keys)

################
##ADD TO WORKFLOW
# wfr_time = datetime.strptime(wfr_data['date_created'],'%Y-%m-%dT%H:%M:%S.%f+00:00')
# run_hours = int((datetime.now()-wfr_time).total_seconds()/3600)
################

def summarize_file(file_resp):
    qc = False
    file_id = file_resp['accession']
    sequencer = file_resp.get('instrument')
    relations = file_resp.get('related_files')
    status = file_resp.get('status')
    workflows = file_resp.get('workflow_run_inputs')
    first_alias = file_resp.get('aliases',[None])[0]
    pair_no = file_resp.get('paired_end')
    # get related file
    paired_file = ''
    for relation in relations:
        if relation['relationship_type'] == 'paired with':
            paired_file = relation['file']['accession']
    
    # is there a qc?
    if file_resp.get('quality_metric'):
        qc = True
        
    # Check workflows for qc fastqc workflow partA
    last_part_A = ''
    last_part_A_status = 'did_not_run'
    md5_status = 'did_not_run'
    fastqc_status = 'did_not_run'
    # Assumes workflow_runs come in time ordered list, and grabs the last ones for each wf run
    if workflows:
        for a_wfr in workflows:
            wfr_resp = ff_utils.get_metadata(a_wfr['uuid'], connection=ff)  
            wfr_name = wfr_resp['display_title']
            if wfr_name.startswith(wf_md5):
                md5_status = wfr_resp.get('run_status')     
            elif wfr_name.startswith(wf_fastqc):
                fastqc_status = wfr_resp.get('run_status')     
            elif wfr_name.startswith(wf_partA):
                last_part_A=wfr_resp['uuid']
                last_part_A_status = wfr_resp.get('run_status')  
                
    # Check for md5 and fastqc, and if not complete, run or report it. 
    # if exclude miseq is on, do this only if sequencer is not miseq
    if not exclude_miseq or sequencer != "Illumina MiSeq":
        # check if md5 step is completed properly
        
        if status not in status_good or md5_status not in status_done:
            # if not, shall we run it?
            if run_md_qc in ['md5', 'all']:
                print 'md5 running for', file_resp['accession']
                code_md5= "invoke run_md5 " + env + " " + file_resp['accession'] + " " + file_resp['uuid']
                run(code_md5)
                print ''
                time.sleep(10)
            # user does not want it to be run, so just report
            else:
                print 'md5 run missing for', file_resp['accession']
        # check fastqc if md5 is fine
        else:

            if not qc or fastqc_status not in status_done:
                # if not, shall we run it?
                if run_md_qc in ['qc', 'all']:
                    print 'fastqc running for', file_resp['accession']
                    code_qc= "invoke run_fastqc " + env + " " + file_resp['accession'] + " " + file_resp['uuid']
                    run(code_qc)
                    print ''    
                    time.sleep(10)
                # user does not want it to be run, so just report
                else:
                    print 'fastqc run missing for', file_resp['accession'], fastqc_status
                    print 
   
    # return a small report
    return {'file': file_id,
            'alias': first_alias,
            'sequencer': sequencer,
            'pair_no': pair_no,
            'paired_file': paired_file,
            'file_status': status,
            'qc': qc,
            'md5_status': md5_status,
            'fastqc_status': fastqc_status,
            'last_part_A': last_part_A,
            'last_part_A_status': last_part_A_status
           }


def get_file_list(my_rep_set):

    rep_resp = ff_utils.get_metadata(my_rep_set, connection=ff)['experiments_in_set']
    report = []
    enzymes = []
    organisms = []
    for exp in rep_resp:
        exp_resp = ff_utils.get_metadata(exp, connection=ff)

        if not organisms:
            biosample = ff_utils.get_metadata(exp_resp['biosample'], connection=ff, frame='embedded')      
            organisms = list(set([bs['individual']['organism']['display_title'] for bs in  biosample['biosource']]))
            print organisms

        exp_files = exp_resp['files']
        enzyme = exp_resp.get('digestion_enzyme')
        enzymes.append(enzyme)
        for fastq_file in exp_files:
            file_resp = ff_utils.get_metadata(fastq_file, connection=ff, frame='embedded')  
            #Some checks before running
            #check if status is deleted
            if file_resp['status'] == 'deleted':
                continue
            #if no uploaded file in the file item report and skip
            if not file_resp.get('filename'):
                print file_resp['accession'], "does not have a file"
                continue
            # check that file has a pair
            if not file_resp.get('related_files'):
                print file_resp['accession'], 'does not have a pair'
                continue
            # check if file is in s3
            head_info = tibanna.s3.does_key_exist(file_resp['upload_key'], tibanna.s3.raw_file_bucket)
            if not head_info:
                print file_resp['accession'], "does not have a file in S3"
                continue

            # skip pair no 2
            if file_resp.get('paired_end')=='2':
                continue 

            # if the file size is more than 42 GB do not run
            file_size = head_info['ContentLength']
            if file_size > 45097156608:
                print file_resp['aliases'], 'larger than 42GB, skipping, please use another script'
                continue
            filesize = round(head_info['ContentLength']/1073741824.0,1)

            file_info = summarize_file(file_resp)

            # check for miseq
            if exclude_miseq:
                if file_info['sequencer'] == 'Illumina MiSeq':
                    continue
            paired_file = file_info['paired_file']
            pair_file_resp = ff_utils.get_metadata(paired_file, connection=ff, frame='embedded')
            pair_file_info = summarize_file(pair_file_resp)
            print fastq_file,paired_file, filesize

            # check consistency of paired file info
            # status differences gives error but there are multiple statuses that indicate complete
            # TODO fix it
            pairs_inconsistent = ""
            check_items = [ i for i in file_info.keys() if i not in ['file', 'paired_file', 'pair_no', 'alias']]
            for check_item in check_items:
                try:
                    assert file_info[check_item] == pair_file_info[check_item]
                except AssertionError:
                    print check_item, "not the same between pair", fastq_file, 'and', paired_file
                    pairs_inconsistent += check_item + ', '
            wf_check = ''
            # check if md5 and qc are okay
            for info in [file_info, pair_file_info]:
                if (info['md5_status'] in status_done and info['file_status'] in status_good and
                    info['fastqc_status'] in status_done and info['qc'] == True):
                    wf_check += '+'
            rep = {"consistency": pairs_inconsistent,  
                   "file1": file_info['alias'],
                   "file2": pair_file_info['alias'],
                   "const_check": pairs_inconsistent,
                   "wf_check": wf_check, 
                   "partA_wf": file_info['last_part_A'], 
                   "partA_status": file_info['last_part_A_status']
                   }
            # status differences gives error but there are multiple statuses that indicate complete
            # TODO fix it
            report.append(rep)
            if rep.get('const_check'):
                print rep['const_check']
    
    return my_rep_set, organisms, report
# Out:
# Do you wanna run md5 and/or fastqc if missing? (md5/qc/all/none)

# %%
all_reports = []
set_url = '/search/?experiments_in_set.biosample.biosource.individual.organism.name=human&experiments_in_set.experiment_type=in%20situ%20Hi-C&experiments_in_set.experiment_type=dilution%20Hi-C&experiments_in_set.experiment_type=DNase%20Hi-C&experiments_in_set.experiment_type=micro-C&experiments_in_set.experiment_type=PLAC-seq&experiments_in_set.experiment_type=capture%20Hi-C&experiments_in_set.experiment_type=CHIA-pet&experiments_in_set.experiment_type=TrAC-loop&type=ExperimentSetReplicate'
run_sets = [i['uuid'] for i in ff_utils.get_metadata(set_url , connection=ff)['@graph']]

print len(run_sets)
c = 0
for a_set in run_sets:
    c += 1
    print c
    print a_set
    rep = get_file_list(a_set)
    if rep:
        all_reports.append(rep)
    print
print 'done'
# Out:
# 117
# 1
# f8da32f6-18fe-4f90-82f2-36dca70b409f
# [u'human']
# /files-fastq/4DNFIFF7K2ZC/ 4DNFIEPLTDNG 1.2
# /files-fastq/4DNFIWB5O95D/ 4DNFIJ95LUGK 24.6
# /files-fastq/4DNFIOOZOF4F/ 4DNFIJ4JO7H2 0.8
# /files-fastq/4DNFIB734M8W/ 4DNFIPG8BLCU 26.0
#
# 2
# 9b1063f5-c891-44a8-b44a-3b4879257366
# [u'human']
# /files-fastq/4DNFI3EIJZ1S/ 4DNFILPUZLAP 1.5
# /files-fastq/4DNFINYCUVKX/ 4DNFIHZQRKFQ 1.6
# /files-fastq/4DNFIT2Y15DJ/ 4DNFIR7H77KR 1.2
# /files-fastq/4DNFIQLDW5SE/ 4DNFIKVK3ZUG 1.3
# /files-fastq/4DNFI6UHAJ72/ 4DNFISYFW1FW 1.3
# /files-fastq/4DNFI7ITYF7V/ 4DNFIW1UQ1UH 1.3
# /files-fastq/4DNFI42SLX1J/ 4DNFIQAHKX9G 1.6
# /files-fastq/4DNFI2LUHMUT/ 4DNFIVEYCSDC 1.7
# /files-fastq/4DNFIZMI8RBZ/ 4DNFIZQYOVRZ 1.4
# /files-fastq/4DNFIL41JKUA/ 4DNFIZ1VGJXF 1.5
# /files-fastq/4DNFIVAE9EIS/ 4DNFIRRWCZN4 1.2
# /files-fastq/4DNFIM4VAKNZ/ 4DNFI4ZZ9UXN 1.2
# /files-fastq/4DNFI4RJFKSL/ 4DNFIYUZQRIJ 1.2
# /files-fastq/4DNFIYM5YJPF/ 4DNFIL5UXD8D 1.2
# /files-fastq/4DNFIAD6CA2N/ 4DNFIG78CNWP 1.2
# /files-fastq/4DNFIS32DRD4/ 4DNFIM6BAWWO 1.2
#
# 3
# c5db8085-92bd-4d06-a22c-7958e4a78e19
# [u'human']
# /files-fastq/4DNFIPH8CKTY/ 4DNFICQFPTFZ 1.2
# /files-fastq/4DNFI6Z6ZR9X/ 4DNFIV5H3RCO 1.1
# /files-fastq/4DNFIFNFPWA8/ 4DNFI4TZRR4Y 1.0
# /files-fastq/4DNFIQW39HC5/ 4DNFIEC2SIAM 1.0
# /files-fastq/4DNFIX2YU76H/ 4DNFI3AF2455 1.1
# /files-fastq/4DNFI53E3GJJ/ 4DNFITM3L7ZQ 1.1
# /files-fastq/4DNFID1E7NDD/ 4DNFITCJ4CB7 1.2
# /files-fastq/4DNFIVXSZD4Q/ 4DNFIKJUE8V9 1.2
# /files-fastq/4DNFI75SPZAN/ 4DNFI38DCAR2 0.9
# /files-fastq/4DNFIASBU8FG/ 4DNFIT2BW6NR 0.9
# /files-fastq/4DNFIPK17VRO/ 4DNFIDF8KKKH 1.0
# /files-fastq/4DNFIZ8WVUPQ/ 4DNFI1ZF86A3 1.0
# /files-fastq/4DNFIGU4WV7D/ 4DNFIOXRTFJM 0.7
# /files-fastq/4DNFIBL3JC41/ 4DNFIK5QD352 0.8
# /files-fastq/4DNFI3JG5GE9/ 4DNFI84Y6SH5 0.8
# /files-fastq/4DNFIP83XFRA/ 4DNFIFUKP1IJ 0.8
#
# 4
# a0738fc8-c1a4-4f3c-87ed-80cc0217c1a3
# [u'human']
# /files-fastq/4DNFISTNZMGV/ 4DNFIFADHPSI 0.8
# /files-fastq/4DNFIWVP3FYL/ 4DNFIWIWCZA2 35.6
# /files-fastq/4DNFI61TSIX2/ 4DNFIF5ZRDYC 0.8
# [u'ruan-lab:H1_CTCF_rep2_hiseq_fastq_R1'] larger than 42GB, skipping, please use another script
#
# 5
# 17e0a7a6-ded4-462c-bc1d-126116fcdb3b
# [u'human']
# /files-fastq/4DNFIX7EIFE4/ 4DNFIUGHHII9 9.6
# /files-fastq/4DNFIQ3NAXKR/ 4DNFISN61KYQ 9.6
#
# 6
# ffda916d-c6b2-49be-8b02-0819f0509cb3
# [u'human']
# /files-fastq/4DNFIA14UPF7/ 4DNFIGCCXMAI 11.8
# /files-fastq/4DNFIK8IC6WZ/ 4DNFI839XZ3K 12.7
#
# 7
# c7be118a-9983-4a84-a88f-213cb39b0f4d
# [u'human']
# /files-fastq/4DNFI49YARYL/ 4DNFIVZQY9UE 1.6
# [u'ruan-lab:GM12878_RNAPII_rep1_hiseq_fastq_R1'] larger than 42GB, skipping, please use another script
# /files-fastq/4DNFIC39YRWS/ 4DNFI8R49IG2 2.1
# [u'ruan-lab:GM12878_RNAPII_rep2_hiseq_fastq_R1'] larger than 42GB, skipping, please use another script
# /files-fastq/4DNFIEEWE1R4/ 4DNFIQ51QR18 3.3
# [u'ruan-lab:GM12878_RNAPII_rep3_hiseq_fastq_R1'] larger than 42GB, skipping, please use another script
#
# 8
# 069d5b42-b235-4bc0-a80d-fe9e6c6dc79a
# [u'human']
# /files-fastq/4DNFIZDLRC6P/ 4DNFICALV8AE 0.8
# /files-fastq/4DNFIDRUF8TL/ 4DNFI91YZTQN 12.1
# /files-fastq/4DNFIJB49KS9/ 4DNFI24DAINB 2.1
# /files-fastq/4DNFI78RZF3H/ 4DNFIURCFHTM 16.4
# /files-fastq/4DNFIMCMUAX2/ 4DNFIDVEP257 1.9
# /files-fastq/4DNFIYTC3RKF/ 4DNFISLCIDMU 34.1
#
# 9
# 5db537d2-1cf6-44c2-ae5d-6d724c9f43bc
# [u'human']
# /files-fastq/4DNFIG22ZQ7Y/ 4DNFIMM81AZ3 9.0
# /files-fastq/4DNFI855FM8W/ 4DNFIHIB8POP 12.1
#
# 10
# 2a9d5a2d-f469-43ef-8f71-2cca3c872156
# [u'human']
# /files-fastq/4DNFIAJ8W42C/ 4DNFIC7T2XVN 5.1
# /files-fastq/4DNFI6T66UWS/ 4DNFIR4FUFD6 4.3
# /files-fastq/4DNFII9GQGQL/ 4DNFILFFRAE4 4.8
# /files-fastq/4DNFIF7HZPDI/ 4DNFI5AGFC8H 5.1
#
# 11
# 208dc2d9-549c-4533-9f77-01e0f0490755
# [u'human']
# /files-fastq/4DNFIZL34QSV/ 4DNFIUNVLC8R 5.1
# /files-fastq/4DNFITX9AEOV/ 4DNFI43YJNTD 4.5
# /files-fastq/4DNFILH15KEA/ 4DNFIKQHMOOO 3.4
# /files-fastq/4DNFIEO89PNT/ 4DNFIOREEZ47 3.6
#
# 12
# 37ac19c8-3280-4026-91ba-e401b4ffa1e9
# [u'human']
# /files-fastq/4DNFIPB1CIOM/ 4DNFIW27YORO 5.0
# /files-fastq/4DNFIZFYYQGS/ 4DNFID4T1AB1 4.4
# /files-fastq/4DNFIQUB7P26/ 4DNFIDDI4RYR 2.6
# /files-fastq/4DNFIQZZ33YZ/ 4DNFIGYLL86E 2.8
#
# 13
# 3effa8a5-1156-4f1a-aa8a-e6d511c384c6
# [u'human']
# /files-fastq/4DNFIJ3SS1X6/ 4DNFINU3572Y 3.5
# last_part_A_status not the same between pair /files-fastq/4DNFIJ3SS1X6/ and 4DNFINU3572Y
# last_part_A not the same between pair /files-fastq/4DNFIJ3SS1X6/ and 4DNFINU3572Y
# last_part_A_status, last_part_A,
# /files-fastq/4DNFISUM635J/ 4DNFIWE1ZP5N 3.2
# last_part_A_status not the same between pair /files-fastq/4DNFISUM635J/ and 4DNFIWE1ZP5N
# last_part_A not the same between pair /files-fastq/4DNFISUM635J/ and 4DNFIWE1ZP5N
# last_part_A_status, last_part_A,
# /files-fastq/4DNFI2SKXYPC/ 4DNFID7X872X 3.1
# /files-fastq/4DNFI8GSUPY1/ 4DNFIW86MWF1 3.3
#
# 14
# 998573fb-384e-4792-a621-254d705d4ec9
# [u'human']
# /files-fastq/4DNFITHCIIBX/ 4DNFID2ZCDGF 10.8
# /files-fastq/4DNFIYPZEW62/ 4DNFIS85NTGH 10.0
# /files-fastq/4DNFIBCP22ZD/ 4DNFI4JPLLJ2 3.0
# /files-fastq/4DNFIGLO7TEA/ 4DNFITX2GCNC 10.4
# /files-fastq/4DNFI8CNEAQE/ 4DNFIPWY7VVZ 9.9
# /files-fastq/4DNFIGFCD6EA/ 4DNFI3COYVZO 2.3
# /files-fastq/4DNFIGSUOI4Z/ 4DNFID35MVU8 9.7
# /files-fastq/4DNFI8EZ9CRP/ 4DNFIYNONVYR 9.9
# /files-fastq/4DNFIUO8C231/ 4DNFI4J6LQYN 2.2
# /files-fastq/4DNFI9K4GV7L/ 4DNFIV6WM35F 10.9
# /files-fastq/4DNFI7GJ6O94/ 4DNFIJTPDVEI 10.2
# /files-fastq/4DNFI2T8FS1E/ 4DNFIFLLEUY1 2.6
#
# 15
# 51d9ac15-e55e-4f64-85e5-01998e349cf1
# [u'human']
# /files-fastq/4DNFIVHI87CC/ 4DNFIKQJY7L2 10.1
# /files-fastq/4DNFIAP8BN78/ 4DNFILEPLJNY 10.3
# /files-fastq/4DNFIXXU98YU/ 4DNFIINDPXJJ 1.9
# /files-fastq/4DNFIXALIKQL/ 4DNFIZVMNX8Y 10.1
# /files-fastq/4DNFIZHLTFWN/ 4DNFI6XT2LSJ 10.5
# /files-fastq/4DNFIAQPZGR9/ 4DNFIDTB4DYO 1.7
# /files-fastq/4DNFIGWJ2J1L/ 4DNFICXSVGNT 10.4
# /files-fastq/4DNFI1OXYULK/ 4DNFIECD3OLE 10.1
# /files-fastq/4DNFIG77YD16/ 4DNFIFW1UDK9 1.6
# /files-fastq/4DNFIR2ZNDZY/ 4DNFIF19ESZV 10.3
# /files-fastq/4DNFIHLGKEWE/ 4DNFIJI5FBMA 10.4
# /files-fastq/4DNFI4PTEG9X/ 4DNFIVAZ44PT 1.5
# /files-fastq/4DNFIQWDFUI7/ 4DNFIVWCHMEG 10.0
# /files-fastq/4DNFIB2BJTO3/ 4DNFIJ9JKURX 10.4
# /files-fastq/4DNFIGMXLQMY/ 4DNFI25ACLC5 1.7
# /files-fastq/4DNFIM13CH83/ 4DNFIDXR4P6N 9.9
# /files-fastq/4DNFIMCOCQVH/ 4DNFIXFLLLY4 10.3
# /files-fastq/4DNFIB6XAMH2/ 4DNFINLULR9B 1.9
#
# 16
# f5af7c20-211d-4fca-8cc1-d42c8d99a2d4
# [u'human']
# /files-fastq/4DNFIWDY2U4S/ 4DNFIS8I1Y5L 10.2
# /files-fastq/4DNFI65A88XH/ 4DNFIY67X18K 10.0
# /files-fastq/4DNFIONTKGCC/ 4DNFISXNGXNA 10.1
# /files-fastq/4DNFIAAJYJ1Y/ 4DNFICOIG8A1 10.3
# /files-fastq/4DNFINCPY93G/ 4DNFI6BFAKQI 10.3
# /files-fastq/4DNFIF5LBBWQ/ 4DNFI9S272R7 10.1
# /files-fastq/4DNFID9WXC6L/ 4DNFIWIGZ5EW 9.9
# /files-fastq/4DNFIPC1UAH2/ 4DNFIG2BLIPZ 10.4
# /files-fastq/4DNFIFXD526I/ 4DNFI77ORE8G 10.4
# /files-fastq/4DNFIPL4UKY5/ 4DNFI2EB5HBJ 10.6
# /files-fastq/4DNFIKHJTBXN/ 4DNFIYCHCAAV 10.4
# /files-fastq/4DNFI6BHUZA6/ 4DNFIDKRWIPN 10.5
# /files-fastq/4DNFIAYGJL8A/ 4DNFI7GUU391 10.1
# /files-fastq/4DNFIW2NPXX9/ 4DNFI65W1NWV 10.1
# /files-fastq/4DNFISVE7HB2/ 4DNFIBPSVSZ6 10.5
# /files-fastq/4DNFIQ4VTRCE/ 4DNFIX3X22EQ 10.2
# /files-fastq/4DNFIMXEJLHF/ 4DNFIFDD2YM2 10.0
# /files-fastq/4DNFIWZUG4AN/ 4DNFI65C492U 10.7
#
# 17
# d9d0127e-af74-4bc1-a1ef-3f5c91bf618b
# [u'human']
# /files-fastq/4DNFI6HRNY45/ 4DNFI7FOUE8B 6.2
# /files-fastq/4DNFI5PBE2HV/ 4DNFIIJ3F86A 10.1
# /files-fastq/4DNFIERUVHB7/ 4DNFIG9PFXT7 10.5
#
# 18
# cdb9f084-8298-4e38-836b-d312521d8961
# [u'human']
# /files-fastq/4DNFI16N1D9U/ 4DNFID5XUAWS 11.0
#
# 19
# 9929a4d2-6915-495c-895e-68733437a7b3
# [u'human']
# /files-fastq/4DNFILOQ8JYX/ 4DNFIXIZEDVB 10.4
#
# 20
# 2156ca45-9773-4bf6-922a-36f573f47136
# [u'human']
# /files-fastq/4DNFIJPXVT65/ 4DNFIDSAIYMR 10.3
# /files-fastq/4DNFI92AGJ5Z/ 4DNFI36LCDR9 10.6
#
# 21
# 783869b7-d4ac-4590-aedc-b91e7a6915cd
# [u'human']
# /files-fastq/4DNFIWYFMAXR/ 4DNFI96XT4FW 10.8
#
# 22
# fdd70fd4-467a-4b69-bf43-b03998980f8e
# [u'human']
# /files-fastq/4DNFIWI31XWR/ 4DNFIGYSLI8R 18.3
#
# 23
# 66681d95-b946-4477-8199-fdac7c58fb65
# [u'human']
# /files-fastq/4DNFIGPPRYTM/ 4DNFIDNQ21N9 10.6
#
# 24
# d5866e8f-178c-4dc1-8926-a7dc4bbaac25
# [u'human']
# /files-fastq/4DNFI8UG5MZQ/ 4DNFIAWB663C 10.6
# /files-fastq/4DNFITGYYECV/ 4DNFII8MHP2G 10.5
#
# 25
# 01c8292e-40c1-4277-b36a-9f77d785d9b5
# [u'human']
# /files-fastq/4DNFIES6RBTU/ 4DNFIMV6Y8AB 4.3
# /files-fastq/4DNFIHRVGNN5/ 4DNFIKRKNWCJ 5.5
# /files-fastq/4DNFI5M3TNBD/ 4DNFIP6LZBFY 8.5
# /files-fastq/4DNFI5QYQREE/ 4DNFI81I215O 8.5
# /files-fastq/4DNFI25DCHPP/ 4DNFI9JT48Q9 9.2
# /files-fastq/4DNFI57Y5KNY/ 4DNFIL1SW3KU 8.3
# /files-fastq/4DNFIMU4VRBO/ 4DNFI7TTQM4D 8.2
# /files-fastq/4DNFIGS4IWU9/ 4DNFINEB9NQA 8.6
#
# 26
# 6ba6a5df-dac5-4111-b5f0-299b6bee0f38
# [u'human']
# /files-fastq/4DNFIBCRYBPW/ 4DNFI8TIPK75 10.2
# /files-fastq/4DNFI1PAJKFC/ 4DNFIUXJJM67 10.0
# /files-fastq/4DNFI4F6KXR5/ 4DNFIY55W1HW 9.9
# /files-fastq/4DNFIVNDDEDZ/ 4DNFI29W6CX6 10.2
# /files-fastq/4DNFI7PO1Y9I/ 4DNFI7FTRUX4 10.1
# /files-fastq/4DNFIA7QPBK1/ 4DNFIFSML3KY 10.1
# /files-fastq/4DNFIHY3D1G7/ 4DNFI96OZWFF 10.0
# /files-fastq/4DNFINLRXHSC/ 4DNFIHNEAEMA 9.5
# /files-fastq/4DNFIJI2ZEWN/ 4DNFIMZ4MZCG 10.2
# /files-fastq/4DNFIO9OHYUV/ 4DNFIM62WI62 9.2
# /files-fastq/4DNFI3TE7QNY/ 4DNFIS28AISX 10.0
# /files-fastq/4DNFIN9HJDNO/ 4DNFIBZJ8W8V 10.1
# /files-fastq/4DNFI6LI5AMP/ 4DNFIEIHJLLV 10.2
# /files-fastq/4DNFIU8LC2OB/ 4DNFI4Z2Y6IR 10.2
# /files-fastq/4DNFITO994UM/ 4DNFIROGHFF7 10.2
# /files-fastq/4DNFIYC5ZZGF/ 4DNFI6LY81F9 10.2
# /files-fastq/4DNFIZWJPRWP/ 4DNFIQQ1T6EJ 10.1
# /files-fastq/4DNFIF3HEOMM/ 4DNFICIEIA1P 10.0
#
# 27
# e58e2141-9253-4c91-85c3-d67ce06db28f
# [u'human']
# /files-fastq/4DNFIR8PHK1N/ 4DNFIAGRT5V5 1.7
# /files-fastq/4DNFI4J23CH2/ 4DNFICAWNEZW 1.7
# /files-fastq/4DNFI6PNCV7R/ 4DNFI9NZGW4Y 1.7
# /files-fastq/4DNFI3DA7YJF/ 4DNFI2OXQHDH 1.7
# /files-fastq/4DNFIO9EQHVN/ 4DNFIY5JXHPZ 4.4
# /files-fastq/4DNFI9EKRB76/ 4DNFI8NNUJ8Q 7.1
# /files-fastq/4DNFIP3N39QW/ 4DNFIPZF824U 2.2
# /files-fastq/4DNFIZ9ALLMU/ 4DNFIUE942HE 2.2
# /files-fastq/4DNFIL7LDN94/ 4DNFISAZPH4J 2.1
# /files-fastq/4DNFI42JKYB6/ 4DNFIXZ8C2KZ 9.6
# /files-fastq/4DNFIVWU1JTG/ 4DNFINCVAP61 4.1
# /files-fastq/4DNFI9NLU8QD/ 4DNFIO9I1LG7 12.3
# /files-fastq/4DNFIJL1RZFO/ 4DNFIPEIYTOU 6.7
# /files-fastq/4DNFIUAFPG1V/ 4DNFIHEDVKR8 7.1
# /files-fastq/4DNFI6NMDRBU/ 4DNFISX8ZQUC 6.5
# /files-fastq/4DNFIU8SO6EO/ 4DNFI5IE42HO 10.1
# /files-fastq/4DNFIV1Y9LEH/ 4DNFID4RGP8C 8.8
#
# 28
# 10d1c941-87af-44d9-ac29-8bdcb15d4ca7
# [u'human']
# /files-fastq/4DNFI5VLWJVD/ 4DNFI9RZ5M46 6.4
# /files-fastq/4DNFISFTHGMO/ 4DNFIRHB1DY6 8.7
# /files-fastq/4DNFIFLPPFEF/ 4DNFIEOF23ON 7.3
# /files-fastq/4DNFIF682T66/ 4DNFIX3JHRA6 7.2
# /files-fastq/4DNFIBFNQAPD/ 4DNFI3B5A5F7 5.9
# /files-fastq/4DNFIPST6TJR/ 4DNFIBA9UA7A 8.1
# /files-fastq/4DNFIWTWWMFV/ 4DNFIDJTCT3M 6.9
# /files-fastq/4DNFIBW7YMZK/ 4DNFIJT9H12M 7.0
#
# 29
# feb71372-4798-465e-a0de-a30dfc88d10c
# [u'human']
# /files-fastq/4DNFI8SNQQAM/ 4DNFIN1VFFCD 7.4
#
# 30
# 03a396f5-7379-4f86-a26b-232b5e9c7853
# [u'human']
# /files-fastq/4DNFI1HOWHSO/ 4DNFIZRR9WL8 4.2
# /files-fastq/4DNFIY69KSY4/ 4DNFIQ5NI8TY 3.8
#
# 31
# d2f95ea3-1c24-4884-bd68-6d412e0d0eaf
# [u'human']
# /files-fastq/4DNFIVZN1PCS/ 4DNFIVGWCOIT 4.3
#
# 32
# 6093fe05-edf0-4697-80d8-c61c29ef5b7b
# [u'human']
# /files-fastq/4DNFIGI7514S/ 4DNFIQK4MFWL 3.6
# /files-fastq/4DNFIHCMAFAZ/ 4DNFIGNFCZ4F 4.1
#
# 33
# 65e81c71-1785-42ca-a28e-3da4c27f659c
# [u'human']
# /files-fastq/4DNFIB4AR4WI/ 4DNFIB5XCS7Y 4.2
# /files-fastq/4DNFIQDPZ4LA/ 4DNFI472SHD5 8.8
#
# 34
# 7ec0a86a-79dc-43c0-8e7f-9b10951c4abe
# [u'human']
# /files-fastq/4DNFI964ZQ61/ 4DNFIKBBUOEL 14.4
# /files-fastq/4DNFIXEX6BR4/ 4DNFIH5DESRX 7.4
#
# 35
# 233740be-ffbe-4acc-b6a4-24bbee96ca73
# [u'human']
# /files-fastq/4DNFI6W7Y783/ 4DNFIZH3ET82 3.8
# /files-fastq/4DNFIGTAI53P/ 4DNFIT5LAX8R 2.3
#
# 36
# 5f605a56-21f8-4c0b-8c29-ef68b31c3e19
# [u'human']
# /files-fastq/4DNFIZGJG2VU/ 4DNFITVNI13Q 8.4
# /files-fastq/4DNFIW7NRRN3/ 4DNFIEN6IM4S 4.3
#
# 37
# 06e24460-5585-4c7f-9b07-3dc67cd2ff07
# [u'human']
# /files-fastq/4DNFISSKZ1D2/ 4DNFICSF2QY4 8.0
# /files-fastq/4DNFINULGJNQ/ 4DNFI33DXSQI 15.2
#
# 38
# 5dbcb281-9491-40c2-82d7-dd003c2c61b9
# [u'human']
# /files-fastq/4DNFIXPNTARQ/ 4DNFICTGPEM7 14.2
# /files-fastq/4DNFIPSKHIBT/ 4DNFI6XU5SVD 12.1
#
# 39
# a6632fc2-18b9-4db6-b0d4-8801f43ef106
# [u'human']
# /files-fastq/4DNFI4K2V6OS/ 4DNFIY2SMLY8 6.7
# /files-fastq/4DNFIBR1IRNR/ 4DNFIHRDDPFW 7.1
#
# 40
# 32de0079-ec6f-472f-baf5-82af899f23c5
# [u'human']
# /files-fastq/4DNFIITWJZNS/ 4DNFI3R3MRL3 6.9
# /files-fastq/4DNFI4P58DU7/ 4DNFI4GAN2R7 7.4
#
# 41
# 06ee39a2-fe15-4f89-a2fc-c33fe0e5f5fc
# [u'human']
# /files-fastq/4DNFIZ81FJA7/ 4DNFI253EY3I 6.8
# /files-fastq/4DNFIA8HTWVW/ 4DNFI37UIVDH 8.7
#
# 42
# 9fff2c05-0f34-435f-b0a4-765bf8a1a5cd
# [u'human']
# /files-fastq/4DNFIFO44AC5/ 4DNFIJKZITNF 5.9
# /files-fastq/4DNFICCEL937/ 4DNFIRENAFZ3 15.4
# /files-fastq/4DNFIRGQF7UI/ 4DNFIX3SCQNJ 1.4
# /files-fastq/4DNFI4DWD88F/ 4DNFITL1BN7A 1.9
# /files-fastq/4DNFIJIQGH7H/ 4DNFIKECI2BJ 6.1
# /files-fastq/4DNFIUJN3WJC/ 4DNFIZDWZKW6 2.4
#
# 43
# 639074b1-82e5-4355-a49e-2cda2c82efb2
# [u'human']
# /files-fastq/4DNFIEPZAEQO/ 4DNFI54WUGTH 6.5
# /files-fastq/4DNFIEGXB7QA/ 4DNFI6PUKY6I 16.4
# /files-fastq/4DNFIYA3HU5U/ 4DNFI7DV24MK 1.5
# /files-fastq/4DNFI8LZYRSF/ 4DNFID8W9UWY 2.0
# /files-fastq/4DNFIOO5NXR3/ 4DNFI1EUN5KT 6.3
# /files-fastq/4DNFIA195SFA/ 4DNFI5IJB5CM 2.7
#
# 44
# 9eb40c13-cf85-487c-9819-71ef74a22dcc
# [u'human']
# /files-fastq/4DNFIBK2WFVX/ 4DNFIB1Y8SXF 4.7
# /files-fastq/4DNFI6J2WOO2/ 4DNFIMTPBZY9 13.5
# /files-fastq/4DNFIJRS2DH1/ 4DNFIFDGPA7E 1.3
# /files-fastq/4DNFIYCB455C/ 4DNFIAJK2TE4 1.9
# /files-fastq/4DNFI5VZW7FG/ 4DNFI74MOQ66 6.3
# /files-fastq/4DNFIK1LWQ54/ 4DNFICM3XC69 2.6
#
# 45
# 1f25a58f-08c7-45a3-b3a8-75fbadd92365
# [u'human']
# /files-fastq/4DNFIVVG4S4M/ 4DNFIT2FYCIH 6.0
# /files-fastq/4DNFI9GA8BEG/ 4DNFIQQPEXLR 15.2
# /files-fastq/4DNFI9IXPGDW/ 4DNFIN4PVSJC 1.4
# /files-fastq/4DNFIW8KZESC/ 4DNFIIOQP7WU 4.3
# /files-fastq/4DNFIIA9R7M1/ 4DNFIUOK7QEM 5.8
# /files-fastq/4DNFIDSEEOVH/ 4DNFIW85IYHX 2.7
#
# 46
# 188be50a-72a8-4729-a03a-882e86f7739a
# [u'human']
# /files-fastq/4DNFI5XQO76M/ 4DNFIWYETVQ4 6.2
# /files-fastq/4DNFICWAWEYH/ 4DNFIIQVPD73 17.9
# /files-fastq/4DNFID29B479/ 4DNFI43TD9CJ 1.7
# /files-fastq/4DNFIZ7G79A9/ 4DNFIR1XVLUL 2.2
# /files-fastq/4DNFILT5X7TK/ 4DNFIMOXQ9UR 6.3
# /files-fastq/4DNFID9QWUIS/ 4DNFICSBWWWW 2.7
#
# 47
# e6e2bd9e-d91d-4296-b227-e3829fa395d6
# [u'human']
# /files-fastq/4DNFIL98K6KB/ 4DNFIHHGTS7L 5.0
# /files-fastq/4DNFIRUPDEXP/ 4DNFIO6DJCXE 14.4
# /files-fastq/4DNFIDSCVHA4/ 4DNFIB86AJ28 1.3
# /files-fastq/4DNFI412W9LK/ 4DNFIXWYWMGE 1.9
# /files-fastq/4DNFIP9VWYIB/ 4DNFIYD2XMBA 6.1
# /files-fastq/4DNFIG36X2DU/ 4DNFIST7XI9H 2.6
#
# 48
# 989e35be-58c8-479d-bb4e-e0cb01705405
# [u'human']
# /files-fastq/4DNFI23CNILG/ 4DNFIL4QYF26 4.8
# /files-fastq/4DNFIZ44BASO/ 4DNFII751LK8 8.2
# /files-fastq/4DNFIO7DLI48/ 4DNFI3EG4N7P 2.4
# /files-fastq/4DNFI9Y415AI/ 4DNFIUY2AGQN 17.7
# /files-fastq/4DNFIPGE1PZW/ 4DNFI2QXK1GU 3.2
# /files-fastq/4DNFIMMJVF17/ 4DNFIOFRBNHL 6.9
# /files-fastq/4DNFIRU1WB4T/ 4DNFI7OK1DZQ 9.3
# /files-fastq/4DNFI4USEWYJ/ 4DNFI4FG9RWV 18.0
#
# 49
# bc7d1347-da41-40ef-ba4b-060523411773
# [u'human']
# /files-fastq/4DNFI9NU3ZU4/ 4DNFIFO9QQKB 2.0
# /files-fastq/4DNFIEY8DWEO/ 4DNFIP8UWJ53 7.8
# /files-fastq/4DNFIUY8JQ8M/ 4DNFIY37BX1P 9.2
# /files-fastq/4DNFIT9P1TDP/ 4DNFIR8778O4 2.2
# /files-fastq/4DNFI8W9YL4S/ 4DNFI9GXL2EU 13.9
# /files-fastq/4DNFIIUXITK2/ 4DNFIDK996IR 15.4
# /files-fastq/4DNFIB1JOP3F/ 4DNFICU9DO7Z 5.8
#
# 50
# e3813ca1-f333-4943-8d83-d05829acefb2
# [u'human']
# /files-fastq/4DNFIPPD9LQX/ 4DNFIPUTKQAJ 2.4
# /files-fastq/4DNFISJKVVGY/ 4DNFIVIHEKCE 15.8
# /files-fastq/4DNFIZ6VR977/ 4DNFIP1SKFKA 16.4
# /files-fastq/4DNFIUP2TXHR/ 4DNFIL6K13DV 1.4
# /files-fastq/4DNFICB72WBP/ 4DNFIVH37BAQ 8.5
# /files-fastq/4DNFIJRL8V7K/ 4DNFIGHF2VDE 9.7
#
# 51
# 33f64f97-c9d5-4dc1-84bc-396b3de8159c
# [u'human']
# /files-fastq/4DNFIDF9E6QO/ 4DNFIOOF7YZ4 0.1
# /files-fastq/4DNFIVERQ6IV/ 4DNFI1NEKAJ5 0.1
# /files-fastq/4DNFIKOYVAAZ/ 4DNFIVLQ9OJ4 0.1
# /files-fastq/4DNFI14JGP8Q/ 4DNFIAKG3O2J 0.1
#
# 52
# ceea99e0-e6b0-49b9-8587-46f9d1791d33
# [u'human']
# /files-fastq/4DNFIVFDMNR4/ 4DNFIZB5TJWR 0.1
# /files-fastq/4DNFI6FYLLTB/ 4DNFIOR7IT5H 0.1
# /files-fastq/4DNFIFZZ6MHH/ 4DNFISD4ZNOK 0.1
# /files-fastq/4DNFITZD56RM/ 4DNFI8MX2WD5 0.1
#
# 53
# 0f0ce890-011a-45cc-8d29-ed25d1a8fee5
# [u'human']
# /files-fastq/4DNFI3KPZ7MH/ 4DNFIANG77CU 0.0
# /files-fastq/4DNFIT639SVM/ 4DNFIB8E8FEN 0.0
# /files-fastq/4DNFIH7RPC2S/ 4DNFIZVLSUA1 0.0
# /files-fastq/4DNFIIA4PZKZ/ 4DNFIBB761R9 0.0
# /files-fastq/4DNFIIGHRORP/ 4DNFI8DGGTHL 0.0
# /files-fastq/4DNFIMENYUWT/ 4DNFIWEMW134 0.0
# /files-fastq/4DNFIFD3GXIT/ 4DNFIS7K8R9H 0.0
# /files-fastq/4DNFIQDQ2EFQ/ 4DNFIG35PQLW 0.0
#
# 54
# 13504d56-948b-4d02-8402-0ce603817e8a
# [u'human']
# /files-fastq/4DNFI4EQOI9P/ 4DNFIP1VRILA 0.1
# /files-fastq/4DNFIY9OFIVZ/ 4DNFINPHB33C 0.1
# /files-fastq/4DNFIF6EJTQM/ 4DNFIXCREB47 0.1
# /files-fastq/4DNFIG6M7WDO/ 4DNFI5XGY8NJ 0.1
#
# 55
# bd73b8c3-29ad-4dd4-aa05-4fc201d5b7bc
# [u'human']
# /files-fastq/4DNFIVK9NAPQ/ 4DNFIBFXT698 0.2
# /files-fastq/4DNFIAFS54AF/ 4DNFIYAGGZCB 0.2
# /files-fastq/4DNFIBZ38EWL/ 4DNFIZ5A8Q6P 0.2
# /files-fastq/4DNFI5ZLPONR/ 4DNFIS745CTW 0.2
# /files-fastq/4DNFIA468WZA/ 4DNFINQ8FPK1 0.2
# /files-fastq/4DNFIHWS7WJT/ 4DNFIYV9G6XL 0.2
# /files-fastq/4DNFIECF73RU/ 4DNFIM979TMM 0.2
# /files-fastq/4DNFI4794X2M/ 4DNFIOHG1PT1 0.2
#
# 56
# 9b97c001-5a38-48ca-8e20-8a2dfe073b53
# [u'human']
# /files-fastq/4DNFIUJQD4KY/ 4DNFIEH4T6MU 0.0
# /files-fastq/4DNFIG3F4WTK/ 4DNFIA3AKOC5 0.0
# /files-fastq/4DNFIT2ADOV9/ 4DNFI4LSMEHL 0.0
# /files-fastq/4DNFI7RR5RO2/ 4DNFIDJ4HPUU 0.0
#
# 57
# a0b4c3a6-fb4c-41ae-8ca2-d035f09e4b46
# [u'human']
# /files-fastq/4DNFIKQ2WKBZ/ 4DNFIEF63HY4 0.0
# /files-fastq/4DNFIZKWF9NW/ 4DNFIK8LPUSR 0.0
# /files-fastq/4DNFIFDXP9MM/ 4DNFI6ATF1SC 0.0
# /files-fastq/4DNFIQ2F7IPM/ 4DNFIWTTQ34S 0.0
#
# 58
# 1e5f0646-e569-45e0-9560-bd5c39a68859
# [u'human']
# /files-fastq/4DNFIBVEWU6D/ 4DNFIH6TEYTI 0.0
# /files-fastq/4DNFIY9D6LOK/ 4DNFIZCDQ8H9 0.0
# /files-fastq/4DNFI3UFYOWR/ 4DNFIJRG7G2X 0.0
# /files-fastq/4DNFI7YMVCGF/ 4DNFIPP825HG 0.0
#
# 59
# d99fcef2-8167-417f-a4e4-a0e757b30942
# [u'human']
# /files-fastq/4DNFICTA2EY8/ 4DNFI5SZXCB7 0.0
# /files-fastq/4DNFINDN9LFE/ 4DNFILFI89TD 0.0
# /files-fastq/4DNFIZ5HEG3B/ 4DNFIT1TO2CF 0.0
# /files-fastq/4DNFIDGAVP7C/ 4DNFIDME1O8H 0.0
# /files-fastq/4DNFIQ91Z4YK/ 4DNFI5R8NHIN 0.0
# /files-fastq/4DNFICB1JI1T/ 4DNFILKNKH8S 0.0
# /files-fastq/4DNFIOOS6EDC/ 4DNFIGAA2XRC 0.0
# /files-fastq/4DNFIR8ARGX9/ 4DNFIKEHEQLM 0.0
#
# 60
# 44623ac0-2a83-4bd5-8071-352680a7c2c2
# [u'human']
# /files-fastq/4DNFIQO1TVE9/ 4DNFIFQXBU9G 0.0
# /files-fastq/4DNFIVC6AWC3/ 4DNFIBGCTVWC 0.0
# /files-fastq/4DNFISS5UFNS/ 4DNFI2HWQEIB 0.0
# /files-fastq/4DNFIWLT7KPR/ 4DNFI66BY2XE 0.0
# /files-fastq/4DNFIPTFBE9F/ 4DNFI3G1N5FL 0.0
# /files-fastq/4DNFIAR9EUXU/ 4DNFINGZD8JQ 0.0
# /files-fastq/4DNFISVPQAJF/ 4DNFIGUI66KL 0.0
# /files-fastq/4DNFIOWA3IQH/ 4DNFIJ2U728R 0.0
#
# 61
# 56f7ad57-e70d-48a3-a2f8-4b42d1cf0280
# [u'human']
# /files-fastq/4DNFIBR6GI5Q/ 4DNFIFG2VLFU 0.0
# /files-fastq/4DNFIFV2I181/ 4DNFIDVNQ5JI 0.0
# /files-fastq/4DNFI5XLT3D7/ 4DNFIN1K3B8U 0.0
# /files-fastq/4DNFI7V93GZP/ 4DNFIJCM8QGS 0.0
# /files-fastq/4DNFI5Y8AEBD/ 4DNFIS8DBGBX 0.0
# /files-fastq/4DNFID72MLCA/ 4DNFIQC9Y1QC 0.0
# /files-fastq/4DNFI64QXWYX/ 4DNFIZ988CQG 0.0
# /files-fastq/4DNFI47FHPKU/ 4DNFIXVVM7NI 0.0
#
# 62
# 36fa883d-c984-4cdc-8646-35554bfab60b
# [u'human']
# /files-fastq/4DNFI4F7HY6V/ 4DNFISY3ZUN2 0.1
# /files-fastq/4DNFIMOCJ377/ 4DNFI2SWBGSE 0.1
# /files-fastq/4DNFIVOZN511/ 4DNFIRSRJH45 0.1
# /files-fastq/4DNFIYCOL4VG/ 4DNFIWF658RG 0.1
# /files-fastq/4DNFIHO56SV2/ 4DNFIRD5N1H2 0.1
# /files-fastq/4DNFIY8NSXII/ 4DNFIUK4W89K 0.1
# /files-fastq/4DNFI5GIQCUJ/ 4DNFI8VALPKZ 0.1
# /files-fastq/4DNFIP4P47LD/ 4DNFII2N6Z3W 0.1
# /files-fastq/4DNFIBX1H53B/ 4DNFICYFYKKM 0.1
# /files-fastq/4DNFINVSBKD2/ 4DNFIJ5I8LJP 0.1
# /files-fastq/4DNFIZM33G4O/ 4DNFI3NIGM8V 0.1
# /files-fastq/4DNFIP6L72P4/ 4DNFIJNL826W 0.1
#
# 63
# f46bd57d-075d-4663-aa7a-91f16d896cd0
# [u'human']
# /files-fastq/4DNFIHU7WJTZ/ 4DNFI7J7LIMM 0.2
# /files-fastq/4DNFIP2OH6Y3/ 4DNFI9MZ9IEA 0.1
# /files-fastq/4DNFI1WJD786/ 4DNFIGX57TZO 0.2
# /files-fastq/4DNFIEWOOZKX/ 4DNFIQ594TDS 0.1
# /files-fastq/4DNFIU718OMD/ 4DNFIOO3D2GW 0.2
# /files-fastq/4DNFISMLGIJ6/ 4DNFIGD6D88X 0.2
# /files-fastq/4DNFIHO51D19/ 4DNFIDYFKT16 0.2
# /files-fastq/4DNFI9L6XI9S/ 4DNFI261LTTO 0.2
#
# 64
# 67f65a1c-f8bb-4ea0-abfe-2d9f6ab0a0e5
# [u'human']
# /files-fastq/4DNFIYVE1QEH/ 4DNFIOXMKDNM 0.1
# /files-fastq/4DNFIL8IPFWZ/ 4DNFIQKQEI14 0.1
# /files-fastq/4DNFIKKN68XO/ 4DNFIMJQCLMC 0.1
# /files-fastq/4DNFI7W553WD/ 4DNFIA4BCSZ5 0.1
# /files-fastq/4DNFIENM5OEF/ 4DNFIB6UF5EG 0.1
# /files-fastq/4DNFILXT5KNF/ 4DNFICRXLNQU 0.1
# /files-fastq/4DNFIBIHAFPG/ 4DNFIR2LN832 0.1
# /files-fastq/4DNFIVF6I36X/ 4DNFI32EQQ3C 0.1
#
# 65
# 69732837-1eba-4882-9ea8-8931ad97aae9
# [u'human']
# /files-fastq/4DNFIC6ILINT/ 4DNFIQBJ42XR 0.1
# /files-fastq/4DNFI2A52WDD/ 4DNFIHLCY6KO 0.1
# /files-fastq/4DNFIJOHOA8S/ 4DNFI85TY8KW 0.1
# /files-fastq/4DNFISDAR7ZW/ 4DNFID56ROEH 0.1
# /files-fastq/4DNFI9V3C3CR/ 4DNFIPNECSNL 0.0
# /files-fastq/4DNFITMJ4WAH/ 4DNFIUHMS465 0.0
# /files-fastq/4DNFIMLTH8SX/ 4DNFIADU16Y7 0.0
# /files-fastq/4DNFITGY7JTR/ 4DNFI3ZR86VQ 0.0
#
# 66
# 72533bb7-23fd-43e4-9ee8-14d8375c7f14
# [u'human']
# /files-fastq/4DNFI1PNX9UU/ 4DNFIBTK2UV1 0.1
# /files-fastq/4DNFITYOTEDR/ 4DNFIC18IYWI 0.1
# /files-fastq/4DNFIS8G6FGS/ 4DNFI9Z5PWNV 0.1
# /files-fastq/4DNFIT3IBYI4/ 4DNFIYBD5XSR 0.1
#
# 67
# 83d02b50-a2c0-4256-8839-c694433c371f
# [u'human']
# /files-fastq/4DNFI6SMT29C/ 4DNFIQFQ4M9G 1.3
# /files-fastq/4DNFIJVL4EDR/ 4DNFIQMXJRKV 1.3
#
# 68
# 46572b13-ac2d-45de-9e11-a50236f975dd
# [u'human']
# /files-fastq/4DNFITYRLYTG/ 4DNFI5J8F7AT 0.6
# /files-fastq/4DNFIXP926SF/ 4DNFI2VXKAOI 0.6
#
# 69
# 2e65abef-7451-405a-9586-eb8feb20ca04
# [u'human']
# /files-fastq/4DNFIS2NX4LB/ 4DNFINO5I5K4 0.4
# /files-fastq/4DNFIDUYJ1ZK/ 4DNFI6T8LFON 0.4
# /files-fastq/4DNFICZA5BTH/ 4DNFIMEQ3UF6 0.0
# /files-fastq/4DNFI41H812Z/ 4DNFIFYUFDA3 0.0
# /files-fastq/4DNFIGKPXVN2/ 4DNFIKBZNB8K 0.0
# /files-fastq/4DNFIL3NEI27/ 4DNFICQ24KYE 0.0
#
# 70
# b35995d5-dbf5-497f-8e53-6581e6ecccf4
# [u'human']
# /files-fastq/4DNFIO9KIUNR/ 4DNFIHFMKZDC 0.2
# /files-fastq/4DNFIWNBNGB6/ 4DNFIUV1PA6G 0.2
# /files-fastq/4DNFIEQ8V1DY/ 4DNFIF51ZLCI 0.2
# /files-fastq/4DNFIV7RDJON/ 4DNFIJLD2IPZ 0.2
# /files-fastq/4DNFI6X9LTZM/ 4DNFI579L2VR 0.2
# /files-fastq/4DNFI22A6PLP/ 4DNFIYWMF6KO 0.2
# /files-fastq/4DNFINYTUCFI/ 4DNFI4BUO674 0.2
# /files-fastq/4DNFIL1HYD8D/ 4DNFI6GTIA46 0.2
# /files-fastq/4DNFIN4EIE5L/ 4DNFIEZXPGFO 0.2
# /files-fastq/4DNFI1X7ZCTV/ 4DNFIX3E4M3U 0.2
# /files-fastq/4DNFIOCG96A5/ 4DNFIB9PIJCB 0.2
# /files-fastq/4DNFI9GQ3ANV/ 4DNFIYDMJGZB 0.2
# /files-fastq/4DNFIWR7F9HT/ 4DNFITNWGQOJ 0.2
# /files-fastq/4DNFIVNXZYSU/ 4DNFICN8ZS3G 0.2
# /files-fastq/4DNFIJFV894L/ 4DNFI9UMXSE6 0.2
# /files-fastq/4DNFIK96H3DL/ 4DNFI4C2BVQG 0.2
#
# 71
# 0aee0c6f-fbd5-4d62-96c8-11a5cdc1816e
# [u'human']
# /files-fastq/4DNFIMFB3UGI/ 4DNFI8LV54QP 0.2
# /files-fastq/4DNFI6A63S7Q/ 4DNFIYKF6JSX 0.2
# /files-fastq/4DNFIK8F8SWK/ 4DNFIGTYJSYZ 0.2
# /files-fastq/4DNFI58CVW1Y/ 4DNFICBNBSUJ 0.2
# /files-fastq/4DNFIWE2RTF8/ 4DNFILQBWW25 0.1
# /files-fastq/4DNFIFVQVFRH/ 4DNFIBYEQLFL 0.1
# /files-fastq/4DNFIAZD4BHP/ 4DNFIDQCFW5A 0.1
# /files-fastq/4DNFITXM5URP/ 4DNFIE5VMNC2 0.1
# /files-fastq/4DNFINPFR88E/ 4DNFIQ21J9QZ 0.1
# /files-fastq/4DNFIMF6MBH8/ 4DNFI9PW1HM4 0.1
# /files-fastq/4DNFIDSSTGB7/ 4DNFI314G2KJ 0.1
# /files-fastq/4DNFI7Y7JX5H/ 4DNFIVCXW2HJ 0.1
# /files-fastq/4DNFINDM4JO4/ 4DNFIKVF3JCR 0.1
# /files-fastq/4DNFIFZP7DWL/ 4DNFI4I2E81B 0.1
# /files-fastq/4DNFI5ATSFFP/ 4DNFIPGRS3ND 0.1
# /files-fastq/4DNFIV2ZN48X/ 4DNFIWWXL7YT 0.1
#
# 72
# 2e031174-c022-4aa7-ad63-9d072f433b50
# [u'human']
# /files-fastq/4DNFIUBRCYNX/ 4DNFIQ8WRD5H 0.0
# /files-fastq/4DNFI3ERDB8D/ 4DNFIWQKYTWJ 0.0
# /files-fastq/4DNFIEDG14YX/ 4DNFICTJHR16 0.0
# /files-fastq/4DNFILLD9J46/ 4DNFI3LOD85Z 0.0
#
# 73
# a7197d64-2a04-48d5-8ad3-269496888dce
# [u'human']
# /files-fastq/4DNFI3AECXBN/ 4DNFIBBD59Z8 0.0
# /files-fastq/4DNFI2LMMHV3/ 4DNFI67S4RXM 0.0
# /files-fastq/4DNFIPLCC2V8/ 4DNFI1QP5RQ4 0.0
# /files-fastq/4DNFIIMI56PZ/ 4DNFI4FQRMOE 0.0
# /files-fastq/4DNFIE15Y6ZE/ 4DNFI27L7KYS 0.0
# /files-fastq/4DNFIOZCEBTV/ 4DNFIZHWKAZH 0.0
# /files-fastq/4DNFI8KDSQH2/ 4DNFIKP52F18 0.0
# /files-fastq/4DNFIIE83BP5/ 4DNFIOINDI7L 0.0
# /files-fastq/4DNFICZFJE4X/ 4DNFIKZUVWKB 0.0
# /files-fastq/4DNFIEEV9PLN/ 4DNFIVD1CUE2 0.0
# /files-fastq/4DNFI5XEIYP3/ 4DNFI1ET8J3M 0.0
# /files-fastq/4DNFIDZSCI4F/ 4DNFI41BYCYA 0.0
# /files-fastq/4DNFII7ML7LO/ 4DNFIJOQUPIC 0.0
# /files-fastq/4DNFIPKG5AU3/ 4DNFINSLA29J 0.0
# /files-fastq/4DNFIZAIE1P2/ 4DNFIU8C1LG3 0.0
# /files-fastq/4DNFIQL5B2A7/ 4DNFIOTU4BKU 0.0
# /files-fastq/4DNFI991U2D8/ 4DNFI7LN42PB 0.0
# /files-fastq/4DNFILK6N9Z8/ 4DNFINBDODV8 0.0
# /files-fastq/4DNFI5WFZER4/ 4DNFI9VT1Z9G 0.0
# /files-fastq/4DNFIEOX5BID/ 4DNFIYAUGCHE 0.0
#
# 74
# f407a727-98c9-4cbf-8d47-666bf6fcf215
# [u'human']
# /files-fastq/4DNFIC7YZHEV/ 4DNFIV36B4PT 0.1
# /files-fastq/4DNFIKB7MZ71/ 4DNFI7IVNG93 0.1
# /files-fastq/4DNFIUKL7R12/ 4DNFI466G2WW 0.1
# /files-fastq/4DNFINIU5978/ 4DNFIUE7AKQJ 0.1
#
# 75
# a5a7ddd3-7c3d-431f-9a38-2941ff48ca4b
# [u'human']
# /files-fastq/4DNFIFKFRQKO/ 4DNFI5CMW6J5 0.0
# /files-fastq/4DNFIEHFRPPT/ 4DNFIXSCNGQL 0.0
# /files-fastq/4DNFIBASDHZW/ 4DNFIRB2AEGS 0.0
# /files-fastq/4DNFIOIHFBFI/ 4DNFIZLM4MSI 0.0
# /files-fastq/4DNFI1MD1JDI/ 4DNFIHQPC46T 0.0
# /files-fastq/4DNFI5AW7A5L/ 4DNFIWCBCY1Y 0.0
# /files-fastq/4DNFI5OLWIRQ/ 4DNFIO7BWWFT 0.0
# /files-fastq/4DNFI1SAYS2T/ 4DNFI5C1WHUA 0.0
# /files-fastq/4DNFILVPXCJC/ 4DNFIFXXAJKH 0.0
# /files-fastq/4DNFI1FN5IO8/ 4DNFI7BL2RQP 0.0
# /files-fastq/4DNFIFFTT989/ 4DNFIZ93MONR 0.1
# /files-fastq/4DNFIP2EALXV/ 4DNFINOTCOVG 0.1
# /files-fastq/4DNFIL4OMK17/ 4DNFINK1V14Q 0.1
# /files-fastq/4DNFI7KEMSBO/ 4DNFIKQAM8S7 0.1
# /files-fastq/4DNFI6FBG681/ 4DNFIHSLGZJ7 0.0
# /files-fastq/4DNFIDN84WPS/ 4DNFIJ9NPAKK 0.0
# /files-fastq/4DNFIKNJHM3U/ 4DNFI72H6X6M 0.0
# /files-fastq/4DNFI3W15K5N/ 4DNFIVL4EB3K 0.0
#
# 76
# b5fb91fd-34cc-43d1-9e93-fc317d53c5a1
# [u'human']
# /files-fastq/4DNFIXWHQFO9/ 4DNFISBLR2R6 0.0
# /files-fastq/4DNFICRE72JW/ 4DNFI4LKCDPE 0.0
# /files-fastq/4DNFIB36TK7A/ 4DNFI24SHTVF 0.0
# /files-fastq/4DNFIXDTM8KT/ 4DNFIZIGUH1X 0.0
# /files-fastq/4DNFI6K9U643/ 4DNFIYD3NXOA 0.0
# /files-fastq/4DNFIT1XED2D/ 4DNFIPS5DFSZ 0.0
# /files-fastq/4DNFIWHUQG6J/ 4DNFIN36BI6I 0.0
# /files-fastq/4DNFI2PIUC8H/ 4DNFIGTKGPHX 0.0
# /files-fastq/4DNFITKLCQS8/ 4DNFI14URKNA 0.0
# /files-fastq/4DNFI6RJTP9D/ 4DNFISS35OSV 0.0
# /files-fastq/4DNFIX1J1O73/ 4DNFIQT9TW71 0.0
# /files-fastq/4DNFIEXLKK9P/ 4DNFIY8I8OMW 0.0
# /files-fastq/4DNFIJHWYQRH/ 4DNFI8EDE4QE 0.0
# /files-fastq/4DNFI1L2YYU5/ 4DNFIVQF2X77 0.0
# /files-fastq/4DNFIEOIJNP8/ 4DNFILU2W38H 0.0
# /files-fastq/4DNFI46QP8AT/ 4DNFIOPO5R29 0.0
# /files-fastq/4DNFI5UDXHZX/ 4DNFIDJ4LIEC 0.0
# /files-fastq/4DNFISQT7FNY/ 4DNFIR2VWCEO 0.0
# /files-fastq/4DNFI3NY3VBR/ 4DNFIW83E59D 0.0
# /files-fastq/4DNFI6E8PEFS/ 4DNFI7H48YZN 0.0
#
# 77
# 1324d727-2ac8-4622-8ad3-b6e209235087
# [u'human']
# /files-fastq/4DNFIQSRICLP/ 4DNFIW2ERNRL 0.2
# /files-fastq/4DNFIKBLE5QQ/ 4DNFI9PH3JHT 0.2
# /files-fastq/4DNFI5UD9337/ 4DNFILZ2UWNY 0.2
# /files-fastq/4DNFI91K4LFL/ 4DNFIX78YTAA 0.2
# /files-fastq/4DNFIW1LFM42/ 4DNFIXLQP54C 0.1
# /files-fastq/4DNFIOZY6GZ4/ 4DNFIRTFUJJE 0.1
# /files-fastq/4DNFI15IQYCE/ 4DNFISF9ORQW 0.1
# /files-fastq/4DNFI4LI95P7/ 4DNFIV1VNAUX 0.1
# /files-fastq/4DNFIS69C5SX/ 4DNFI5KNTRJJ 0.2
# /files-fastq/4DNFIZKNQNPM/ 4DNFIX4LYZNZ 0.2
# /files-fastq/4DNFIGMSWSOC/ 4DNFI32WG8XI 0.2
# /files-fastq/4DNFIMDT59U5/ 4DNFI38FYYN7 0.2
# /files-fastq/4DNFIB2GTXY5/ 4DNFI9XQ6UW1 0.2
# /files-fastq/4DNFIJSEKHCZ/ 4DNFIZK1VATZ 0.1
# /files-fastq/4DNFIHR715RF/ 4DNFIQ81A3IX 0.2
# /files-fastq/4DNFIDUA4NN9/ 4DNFINLK72Q2 0.2
#
# 78
# c5295325-d69e-4d4d-953a-322e52017272
# [u'human']
# /files-fastq/4DNFIQHKLUNI/ 4DNFIFZPTWXN 0.1
# /files-fastq/4DNFI441DS64/ 4DNFI6TVKP9W 0.1
# /files-fastq/4DNFIZ579P4F/ 4DNFIOJZXWP3 0.2
# /files-fastq/4DNFIZAYTENI/ 4DNFIYH1GPD1 0.2
# /files-fastq/4DNFIVS93VF3/ 4DNFINRTT1U4 0.1
# /files-fastq/4DNFIS5BVZQ7/ 4DNFIK47S2J8 0.1
# /files-fastq/4DNFITVG4SSN/ 4DNFIN6HIKX1 0.1
# /files-fastq/4DNFIHKCMRWL/ 4DNFIZ5DDZRL 0.1
# /files-fastq/4DNFIUI9E55O/ 4DNFI1QGJERV 0.1
# /files-fastq/4DNFIFAERABK/ 4DNFI2EGE35R 0.1
# /files-fastq/4DNFI5V7ZH5P/ 4DNFIFPOQ2XM 0.1
# /files-fastq/4DNFIXUAWRTP/ 4DNFI5NK4SWY 0.1
# /files-fastq/4DNFIH7KKLQP/ 4DNFIXJ7WBZQ 0.2
# /files-fastq/4DNFIELTT6W2/ 4DNFIEF2Y56O 0.2
# /files-fastq/4DNFIEPZF3VH/ 4DNFIBR6U38R 0.2
# /files-fastq/4DNFIS25SR9O/ 4DNFII67IGQ1 0.2
# /files-fastq/4DNFIYJ1IL7D/ 4DNFIFRLS7YI 0.1
# /files-fastq/4DNFIUVQWECY/ 4DNFIHK46VYZ 0.1
# /files-fastq/4DNFI2AM2JW8/ 4DNFI5KJWVGS 0.1
# /files-fastq/4DNFIM2X78AQ/ 4DNFIT5Q5K1P 0.1
# /files-fastq/4DNFIMZQFHM2/ 4DNFIYRACVXU 0.0
# /files-fastq/4DNFILHHSETD/ 4DNFICNOLUQH 0.0
# /files-fastq/4DNFIE3RLVIR/ 4DNFIW4UTR1N 0.0
# /files-fastq/4DNFIKXBLLA2/ 4DNFI4QZLNWA 0.0
# /files-fastq/4DNFIUGQQEXI/ 4DNFIUPFVU71 0.0
# /files-fastq/4DNFIF896ERO/ 4DNFI2QMTOOK 0.0
# /files-fastq/4DNFI2IRZYD9/ 4DNFITEOBUGF 0.0
# /files-fastq/4DNFIZK5DKHV/ 4DNFINT9VAJN 0.0
#
# 79
# 821112a5-c2f3-4e23-928a-99825ea73e35
# [u'human']
# /files-fastq/4DNFIUH314QU/ 4DNFIM7C7W8Y 0.1
#
# 80
# c8eddaef-ae6b-4f3b-bc4b-584198d570f7
# [u'human']
# /files-fastq/4DNFIEG74G77/ 4DNFILI9531T 0.1
#
# 81
# 70f48384-9bab-4225-9545-23b657eac395
# [u'human']
# /files-fastq/4DNFI93WJVIF/ 4DNFI3AZ7KXO 0.1
#
# 82
# 8bfe6c60-3e3c-40e1-9054-83f7ec460355
# [u'human']
# /files-fastq/4DNFIQZRBXSE/ 4DNFIHKIZNIH 0.1
#
# 83
# c0d66b79-524b-439b-9ece-df89c2a785e7
# [u'human']
# /files-fastq/4DNFIBYDOYRC/ 4DNFIQNT4H9T 0.1
#
# 84
# 13828aab-dca9-486b-a351-c5c90ba5cd51
# [u'human']
# /files-fastq/4DNFILB14ET4/ 4DNFIFLPFGCP 0.1
#
# 85
# ff988a5f-9dfd-41ee-a856-cd543ced4aa3
# [u'human']
# /files-fastq/4DNFI2P4YHYM/ 4DNFILZBGYDJ 4.1
# /files-fastq/4DNFIVV768H5/ 4DNFIKYCYEBL 4.2
# /files-fastq/4DNFIQ7IGVKT/ 4DNFIZGMYTO1 3.5
# /files-fastq/4DNFIVECA7IR/ 4DNFID7JGJJC 3.4
# /files-fastq/4DNFIYMHLNH1/ 4DNFIX4LCZ6H 3.4
# /files-fastq/4DNFI3A1N6VK/ 4DNFI5TORUSS 3.5
# /files-fastq/4DNFIUW1ZORK/ 4DNFIMGFQ7YV 3.6
# /files-fastq/4DNFIOO7FY12/ 4DNFIYYVNJ2J 3.8
# /files-fastq/4DNFIBJ17ZHS/ 4DNFIETJGESQ 3.9
# /files-fastq/4DNFIL1W2A7V/ 4DNFIOC2RYPY 3.8
# /files-fastq/4DNFIOXBMJO2/ 4DNFIL1Y311E 2.5
# /files-fastq/4DNFI1738CU6/ 4DNFIJ7P8K3M 2.7
# /files-fastq/4DNFICPT9427/ 4DNFI9GOGIGR 14.7
# /files-fastq/4DNFIBZAN516/ 4DNFIH8KDJ7I 0.3
# /files-fastq/4DNFIWBEUNPC/ 4DNFIK2NHAKH 15.2
#
# 86
# ec888986-1cca-4931-80e3-a0c9a031678f
# [u'human']
#
# 87
# 80abb6ed-f6c3-44be-92a9-45ced677c19a
# [u'human']
#
# 88
# af403e4d-19d1-4b98-81be-a49b2274496b
# [u'human']
#
# 89
# fcd8a4db-c26f-484b-a715-1ebfa0d7863a
# [u'human']
#
# 90
# 84019550-7de6-45d7-88dc-80aa784530b1
# [u'human']
#
# 91
# 7d9b634a-1281-4dcf-a3c1-910141c78a29
# [u'human']
#
# 92
# cc1216a1-1bf0-4457-851c-ba9780e8144c
# [u'human']
#
# 93
# e668263f-d66f-4020-bd2d-12e42c0035be
# [u'human']
#
# 94
# 11cd095e-3f77-4377-984b-fae418bad288
# [u'human']
#
# 95
# 265b2a84-8f9d-4bcd-83f9-7c99ce9d956c
# [u'human']
#
# 96
# 6072a21e-a96b-4d32-ab52-1c099e71ec7c
# [u'human']
# /files-fastq/4DNFIOXUIVLP/ 4DNFIMIGTXK6 9.8
#
# 97
# 0b3c36cf-4e44-43b0-a5c9-2c2e56ac8f0f
# [u'human']
# /files-fastq/4DNFI9CE9Z8N/ 4DNFIVZJ6VO1 4.7
# /files-fastq/4DNFIWBGNPYK/ 4DNFIFXWZGNX 4.8
#
# 98
# 2ccadfe8-39da-425d-bc17-aa5a83156d8e
# [u'human']
# /files-fastq/4DNFIV62VJ6F/ 4DNFIHIF4IKQ 15.2
# /files-fastq/4DNFIJBXWWNN/ 4DNFILQFNDH2 1.1
# /files-fastq/4DNFIXEXDDRK/ 4DNFIFC2XDRB 4.2
# /files-fastq/4DNFI9AT5WNM/ 4DNFIKS993QM 9.1
#
# 99
# b6cd8f8d-27d2-4d3e-b5bb-a5ceb4ee5c3c
# [u'human']
# /files-fastq/4DNFIGQIMFRI/ 4DNFI8IW8ETI 10.2
# /files-fastq/4DNFIUN68INY/ 4DNFIHOQGXAS 12.9
# /files-fastq/4DNFIWCIXEIF/ 4DNFINQOL4NN 10.9
# /files-fastq/4DNFI5FD75OP/ 4DNFIRXOSUZ6 9.2
# /files-fastq/4DNFI9WHM2LC/ 4DNFI4VTO9QT 17.3
# /files-fastq/4DNFI76KJB9H/ 4DNFIRRZ8UTN 25.3
#
# 100
# 369f6940-8510-4e1f-a07c-8c3b00f85dff
# [u'human']
# /files-fastq/4DNFIRGIBV63/ 4DNFIXH9DKXM 29.5
# /files-fastq/4DNFILI63PH4/ 4DNFIOZYKYU6 37.0
# /files-fastq/4DNFI65EZTY7/ 4DNFINZQ97F3 2.4
# /files-fastq/4DNFIEOYE1KX/ 4DNFIATLKIZY 2.3
# /files-fastq/4DNFIIIH5FWY/ 4DNFI8BROCUM 1.2
# /files-fastq/4DNFI6P89BP9/ 4DNFIXQEC7M2 1.2
# /files-fastq/4DNFIRMOJE5A/ 4DNFINTZC9WB 1.2
# /files-fastq/4DNFIP91RTLM/ 4DNFIMHB73L6 1.2
# /files-fastq/4DNFIR5FRG9W/ 4DNFIBUWE6OE 2.4
# /files-fastq/4DNFIYX2WMAS/ 4DNFICI87A78 2.3
#
# 101
# 8f665e33-2698-4163-b062-949fba63873d
# [u'human']
# /files-fastq/4DNFIXGAG8L7/ 4DNFIUQW4LAA 16.3
#
# 102
# f6589e11-7cf7-4565-86de-3974af7a335e
# [u'human']
# /files-fastq/4DNFIN2IF3F3/ 4DNFIX8KC97M 14.8
# /files-fastq/4DNFION5DGIL/ 4DNFINPCMXLZ 19.6
# /files-fastq/4DNFINMU3HSN/ 4DNFIH3HHV5L 39.0
#
# 103
# 0a017a28-c37a-4b71-8f3a-3904f6b47e42
# [u'human']
# /files-fastq/4DNFIW1SDBUC/ 4DNFI29841UK 16.6
# /files-fastq/4DNFITZLMEQJ/ 4DNFI8ZK74FZ 16.2
# /files-fastq/4DNFITNBSJL1/ 4DNFICI2Y9WQ 16.2
#
# 104
# 7b535bf7-cd95-4a76-8134-3b43a1651b11
# [u'human']
# /files-fastq/4DNFIPISB3B4/ 4DNFIRTG9336 28.5
# /files-fastq/4DNFI74FHUH6/ 4DNFIUT9GCZL 0.5
# /files-fastq/4DNFI3HU4BAH/ 4DNFIWOZX467 0.9
# /files-fastq/4DNFIMF8A64J/ 4DNFIW949JRP 1.1
# /files-fastq/4DNFI1H6R5WZ/ 4DNFILF3FPNL 1.1
# /files-fastq/4DNFISX9GXLD/ 4DNFIJE4MPEF 0.9
#
# 105
# 9135be43-33c6-463d-87c7-9e2b1d56adbd
# [u'human']
# /files-fastq/4DNFIA7QCP4U/ 4DNFITAGYOOC 8.9
#
# 106
# 9f86422b-08a3-4926-9ff8-22f8a0be1c48
# [u'human']
# /files-fastq/4DNFIHEC43TK/ 4DNFIDXXRJUW 16.5
# /files-fastq/4DNFI96TGXLL/ 4DNFIBH6S3JA 17.9
# /files-fastq/4DNFISDQF6CV/ 4DNFIB1HMF29 1.6
# /files-fastq/4DNFIMCJY2QU/ 4DNFIZX1BCT9 7.1
# /files-fastq/4DNFIN45QLQR/ 4DNFILDEVUSF 15.2
# /files-fastq/4DNFIZT5HGXK/ 4DNFIKBURSTL 18.7
# /files-fastq/4DNFIOZ7JX45/ 4DNFI5EXL4JB 20.4
#
# 107
# a1a39925-f4e4-4f68-9520-86dced6a083c
# [u'human']
# /files-fastq/4DNFIQOD73GY/ 4DNFIYFF7KJY 1.7
# /files-fastq/4DNFIQ9WQBVH/ 4DNFIU72RGP9 1.7
# /files-fastq/4DNFITHS83TF/ 4DNFIHUEC1G4 0.0
# /files-fastq/4DNFI5BJFVVZ/ 4DNFIDOO7VNB 0.0
# /files-fastq/4DNFIAIV3V29/ 4DNFI8ZK9A6F 0.3
# /files-fastq/4DNFILFH6RI7/ 4DNFIL8Q3S3J 0.3
# /files-fastq/4DNFITARKG48/ 4DNFIBAKK7QS 0.2
# /files-fastq/4DNFIV5MDEUU/ 4DNFI1R3E54X 0.2
# /files-fastq/4DNFIHVBZZ7X/ 4DNFIRJ8G68S 0.2
# /files-fastq/4DNFI46Q1U9Q/ 4DNFIFIVHVEU 0.2
# /files-fastq/4DNFI75KWVST/ 4DNFIPJVFYSX 1.8
# /files-fastq/4DNFIMJCWJ4O/ 4DNFIHTZPYVM 1.8
# /files-fastq/4DNFIZGBMTQ4/ 4DNFI3UZDKGF 0.0
# /files-fastq/4DNFINHNBAWV/ 4DNFIGQWXPOF 0.0
# /files-fastq/4DNFIW3JNPFC/ 4DNFI72F2L6M 0.4
# /files-fastq/4DNFIPGLO4UL/ 4DNFIXTAZGC6 0.4
# /files-fastq/4DNFIFVSHDJG/ 4DNFIXSUQW5T 0.2
# /files-fastq/4DNFIJ5ET6MX/ 4DNFIS3TQ6DL 0.2
# /files-fastq/4DNFI8EZLF1E/ 4DNFIL614MGU 0.2
# /files-fastq/4DNFI3RPSS5X/ 4DNFIUAQALP7 0.2
#
# 108
# b258fb64-3d9c-472d-9fce-60f293be2ac2
# [u'human']
# /files-fastq/4DNFI6W569F6/ 4DNFI923YLXB 7.7
#
# 109
# 7b3c4c77-221a-4e21-bd95-4345cd220caa
# [u'human']
# /files-fastq/4DNFIGCX4XEH/ 4DNFIPUEUERV 5.9
# /files-fastq/4DNFIYY4W4VY/ 4DNFIR9GJWST 5.9
# /files-fastq/4DNFI2ZKZQTZ/ 4DNFIGENEVWB 7.1
# /files-fastq/4DNFITKTRBZU/ 4DNFIHTJYH5T 5.9
# /files-fastq/4DNFIQVI4XXQ/ 4DNFIMCJXZKH 8.0
#
# 110
# 844ed6ca-1b16-4827-830f-87ab613b0a56
# [u'human']
# /files-fastq/4DNFIOIRW5GO/ 4DNFIHKUJC39 15.6
# /files-fastq/4DNFI4Q46QWG/ 4DNFI2BOWMXW 15.9
# /files-fastq/4DNFIKXS6UAI/ 4DNFITDMVPYE 16.3
# /files-fastq/4DNFI1IBQLLM/ 4DNFI4TFRODP 16.6
#
# 111
# e6ce55ac-a39f-4064-a578-5329c5454205
# [u'human']
# /files-fastq/4DNFI2ODUV3V/ 4DNFIH2FMKX4 14.9
# /files-fastq/4DNFIL3UHHMS/ 4DNFI1LHO8TZ 15.0
# /files-fastq/4DNFIBH655V6/ 4DNFIHTUHK6B 14.9
# /files-fastq/4DNFICYR7A3D/ 4DNFI2FZ7WRH 14.8
# /files-fastq/4DNFIPBN8225/ 4DNFINAYLC5M 14.4
# /files-fastq/4DNFIZ2EM38D/ 4DNFIXRJEPJB 14.6
# /files-fastq/4DNFILE2FFIP/ 4DNFISIAF8Y2 14.9
# /files-fastq/4DNFIELZ58V4/ 4DNFIM4SY95S 15.0
# /files-fastq/4DNFIFMQ2FV2/ 4DNFIASHJZCY 15.1
# /files-fastq/4DNFI635EBRY/ 4DNFIB94UMHJ 15.1
# /files-fastq/4DNFIZE3A7K7/ 4DNFIJH6ENMA 15.0
# /files-fastq/4DNFI6E4RZ9H/ 4DNFIIN1NES7 14.8
# /files-fastq/4DNFIGV3S7HN/ 4DNFINTOMVGZ 15.1
# /files-fastq/4DNFI46K3W1Y/ 4DNFI7DTB5JD 14.9
# /files-fastq/4DNFIT1DXKSN/ 4DNFILW3SKV5 15.1
# /files-fastq/4DNFISUPVVMG/ 4DNFIIX9EOUI 14.9
# /files-fastq/4DNFI6M6HK44/ 4DNFI7U6YR84 14.7
# /files-fastq/4DNFIIHN7EFC/ 4DNFI7RADH7L 16.1
# /files-fastq/4DNFI8TACL55/ 4DNFIBFOCKFA 16.2
# /files-fastq/4DNFIITL9NGY/ 4DNFIEGZHNFV 16.4
# /files-fastq/4DNFI1KA4E4B/ 4DNFIEZGNI5Y 16.1
# /files-fastq/4DNFIBHYIFID/ 4DNFIF1KYPTY 16.1
# /files-fastq/4DNFIHBVVM79/ 4DNFI5PUCNDF 15.8
# /files-fastq/4DNFI374LLU1/ 4DNFISR9NDJN 16.2
# /files-fastq/4DNFISJP1L1W/ 4DNFILGIAEZD 14.1
# /files-fastq/4DNFIXUY3QNH/ 4DNFIGP82LZH 14.1
# /files-fastq/4DNFI32WHLEW/ 4DNFIWV5A3Z6 14.5
# /files-fastq/4DNFIO2OSFGB/ 4DNFIW7FKQXS 14.7
# /files-fastq/4DNFIOKJAEVF/ 4DNFI44JD4EE 14.4
# /files-fastq/4DNFI2YOW532/ 4DNFIUVVZ5R4 14.5
# /files-fastq/4DNFIS2WP42S/ 4DNFIKQLSC9T 14.1
# [u'dcic:HIC037_SRR1658643_1'] larger than 42GB, skipping, please use another script
#
# 112
# 090792c3-6f25-4d33-8ca9-7cc259d070bf
# [u'human']
# /files-fastq/4DNFIAKTJVEA/ 4DNFI49BBQGL 6.2
# /files-fastq/4DNFIHUU81HO/ 4DNFI5BO2H1Z 4.7
#
# 113
# 17b4aa3e-5c9c-457e-8413-1a6441f89324
# [u'human']
# /files-fastq/4DNFIYIR7GH2/ 4DNFIGLQEVE2 9.0
# /files-fastq/4DNFIV24L6E3/ 4DNFIIL4ZUBV 8.8
#
# 114
# 5dbcedc0-0a69-4eb3-8c71-3471212bc5de
# [u'human']
# /files-fastq/4DNFIX9939CW/ 4DNFIBYV2SS8 31.0
#
# 115
# 2a756f80-89c5-4979-bb70-75a4b69634ce
# [u'human']
# /files-fastq/4DNFIPWSGIR7/ 4DNFIJS9NAZ5 24.6
#
# 116
# aa6f0d82-16c9-4109-a1f8-3fa0636a3560
# [u'human']
# /files-fastq/4DNFIPT5ZEMO/ 4DNFIF14XQFV 38.5
# /files-fastq/4DNFI88FECHF/ 4DNFIM7JG41M 10.0
# /files-fastq/4DNFI15H1RVG/ 4DNFIZHUKESO 6.2
# /files-fastq/4DNFIKVDGNJN/ 4DNFIEQ58J6G 9.0
# /files-fastq/4DNFIIEHDKJV/ 4DNFIQC6RSUD 7.2
# /files-fastq/4DNFIHP7VGY8/ 4DNFIJPD156A 12.0
# /files-fastq/4DNFILW25QL3/ 4DNFIN4K7CCH 14.7
# /files-fastq/4DNFIOYJ9LAW/ 4DNFIOA5TNC1 19.0
# /files-fastq/4DNFIISFNNPU/ 4DNFIEPVXYTH 10.4
# /files-fastq/4DNFIHFH58PJ/ 4DNFIVRESE4U 3.9
# /files-fastq/4DNFIPVUH4E5/ 4DNFIBF377E2 3.9
# /files-fastq/4DNFIN5YSD9A/ 4DNFIP9U5XO4 15.4
# /files-fastq/4DNFIS1XPLA6/ 4DNFIUJDWVQV 5.7
# /files-fastq/4DNFIYTLTSFN/ 4DNFIAU6QDBL 12.5
# /files-fastq/4DNFIT48F7C7/ 4DNFI3SFZFFD 10.2
# /files-fastq/4DNFI5QGE2CH/ 4DNFI3VYO28H 13.8
# /files-fastq/4DNFITVJA97A/ 4DNFIBLOYUV7 15.3
# /files-fastq/4DNFI34MGS31/ 4DNFIHWTGBAH 12.6
# /files-fastq/4DNFIZ4N2DWX/ 4DNFIV738FT4 10.7
# /files-fastq/4DNFIXVC9J5G/ 4DNFI17QSV56 14.1
# /files-fastq/4DNFIMPW5J27/ 4DNFIGONO7U7 13.1
# /files-fastq/4DNFI7XH8QCL/ 4DNFIUC32Q3T 16.1
# /files-fastq/4DNFIMKH2U88/ 4DNFIJYWEKNP 14.8
# /files-fastq/4DNFIX6IBS1L/ 4DNFI7T43MJ6 12.4
# /files-fastq/4DNFI4AOE2UW/ 4DNFIVBCV57T 8.7
# /files-fastq/4DNFIJ45F4I8/ 4DNFIZ5X4QH6 27.8
# /files-fastq/4DNFI4HLO4LZ/ 4DNFILKTPE6B 28.7
# /files-fastq/4DNFIX3U2J8P/ 4DNFI9VQS8ZX 25.6
# /files-fastq/4DNFILOPEXLE/ 4DNFIYHR292O 4.2
# /files-fastq/4DNFILI58THH/ 4DNFI8AIOVVP 9.4
# /files-fastq/4DNFIM22HR5E/ 4DNFIW2PDQ4K 5.6
# /files-fastq/4DNFI1VDM6O5/ 4DNFISWMFVOY 6.3
#
# 117
# ee8e40d0-d170-4597-a485-1b9e67af815e
# [u'human']
# /files-fastq/4DNFIMVAKKBC/ 4DNFIOVYXYVP 16.1
# /files-fastq/4DNFIMGO4BQX/ 4DNFIND3P9CZ 32.6
#
# done

# %%
pairs_completed = []
pairs_running = []
pairs_did_not_run = []
pairs_ready_to_run = []
pairs_qcmd_problem = []

all_num= 0
for name, org, report in all_reports: 
    all_num += len(report)
    
    # 1 completed pairs
    pairs_completed.extend([[name,org,i] for i in report if i['partA_status']=='complete'])
    # 2 running pairs
    pairs_running.extend([[name, org, i] for i in report if i['partA_status'] not in ['complete','did_not_run']])
    # 3 no run pairs
    pairs_did_not_run.extend([[name, org, i] for i in report if i['partA_status']=='did_not_run'])
                             
                            
# 3a no run pairs with fine qc md5
pairs_ready_to_run = [[i[0], i[1], i[2]['file1'], i[2]['file2']] for i in pairs_did_not_run if i[2]['wf_check'] == '++']
# 3b no run pairs with problematic qc md5
pairs_qcmd_problem = [[i[0], i[1], i[2]['file1'], i[2]['file2']] for i in pairs_did_not_run if i[2]['wf_check'] != '++']

# # 2 running pairs to run again
# rerun_running_pairs = [(i['file1'], i['file2']) for i in report if i['partA_status'] not in ['complete','did_not_run']]

# rerun_started_pairs = [(i['file1'], i['file2']) for i in report if i['partA_status']=='started']

print "{}/{} pairs completed partA".format(all_num, len(pairs_completed))
print "{}/{} pairs still running partA".format(all_num, len(pairs_running))

print '1) ready to run (pairs_ready_to_run)'
print len(pairs_ready_to_run)
for n,o,a,b in pairs_ready_to_run:
    print n,o,a,b
print ""

print '2) problematics ones (pairs_qcmd_problem)'
for n,o,a,b in pairs_qcmd_problem:
    print n,o,a,b
print ""


print "DONE"
# Out:
# 684/678 pairs completed partA
# 684/0 pairs still running partA
# 1) ready to run (pairs_ready_to_run)
# 6
# 5db537d2-1cf6-44c2-ae5d-6d724c9f43bc [u'human'] chuck-murry-lab:fetal_heart_dnase_hic_seq_rep1_run1_R1 chuck-murry-lab:fetal_heart_dnase_hic_seq_rep1_run1_R2
# 5db537d2-1cf6-44c2-ae5d-6d724c9f43bc [u'human'] chuck-murry-lab:fetal_heart_dnase_hic_seq_rep2_run1_R1 chuck-murry-lab:fetal_heart_dnase_hic_seq_rep2_run1_R2
# 3effa8a5-1156-4f1a-aa8a-e6d511c384c6 [u'human'] chuck-murry-lab:esc_dnase_hic_seq_rep1_run2_R1 chuck-murry-lab:esc_dnase_hic_seq_rep1_run2_R2
# 46572b13-ac2d-45de-9e11-a50236f975dd [u'human'] dcic:SRR2671373_1 dcic:SRR2671373_2
# 46572b13-ac2d-45de-9e11-a50236f975dd [u'human'] dcic:SRR2671374_1 dcic:SRR2671374_2
# b258fb64-3d9c-472d-9fce-60f293be2ac2 [u'human'] dcic:HIC043_SRR1658649_1 dcic:HIC043_SRR1658649_2
#
# 2) problematics ones (pairs_qcmd_problem)
#
# DONE

# %%
from core.utils import Tibanna
from core.utils import run_workflow
import time

paired_files = pairs_ready_to_run

env = 'fourfront-webprod'
tibanna = Tibanna(env=env)
outfiles = tibanna.s3.outfile_bucket
tibanna.s3.outfile_bucket = 'elasticbeanstalk-fourfront-webprod-files'
index_h = make_input_file_json('4DNFIZQZ39L9', 'bwa_index', tibanna)
index_m = make_input_file_json('4DNFI823LSI8', 'bwa_index', tibanna)

for set_name, organisms, f1,f2 in paired_files: 

    # find the correct index
    if organisms == ['human']:
        index = index_h
    elif organisms == ['mouse']:
        #index = index_m
        continue
    else:
        continue

    fastq1 = make_input_file_json(f1, 'fastq1', tibanna)
    fastq2 = make_input_file_json(f2, 'fastq2', tibanna)

    input_files = [fastq1, fastq2, index]
    if all(input_files):
        name = fastq1['object_key'].split('.')[0] + "-" + fastq2['object_key'].split('.')[0]
        input_json = make_hic1_json(input_files, env, outfiles, name)
        # print input_json
        res = run_workflow(input_json)
    else:
        print("some files not found on s3.  Investigate this list %s" % input_files)
    time.sleep(2)
    #a = raw_input("Press Enter to continue...")

print('Done')
# Out:
# looking for upload key 1f53df95-4cf3-41cc-971d-81bb16c486dd/4DNFIZQZ39L9.bwaIndex.tgz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 4a6d10ee-2edb-4402-a98f-0edb1d58f5e1/4DNFI823LSI8.bwaIndex.tgz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 0cfb16e8-b902-4977-a498-587d36497687/4DNFIG22ZQ7Y.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 37d96da6-1daf-4bd0-87fa-50ec8df1cf3f/4DNFIMM81AZ3.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIG22ZQ7Y-4DNFIMM81AZ3
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 3, 19, 20, 27, 10, 288000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '6da9735e-2bd5-11e8-91f9-51cdf96108a6', 'HTTPHeaders': {'x-amzn-requestid': '6da9735e-2bd5-11e8-91f9-51cdf96108a6', 'content-length': '142', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIG22ZQ7Y-4DNFIMM81AZ3'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIG22ZQ7Y-4DNFIMM81AZ3
# looking for upload key 682971b6-eef4-49ca-b35d-7c7b6475bc28/4DNFI855FM8W.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key e230900b-98f5-4473-aecb-9f866c44576b/4DNFIHIB8POP.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFI855FM8W-4DNFIHIB8POP
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 3, 19, 20, 27, 16, 767000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '7186ad32-2bd5-11e8-b840-ff6a6d6d0caa', 'HTTPHeaders': {'x-amzn-requestid': '7186ad32-2bd5-11e8-b840-ff6a6d6d0caa', 'content-length': '142', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFI855FM8W-4DNFIHIB8POP'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFI855FM8W-4DNFIHIB8POP
# looking for upload key 97f08476-c5eb-4257-85d4-03a7cec555b8/4DNFISUM635J.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 833e5ba8-ea5b-4cf5-a2fb-baa3f46b70c0/4DNFIWE1ZP5N.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFISUM635J-4DNFIWE1ZP5N
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 3, 19, 20, 27, 23, 743000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '75adc1a9-2bd5-11e8-833a-33c97d378779', 'HTTPHeaders': {'x-amzn-requestid': '75adc1a9-2bd5-11e8-833a-33c97d378779', 'content-length': '142', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFISUM635J-4DNFIWE1ZP5N'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFISUM635J-4DNFIWE1ZP5N
# looking for upload key a508702f-c0b2-4774-b865-07a3dfdb3657/4DNFITYRLYTG.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 6de300ba-840d-4b45-bf91-98bab76a3294/4DNFI5J8F7AT.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFITYRLYTG-4DNFI5J8F7AT
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 3, 19, 20, 27, 30, 920000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '79f64111-2bd5-11e8-ae4b-3b54587c1e8d', 'HTTPHeaders': {'x-amzn-requestid': '79f64111-2bd5-11e8-ae4b-3b54587c1e8d', 'content-length': '141', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFITYRLYTG-4DNFI5J8F7AT'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFITYRLYTG-4DNFI5J8F7AT
# looking for upload key 5fb1afa0-6256-4f6a-afde-25405c931631/4DNFIXP926SF.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 0daac204-aaeb-4e37-bf84-4b3d6f17d59a/4DNFI2VXKAOI.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFIXP926SF-4DNFI2VXKAOI
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 3, 19, 20, 27, 38, 922000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '7eba590f-2bd5-11e8-9b16-9d9901527bc7', 'HTTPHeaders': {'x-amzn-requestid': '7eba590f-2bd5-11e8-9b16-9d9901527bc7', 'content-length': '142', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIXP926SF-4DNFI2VXKAOI'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIXP926SF-4DNFI2VXKAOI
# looking for upload key 7b5c4d95-4b6a-48af-9028-b8947b9ba8f2/4DNFI6W569F6.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# looking for upload key 88e59e41-888e-4cef-8944-e3f2ffb45826/4DNFI923YLXB.fastq.gz, on bucket elasticbeanstalk-fourfront-webprod-files
# about to start run bwa-mem_4DNFI6W569F6-4DNFI923YLXB
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 3, 19, 20, 27, 46, 774000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '8369afc3-2bd5-11e8-9f46-599974d1ccfd', 'HTTPHeaders': {'x-amzn-requestid': '8369afc3-2bd5-11e8-9f46-599974d1ccfd', 'content-length': '142', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFI6W569F6-4DNFI923YLXB'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFI6W569F6-4DNFI923YLXB
# Done
