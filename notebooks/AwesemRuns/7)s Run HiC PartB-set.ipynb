# %%
from core.utils import Tibanna
from core import ff_utils

#format for input json in hic-partII
def make_input_file_json(obj_ids, arg_name, tibanna, bucket):
    '''
    obj_ids can be either a string or a list.
    {
      "bucket_name": "%s",
      "object_key": "%s",
      "uuid" : "%s",
      "workflow_argument_name": "%s"
    }
    '''
    
    ff = ff_utils.fdn_connection(key=tibanna.ff_keys)
    if not isinstance(obj_ids, list):
        obj_ids = [ obj_ids ]     
    object_key_list = []
    uuid_list = []
    for obj_id in obj_ids:
        metadata = ff_utils.get_metadata(obj_id, connection=ff)
         
        # just make sure the file is on s3, otherwise bail
        print("looking for upload key %s, on bucket %s" % 
              (metadata['upload_key'],
               bucket))
        if tibanna.s3.does_key_exist(metadata['upload_key'], bucket=bucket):
            object_key_list.append(metadata['upload_key'].split('/')[1])
            uuid_list.append(metadata['uuid'])     
    if len(uuid_list)==1:
        uuid_list = uuid_list[0]
    if len(object_key_list)==1:
        object_key_list = object_key_list[0]  
    data = {'bucket_name' : bucket,
            'object_key' :  object_key_list,
            'uuid' : uuid_list,
            'workflow_argument_name': arg_name
            }
    return data


def make_input_file_json2(obj_ids, arg_name, tibanna, bucket):
    '''
    obj_ids can be either a string or a list.
    {
      "bucket_name": "%s",
      "object_key": "%s",
      "uuid" : "%s",
      "workflow_argument_name": "%s"
    }
    '''
    
    ff = ff_utils.fdn_connection(key=tibanna.ff_keys)
    if not isinstance(obj_ids, list):
        obj_ids = [ obj_ids ]     
    object_key_list = []
    uuid_list = []
    for obj_id in obj_ids:
        metadata = ff_utils.get_metadata(obj_id, connection=ff)

         
        # just make sure the file is on s3, otherwise bail
        print("looking for upload key %s, on bucket %s" % 
              (metadata['upload_key'],
               bucket))
        if tibanna.s3.does_key_exist(metadata['upload_key'], bucket=bucket):
            object_key_list.append(metadata['upload_key'].split('/')[1])
            uuid_list.append(metadata['uuid'])     
#     if len(uuid_list)==1:
#         uuid_list = uuid_list[0]
#     if len(object_key_list)==1:
#         object_key_list = object_key_list[0]  
    data = {'bucket_name' : bucket,
            'object_key' :  object_key_list,
            'uuid' : uuid_list,
            'workflow_argument_name': arg_name
            }
    return data


def make_hic7_json(input_files, env, output_bucket, accession):
    input_json = {'input_files': input_files,
                  'output_bucket': output_bucket,
                  'workflow_uuid': "d9e9c966-56d9-47e8-ae21-47f94a1af417",
                  "app_name": "hi-c-processing-partb",
                  "parameters": {
                          "ncores": 1,
                        "min_res": 5000,
                        "maxmem": "60g",
                        "binsize": 5000
                      },
                  "config": {
                        "ami_id": "ami-cfb14bb5",
                        "json_bucket": "4dn-aws-pipeline-run-json",
                        "ebs_iops": 500,
                        "shutdown_min": 30,
                        "s3_access_arn": "arn:aws:iam::643366669028:instance-profile/S3_access",
                        "ebs_type": "io1",
                        "copy_to_s3": True,
                        "script_url": "https://raw.githubusercontent.com/4dn-dcic/tibanna/master/awsf/",
                        "key_name": "4dn-encode",
                        "launch_instance": True,
                        "password": "hahaha",
                        "log_bucket": "tibanna-output"
                      },
                  "_tibanna": {"env": env, 
                               "run_type": "partb",
                               "run_id": accession}
                  }
    return input_json



def get_wfr_out(emb_file, wfr_name, file_format):
    workflows = emb_file.get('workflow_run_inputs')
    wfr = {}
    run_status = 'did not run'
    if workflows:
        for a_wfr in workflows:
            wfr_resp = ff_utils.get_metadata(a_wfr['uuid'], connection=ff)  
            wfr_resp_name = wfr_resp['display_title']
            if wfr_resp_name.startswith(wfr_name):
                wfr = wfr_resp
                run_status = wfr_resp['run_status']
    else:
        return "no workflow in file"
    
    if run_status == 'complete':
        outputs = wfr.get('output_files')
        file_id = [i['value'] for i in outputs if i['format'] == file_format][0]
        if file_id:
            return file_id
        else:
            return "no file found"
    else:
        print wfr_name
        return "no completed run"

# %%
from invoke import run
import time
from datetime import datetime


def form_hyp(id):
    hyp = '=HYPERLINK("https://data.4dnucleome.org/{0}","{0}")'.format(id)
    return hyp


all_sets = [
            'dcic:Selvaraj_gm12878_hic',
            'dekker-lab:ExperimentSet_U54_U54-ESC4DN-FA-DpnII-2017524',
            'dekker-lab:ExperimentSet_U54_HFFc6-FA-DpnII'
            ]
   
my_rep_set = all_sets[0]
print my_rep_set

wf_partI = "bwa-mem"
env = 'fourfront-webprod'
tibanna = Tibanna(env=env)

enzymes = []

ff = ff_utils.fdn_connection(key=tibanna.ff_keys)
rep_set_resp = ff_utils.get_metadata(my_rep_set, connection=ff)
rep_resp = rep_set_resp['experiments_in_set']
set_acc = rep_set_resp['accession']

exps_pairsems = []
all_fine = True

f_pairs = 0
for exp in rep_resp:    
    # print 'Experiment', exp
    exp_resp = ff_utils.get_metadata(exp, connection=ff)
    enzyme = exp_resp['digestion_enzyme']
    enzymes.append(enzyme)
    exp_files = exp_resp['files']
    exp_acc = exp_resp['accession']
    for fastq_file in exp_files:
        file_resp = ff_utils.get_metadata(fastq_file, connection=ff, frame='embedded')  
        #Some checks before running
        #check if status is deleted
        if file_resp['status'] == 'deleted':
            print "delete file", file_resp['accession']
            continue
        #if no uploaded file in the file item report and skip
        if not file_resp.get('filename'):
            print file_resp['accession'], "does not have a file"
            continue
        # check if file is in s3
        head_info = tibanna.s3.does_key_exist(file_resp['upload_key'], tibanna.s3.raw_file_bucket)
        if not head_info:
            print file_resp['accession'], "does not have a file in S3"
            continue
        
        # skip pair no 2
        if file_resp.get('paired_end')=='2':
            continue
        f_pairs += 1
        paired_file = file_resp['related_files'][0]['file']['accession']
        # print file_resp['accession'], paired_file,
        
        #Check for partI
        bam_file = get_wfr_out(file_resp, "bwa-mem", 'bam')
        if bam_file.startswith('no') or not bam_file:
            print bam_file
            all_fine = False
            continue 
        else:
            bam_resp = ff_utils.get_metadata(bam_file, connection=ff, frame='embedded')
            
            # Check for part II
            pairsem_file = get_wfr_out(bam_resp, "pairsam-parse-sort", 'pairsam')
            if pairsem_file.startswith('no') or not pairsem_file:
                print pairsem_file
                all_fine = False
                continue
            else:
                pairsem_resp = ff_utils.get_metadata(pairsem_file, connection=ff, frame='embedded')
                
                #check for result of part IIB
                pairsem_all_file = get_wfr_out(pairsem_resp, "pairsam-merge", 'pairsam')
                if pairsem_all_file.startswith('no') or not pairsem_all_file:
                    print pairsem_all_file
                    all_fine = False
                    continue
                else:
                    pairsem_all_resp = ff_utils.get_metadata(pairsem_all_file, connection=ff, frame='embedded')
                    
                    #check for result of part III
                    pairsem_md = get_wfr_out(pairsem_all_resp, "pairsam-markasdup", 'pairsam')
                    if pairsem_md.startswith('no') or not pairsem_md:
                        print pairsem_md
                        all_fine = False
                        continue
                    else:
                        pairsem_md_resp = ff_utils.get_metadata(pairsem_md, connection=ff, frame='embedded')
                        
                        
                        #check for result of part IV
                        pairsem_ft = get_wfr_out(pairsem_md_resp, "pairsam-filter", 'pairs')
                        if pairsem_ft.startswith('no') or not pairsem_ft:
                            print pairsem_ft
                            all_fine = False
                            continue
                        else:
                            pairsem_ft_resp = ff_utils.get_metadata(pairsem_ft, connection=ff, frame='embedded')
                            
                            #check for result of part V
                            fr_pairs = get_wfr_out(pairsem_ft_resp, "addfragtopairs", 'pairs')
                            if fr_pairs.startswith('no') or not fr_pairs:
                                print fr_pairs
                                all_fine = False
                                continue
                            else:
                                fr_pairs_resp = ff_utils.get_metadata(fr_pairs, connection=ff, frame='embedded')
                            
                                #check for result of part VI
                                pt_pairs = get_wfr_out(fr_pairs_resp, "pairs-patch", 'pairs')
                                if pt_pairs.startswith('no') or not pt_pairs:
                                    print pt_pairs
                                    all_fine = False
                                    continue
                                else:
                                    pt_pairs_resp = ff_utils.get_metadata(pt_pairs, connection=ff, frame='embedded')
                    

                                    f_s = round(pt_pairs_resp['file_size']/(1024*1024*1024.0),2)
                                    print form_hyp(pt_pairs_resp["accession"])+'\t'+pt_pairs_resp["uuid"]+"\t"+str(f_s)
                        
        exps_pairsems.append((exp_acc,pt_pairs_resp["accession"]))
        break


print exps_pairsems
exps_pairsems = [set_acc, [i[1] for i in exps_pairsems]]
print exps_pairsems
# Out:
# dcic:Selvaraj_gm12878_hic
# =HYPERLINK("https://data.4dnucleome.org/4DNFICYJ9FOU","4DNFICYJ9FOU")	a9554821-af87-489d-bba6-f58d4286a2a3	6.66
# =HYPERLINK("https://data.4dnucleome.org/4DNFI1ZLO9D7","4DNFI1ZLO9D7")	817f3faa-0573-45c0-8230-02ec19de6544	6.11
# [(u'4DNEXBZAHAQZ', u'4DNFICYJ9FOU'), (u'4DNEXLQ26QO3', u'4DNFI1ZLO9D7')]
# [u'4DNESLLTENG9', [u'4DNFICYJ9FOU', u'4DNFI1ZLO9D7']]

# %%
from core.utils import Tibanna
from core.utils import run_workflow
import time

pairsem_files = [exps_pairsems]

env = 'fourfront-webprod'
tibanna = Tibanna(env=env)

output_file_bucket = tibanna.s3.outfile_bucket
raw_file_bucket = tibanna.s3.raw_file_bucket

chrsizes = make_input_file_json('4DNFI823LSII', 'chrsizes', tibanna, raw_file_bucket)
#restrict = make_input_file_json(re_ref_file, 'restriction_file', tibanna, raw_file_bucket)

# todo need a function to determin this given fastq1
for exp_pairsem_files in pairsem_files:
    pairsam1 = make_input_file_json2(exp_pairsem_files[1], 'input_pairs', tibanna, output_file_bucket) 
    input_files = [pairsam1, chrsizes]
    if all(input_files):
        name = exp_pairsem_files[0]+'_set_'
        input_json = make_hic7_json(input_files, env, output_file_bucket, name)
        print input_json
        res = run_workflow(input_json)
    else:
        print("some files not found on s3.  Investigate this list %s" % input_files)
    time.sleep(5)
    #a = raw_input("Press Enter to continue...")

print('Done')
# Out:
# looking for upload key 4a6d10ee-2edb-4402-a98f-0edb1d58f5e9/4DNFI823LSII.chrom.sizes, on bucket elasticbeanstalk-fourfront-webprod-files
# 4DNFICYJ9FOU
# {u'display_title': u'4DNFICYJ9FOU.pairs.gz', u'accession': u'4DNFICYJ9FOU', u'link_id': u'~files-processed~4DNFICYJ9FOU~', u'upload_key': u'a9554821-af87-489d-bba6-f58d4286a2a3/4DNFICYJ9FOU.pairs.gz', u'experiments': [], u'alternate_accessions': [], u'file_size': 7153224651, u'experiment_sets': [], u'aliases': [], u'submitted_by': u'/users/986b362f-4eb6-4a9c-8173-3ab267307e3a/', u'dbxrefs': [], u'uuid': u'a9554821-af87-489d-bba6-f58d4286a2a3', u'title': u'4DNFICYJ9FOU', u'schema_version': u'1', u'file_type_detailed': u'other (pairs)', u'extra_files': [{u'file_format': u'pairs_px2'}], u'status': u'uploaded', u'external_references': [], u'workflow_run_outputs': [u'/workflow-runs-awsem/8705ce63-513c-4910-bead-8772fdefc276/'], u'lab': u'/labs/4dn-dcic-lab/', u'award': u'/awards/1U01CA200059-01/', u'principals_allowed': {u'audit': [u'system.Everyone'], u'edit': [u'group.admin', u'submits_for.828cd4fe-ebb0-4b36-a94a-d2e3a36cc989'], u'view': [u'award.b0b9c607-f8b4-4f02-93f4-9895b461334b', u'group.admin', u'group.read-only-admin', u'lab.828cd4fe-ebb0-4b36-a94a-d2e3a36cc989', u'remoteuser.EMBED', u'remoteuser.INDEXER']}, u'@id': u'/files-processed/4DNFICYJ9FOU/', u'workflow_run_inputs': [u'/workflow-runs-awsem/98f9c91e-7e74-4d8e-932b-28faa49f7b6a/'], u'file_format': u'pairs', u'href': u'/files-processed/4DNFICYJ9FOU/@@download/4DNFICYJ9FOU.pairs.gz', u'date_created': u'2017-09-17T16:17:53.935106+00:00', u'@type': [u'FileProcessed', u'File', u'Item']}
# looking for upload key a9554821-af87-489d-bba6-f58d4286a2a3/4DNFICYJ9FOU.pairs.gz, on bucket elasticbeanstalk-fourfront-webprod-wfoutput
# 4DNFI1ZLO9D7
# {u'display_title': u'4DNFI1ZLO9D7.pairs.gz', u'accession': u'4DNFI1ZLO9D7', u'link_id': u'~files-processed~4DNFI1ZLO9D7~', u'upload_key': u'817f3faa-0573-45c0-8230-02ec19de6544/4DNFI1ZLO9D7.pairs.gz', u'experiments': [], u'alternate_accessions': [], u'file_size': 6561025451, u'experiment_sets': [], u'aliases': [], u'submitted_by': u'/users/986b362f-4eb6-4a9c-8173-3ab267307e3a/', u'dbxrefs': [], u'uuid': u'817f3faa-0573-45c0-8230-02ec19de6544', u'title': u'4DNFI1ZLO9D7', u'schema_version': u'1', u'file_type_detailed': u'other (pairs)', u'extra_files': [{u'file_format': u'pairs_px2'}], u'status': u'uploaded', u'external_references': [], u'workflow_run_outputs': [u'/workflow-runs-awsem/3c3eee6a-5e44-40a3-9cb6-c00cb9a9e5cb/'], u'award': u'/awards/1U01CA200059-01/', u'lab': u'/labs/4dn-dcic-lab/', u'principals_allowed': {u'audit': [u'system.Everyone'], u'edit': [u'group.admin', u'submits_for.828cd4fe-ebb0-4b36-a94a-d2e3a36cc989'], u'view': [u'award.b0b9c607-f8b4-4f02-93f4-9895b461334b', u'group.admin', u'group.read-only-admin', u'lab.828cd4fe-ebb0-4b36-a94a-d2e3a36cc989', u'remoteuser.EMBED', u'remoteuser.INDEXER']}, u'@id': u'/files-processed/4DNFI1ZLO9D7/', u'workflow_run_inputs': [u'/workflow-runs-awsem/51538ae1-ea89-4ec0-9a2e-6553d75d819f/'], u'file_format': u'pairs', u'href': u'/files-processed/4DNFI1ZLO9D7/@@download/4DNFI1ZLO9D7.pairs.gz', u'date_created': u'2017-09-17T16:18:00.690798+00:00', u'@type': [u'FileProcessed', u'File', u'Item']}
# looking for upload key 817f3faa-0573-45c0-8230-02ec19de6544/4DNFI1ZLO9D7.pairs.gz, on bucket elasticbeanstalk-fourfront-webprod-wfoutput
# {'app_name': 'hi-c-processing-partb', 'parameters': {'ncores': 1, 'min_res': 5000, 'binsize': 5000, 'maxmem': '60g'}, '_tibanna': {'run_type': 'partb', 'env': 'fourfront-webprod', 'run_id': u'4DNESLLTENG9_set_'}, 'output_bucket': 'elasticbeanstalk-fourfront-webprod-wfoutput', 'config': {'ebs_type': 'io1', 'key_name': '4dn-encode', 'ebs_iops': 500, 'shutdown_min': 30, 's3_access_arn': 'arn:aws:iam::643366669028:instance-profile/S3_access', 'launch_instance': True, 'password': 'hahaha', 'log_bucket': 'tibanna-output', 'ami_id': 'ami-cfb14bb5', 'json_bucket': '4dn-aws-pipeline-run-json', 'copy_to_s3': True, 'script_url': 'https://raw.githubusercontent.com/4dn-dcic/tibanna/master/awsf/'}, 'workflow_uuid': 'd9e9c966-56d9-47e8-ae21-47f94a1af417', 'input_files': [{'workflow_argument_name': 'input_pairs', 'bucket_name': 'elasticbeanstalk-fourfront-webprod-wfoutput', 'uuid': [u'a9554821-af87-489d-bba6-f58d4286a2a3', u'817f3faa-0573-45c0-8230-02ec19de6544'], 'object_key': [u'4DNFICYJ9FOU.pairs.gz', u'4DNFI1ZLO9D7.pairs.gz']}, {'workflow_argument_name': 'chrsizes', 'bucket_name': 'elasticbeanstalk-fourfront-webprod-files', 'uuid': u'4a6d10ee-2edb-4402-a98f-0edb1d58f5e9', 'object_key': u'4DNFI823LSII.chrom.sizes'}]}
# about to start run partb_4DNESLLTENG9_set_
# response from aws was:
#  {u'startDate': datetime.datetime(2017, 9, 17, 14, 58, 29, 936000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '31cffee9-9bda-11e7-9a3a-c5cf032eab9f', 'HTTPHeaders': {'x-amzn-requestid': '31cffee9-9bda-11e7-9a3a-c5cf032eab9f', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:run_awsem_workflow_with_ponies:partb_4DNESLLTENG9_set_'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:run_awsem_workflow_with_ponies:partb_4DNESLLTENG9_set_
# Done
