# %%
from core.utils import Tibanna
from core import ff_utils
from core.utils import run_workflow
from datetime import datetime
from core.wfr import *

env = 'fourfront-webprod'
tibanna = Tibanna(env=env)
tibanna.ff_keys['default']['server'] = 'https://data.4dnucleome.org'
ff = ff_utils.fdn_connection(key=tibanna.ff_keys)
tibanna.ff_keys['default']['server'] = 'https://data.4dnucleome.org'
exclude_miseq = True

# %%
import time

# for a given experiment set and some parameters like instrument
# print set of files and their partA hic workflow status
# if there are one that are running report the number of running cases
# if there are file pairs that don't have a corresponding part A, report them separately

wf_dict =[
    {'wf_name': 'bwa-mem',
     'wf_uuid': '3feedadc-50f9-4bb4-919b-09a8b731d0cc',
     'parameters':{"nThreads": 16},
    },
    {'wf_name': 'hi-c-processing-bam',
     'wf_uuid': '023bfb3e-9a8b-42b9-a9d4-216079526f68',
     'parameters':{"nthreads_merge": 16, "nthreads_parse_sort": 16},
    },
    {'wf_name': 'hi-c-processing-pairs-nore',
     'wf_uuid': 'c19ee11e-9d5a-454f-af50-600a0cf990b6',
     'parameters': {"nthreads": 1, "maxmem": "32g"},
    }    
]

# url for micro-C Dnase exps
exp_types = ['micro-C', 'DNase%20Hi-C']
set_url = '/search/?'+ \
            '&'.join(['experiments_in_set.experiment_type='+i for i in exp_types])+ \
            '&type=ExperimentSetReplicate' + \
            '&status=released&status=released%20to%20project'
            
            
run_sets = ff_utils.get_metadata(set_url , connection=ff)['@graph']

add_pc = True
add_rel = True
add_wfr = True

counter = 0
completed = 0
completed_acc = []

all_sets = len(run_sets)
print(str(all_sets)+' total number of sets')
run_sets = [i for i in run_sets if "HiC_Pipeline_0.2.5"  not in i.get('completed_processes', [])]
print(str(all_sets-len(run_sets))+ ' sets completed')

for a_set in run_sets: 
    counter += 1

    print 
    fastqpairs, organism, enzyme, bwa_ref, chrsize_ref, enz_ref, f_size = find_pairs(a_set, exclude_miseq, ff, tibanna)

    if not bwa_ref or not chrsize_ref:
        print counter, a_set['accession'], organism, enzyme, 'skipping set with not chrsize/bwa index'
        continue
    
    if f_size < 15:
        print counter, a_set['accession'], 'skipping small file size', str(f_size) 
        continue
        
        
    print counter, a_set['accession']
    print enzyme, organism
    part3 = 'done'
    list_release = []
    set_pairs = []        
    # cycle through the experiments
    for exp in fastqpairs.keys():
        if not fastqpairs.get(exp):
            print(exp, 'does not have any fastq pairs')
            continue
        # Check Part 1 and See if all are okay
        exp_bams = []
        part1 = 'done'
        part2 = 'done'
        for pair in fastqpairs[exp]:
            #############
            bam1 = get_wfr_out(pair[0], 'bwa-mem 0.2.5', 'bam', ff)
            bam2 = get_wfr_out(pair[1], 'bwa-mem 0.2.5', 'bam', ff)
            # if run is not successful
            if bam1.startswith('no') or not bam1 or bam1 != bam2:
                part1 = 'not ready'
                if add_wfr:
                    if not bwa_index:
                        print 'not yet usable', organism
                        continue
                    inp_f = {'fastq1':pair[0], 'fastq2':pair[1], 'bwa_index':bwa_ref}
                    name_tag = pair[0].split('/')[2]+'_'+pair[1].split('/')[2]
                    run_missing_wfr(wf_dict[0], inp_f, name_tag, ff, env, tibanna)
            elif bam1 == 'running':
                part1 = 'still running'
                print('part1 still running')
            # if successful
            else:
                exp_bams.append(bam1)
                list_release.append(bam1)
        # stop progress to part2 
        if part1 is not 'done':
            print exp, 'has missing Part1 runs'
            part2 = 'not ready'
            part3 = 'not ready'
            continue
        print exp, 'part1 complete'
        #check if part 2 is run already, it not start the run
        exp_com_bam = []
        exp_pairs = []
        for bam in exp_bams:
            com_bam = get_wfr_out(bam, 'hi-c-processing-bam 0.2.5', 'bam', ff)
            pairs = get_wfr_out(bam, 'hi-c-processing-bam 0.2.5', 'pairs', ff)
            # try to run if missing
            if pairs.startswith('no') or not pairs:
                part2 = 'not ready'
                part3 = 'not ready'
                
            elif pairs == 'running':
                part2 = 'still running'
                part3 = 'not ready'
                
            else:
                exp_com_bam.append(com_bam)
                exp_pairs.append(pairs)
                
        # if still running, skip to next experiment
        if part2 == 'still running':
            print('part2 still running')
            continue
        
        # make sure all bams went through the same wfr and produces same file
        if part2 != 'done' or len(list(set(exp_com_bam))) != 1 or len(list(set(exp_pairs))) !=1:
            print exp, 'Part2 did not complete'
            part3 = 'not ready' 
        
            if add_wfr:
                if not chrsize_ref:
                    print 'not yet usable', organism
                    continue
                # make sure no duplicates
                inp_f = {'input_bams':exp_bams, 'chromsize':chrsize_ref}           
                run_missing_wfr(wf_dict[1], inp_f, exp, ff, env, tibanna)   
            continue
            
        # add bam and pairs to exp proc file
        list_release.extend([exp_com_bam[0],exp_pairs[0]])
        if add_pc:
            add_processed_files(exp, [exp_com_bam[0],exp_pairs[0]], ff)
        
        print exp, 'part2 complete'
        set_pairs.append(exp_pairs[0])
    
    if part3 != 'done':
        print 'Part3 not ready'
        continue
    
    if not set_pairs:
        print 'no pairs can be produced from this set'
        continue
        
    merged_pairs = []
    for set_pair in set_pairs:
        merged_pair = get_wfr_out(set_pair, 'hi-c-processing-pairs-nore 0.2.5', 'pairs', ff)
        hic = get_wfr_out(set_pair, 'hi-c-processing-pairs-nore 0.2.5', 'hic', ff)
        mcool = get_wfr_out(set_pair, 'hi-c-processing-pairs-nore 0.2.5', 'mcool', ff)
        normvec = get_wfr_out(set_pair, 'hi-c-processing-pairs-nore 0.2.5', 'normvector_juicerformat', ff)
        if merged_pair.startswith('no') or not merged_pair:
            part3 = 'not ready'
            break
        elif merged_pair == 'running':
            part3 = 'still running'
            break
        else:
            merged_pairs.append(merged_pair)
    
    
    # if part3 is still running report it, and skip the rest of the script
    if part3 == 'still running':
        print 'part3', part3
        continue        
                
    if part3 != 'done' or len(list(set(merged_pairs))) != 1:
        print a_set['accession'], 'is missing Part3'
        
        # if it is not run, and add_wfr is true, go for it, then skip the rest of the script
        if add_wfr:
            if not chrsize_ref:
                print 'not yet usable', organism
                continue

            inp_f = {'input_pairs':set_pairs, 'chromsizes':chrsize_ref} 
            run_missing_wfr(wf_dict[2], inp_f, a_set['accession'], ff, env, tibanna)
        continue
    #####
    #add competed flag to experiment
    if add_pc and add_rel:
        ff_utils.patch_metadata({"completed_processes":["HiC_Pipeline_0.2.5"]}, obj_id=a_set['accession'] ,connection=ff)
    
    # add processed files to set
    list_release.extend([merged_pair, hic, mcool, normvec])
    if add_pc:
        add_processed_files(a_set['accession'], [merged_pair, hic, mcool, normvec], ff)
    
    #release files and wfrs
    if add_rel:
        release_files(a_set['accession'], list(set(list_release)), ff)
    
    completed += 1
    completed_acc.append(a_set['accession'])
    print a_set['accession'], 'part3 complete'

    
print completed
print completed_acc
# Out:
# 14 total number of sets
# 0 sets completed
#
# 1 4DNESRWDFFF8
# DNaseI mouse
# about to start run bwa-mem_4DNFIFWQS5CQ_4DNFI5J6HNI2de231908-663c-4b16-bed4-839250b8a0b7
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 1, 34, 828000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'd883bd76-52e9-11e8-a9c8-6b7c0a01ee89', 'HTTPHeaders': {'x-amzn-requestid': 'd883bd76-52e9-11e8-a9c8-6b7c0a01ee89', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIFWQS5CQ_4DNFI5J6HNI2de231908-663c-4b16-bed4-839250b8a0b7'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIFWQS5CQ_4DNFI5J6HNI2de231908-663c-4b16-bed4-839250b8a0b7
# about to start run bwa-mem_4DNFII47CZIN_4DNFI2FNBFSIe961e531-1aab-4f14-a758-52354cd2a0e4
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 1, 36, 603000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'd9910f0c-52e9-11e8-95d7-ddb2057c13b9', 'HTTPHeaders': {'x-amzn-requestid': 'd9910f0c-52e9-11e8-95d7-ddb2057c13b9', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFII47CZIN_4DNFI2FNBFSIe961e531-1aab-4f14-a758-52354cd2a0e4'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFII47CZIN_4DNFI2FNBFSIe961e531-1aab-4f14-a758-52354cd2a0e4
# about to start run bwa-mem_4DNFIS9VYAEQ_4DNFI855CBHN0a0c7b08-7d80-4e30-97f9-c91121ee9d63
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 1, 38, 81000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'da718397-52e9-11e8-a2b7-cf1b194d47e5', 'HTTPHeaders': {'x-amzn-requestid': 'da718397-52e9-11e8-a2b7-cf1b194d47e5', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIS9VYAEQ_4DNFI855CBHN0a0c7b08-7d80-4e30-97f9-c91121ee9d63'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIS9VYAEQ_4DNFI855CBHN0a0c7b08-7d80-4e30-97f9-c91121ee9d63
# about to start run bwa-mem_4DNFIX7YTRJ1_4DNFI3VL55944690fc79-00bd-4f3a-9a6f-d880fa5be9de
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 1, 39, 579000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'db55c9cd-52e9-11e8-a44b-03a3a80501c2', 'HTTPHeaders': {'x-amzn-requestid': 'db55c9cd-52e9-11e8-a44b-03a3a80501c2', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIX7YTRJ1_4DNFI3VL55944690fc79-00bd-4f3a-9a6f-d880fa5be9de'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIX7YTRJ1_4DNFI3VL55944690fc79-00bd-4f3a-9a6f-d880fa5be9de
# about to start run bwa-mem_4DNFI9EXOVDG_4DNFIUKK696I1f60718a-75c4-4a67-b592-622d3af3de70
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 1, 41, 136000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'dc3e7b6a-52e9-11e8-a9c8-6b7c0a01ee89', 'HTTPHeaders': {'x-amzn-requestid': 'dc3e7b6a-52e9-11e8-a9c8-6b7c0a01ee89', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFI9EXOVDG_4DNFIUKK696I1f60718a-75c4-4a67-b592-622d3af3de70'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFI9EXOVDG_4DNFIUKK696I1f60718a-75c4-4a67-b592-622d3af3de70
# about to start run bwa-mem_4DNFIF2KE62Q_4DNFI3FVZHDH5eb17d86-8daa-48d4-9672-1a7ab6c70911
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 1, 42, 584000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'dd218894-52e9-11e8-ab40-f18b25a61a85', 'HTTPHeaders': {'x-amzn-requestid': 'dd218894-52e9-11e8-ab40-f18b25a61a85', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIF2KE62Q_4DNFI3FVZHDH5eb17d86-8daa-48d4-9672-1a7ab6c70911'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIF2KE62Q_4DNFI3FVZHDH5eb17d86-8daa-48d4-9672-1a7ab6c70911
# about to start run bwa-mem_4DNFI3G5K887_4DNFIMOIUKEJf9127de7-4a53-43e6-81c5-6adba75b7196
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 1, 44, 813000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'de772d7f-52e9-11e8-9b1f-25425af66925', 'HTTPHeaders': {'x-amzn-requestid': 'de772d7f-52e9-11e8-9b1f-25425af66925', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFI3G5K887_4DNFIMOIUKEJf9127de7-4a53-43e6-81c5-6adba75b7196'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFI3G5K887_4DNFIMOIUKEJf9127de7-4a53-43e6-81c5-6adba75b7196
# 4DNEXB8HHA81 has missing Part1 runs
# about to start run bwa-mem_4DNFIHAM81FI_4DNFILE7FSUR9e3dd1ee-34ab-44a5-afc4-6f9b9cf09741
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 1, 46, 578000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'df81e704-52e9-11e8-9059-8f8960dd49a4', 'HTTPHeaders': {'x-amzn-requestid': 'df81e704-52e9-11e8-9059-8f8960dd49a4', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIHAM81FI_4DNFILE7FSUR9e3dd1ee-34ab-44a5-afc4-6f9b9cf09741'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIHAM81FI_4DNFILE7FSUR9e3dd1ee-34ab-44a5-afc4-6f9b9cf09741
# about to start run bwa-mem_4DNFIV9NOEW9_4DNFI2NPZBQG8e90b36a-fe0c-4894-86db-af388a40dd66
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 1, 48, 242000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'e07ff5e6-52e9-11e8-945e-d94c58b4ba67', 'HTTPHeaders': {'x-amzn-requestid': 'e07ff5e6-52e9-11e8-945e-d94c58b4ba67', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIV9NOEW9_4DNFI2NPZBQG8e90b36a-fe0c-4894-86db-af388a40dd66'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIV9NOEW9_4DNFI2NPZBQG8e90b36a-fe0c-4894-86db-af388a40dd66
# about to start run bwa-mem_4DNFIWT3C79T_4DNFIUSSBJW9beaa2a7c-cd4f-4a59-ac7c-02e88f2743c4
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 1, 50, 533000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'e1e02292-52e9-11e8-9629-5feae093abf0', 'HTTPHeaders': {'x-amzn-requestid': 'e1e02292-52e9-11e8-9629-5feae093abf0', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIWT3C79T_4DNFIUSSBJW9beaa2a7c-cd4f-4a59-ac7c-02e88f2743c4'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIWT3C79T_4DNFIUSSBJW9beaa2a7c-cd4f-4a59-ac7c-02e88f2743c4
# about to start run bwa-mem_4DNFIM5J7ITO_4DNFIVPVSBOS900d04f9-b28b-48b0-9661-671017bde66f
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 1, 52, 322000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'e2ee8541-52e9-11e8-bd91-5ff45b64f1b1', 'HTTPHeaders': {'x-amzn-requestid': 'e2ee8541-52e9-11e8-bd91-5ff45b64f1b1', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIM5J7ITO_4DNFIVPVSBOS900d04f9-b28b-48b0-9661-671017bde66f'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIM5J7ITO_4DNFIVPVSBOS900d04f9-b28b-48b0-9661-671017bde66f
# 4DNEX8EW839G has missing Part1 runs
# Part3 not ready
#
# 2 4DNESWWRKZDK
# DNaseI mouse
# about to start run bwa-mem_4DNFIT8XH3UP_4DNFIUD1UOBMa89f9aa5-4d4a-4785-96b7-06dda760e34a
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 1, 55, 227000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'e4aa65e7-52e9-11e8-b4f2-f9e145779696', 'HTTPHeaders': {'x-amzn-requestid': 'e4aa65e7-52e9-11e8-b4f2-f9e145779696', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIT8XH3UP_4DNFIUD1UOBMa89f9aa5-4d4a-4785-96b7-06dda760e34a'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIT8XH3UP_4DNFIUD1UOBMa89f9aa5-4d4a-4785-96b7-06dda760e34a
# 4DNEXC8TTU1U has missing Part1 runs
# Part3 not ready
#
# 3 4DNESAGFJ56V skipping small file size 5
#
# 4 4DNES49IRGRY
# DNaseI mouse
# about to start run bwa-mem_4DNFIR2QRP2M_4DNFIHCFL38U1573ca86-3fe9-4cbf-b7c4-a8c1776744a9
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 1, 58, 765000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'e6c61988-52e9-11e8-9c2d-d7a07db091d9', 'HTTPHeaders': {'x-amzn-requestid': 'e6c61988-52e9-11e8-9c2d-d7a07db091d9', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIR2QRP2M_4DNFIHCFL38U1573ca86-3fe9-4cbf-b7c4-a8c1776744a9'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIR2QRP2M_4DNFIHCFL38U1573ca86-3fe9-4cbf-b7c4-a8c1776744a9
# 4DNEXYLI7G52 has missing Part1 runs
# Part3 not ready
#
# 5 4DNESNPYVXDM
# DNaseI mouse
# about to start run bwa-mem_4DNFIBMPWOE1_4DNFIXH5OV2Hfd1d08cd-2abc-4326-9388-25ae47545fda
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 2, 1, 917000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'e8a89575-52e9-11e8-a44b-03a3a80501c2', 'HTTPHeaders': {'x-amzn-requestid': 'e8a89575-52e9-11e8-a44b-03a3a80501c2', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIBMPWOE1_4DNFIXH5OV2Hfd1d08cd-2abc-4326-9388-25ae47545fda'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIBMPWOE1_4DNFIXH5OV2Hfd1d08cd-2abc-4326-9388-25ae47545fda
# 4DNEXBH5B94I has missing Part1 runs
# Part3 not ready
#
# 6 4DNESF8PGGTI
# DNaseI mouse
# about to start run bwa-mem_4DNFI6IQNUTJ_4DNFI8BF51LM554b64e9-fc4e-406e-81e0-d768d441a506
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 2, 6, 261000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'eb3ea926-52e9-11e8-a121-877ff04abbdd', 'HTTPHeaders': {'x-amzn-requestid': 'eb3ea926-52e9-11e8-a121-877ff04abbdd', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFI6IQNUTJ_4DNFI8BF51LM554b64e9-fc4e-406e-81e0-d768d441a506'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFI6IQNUTJ_4DNFI8BF51LM554b64e9-fc4e-406e-81e0-d768d441a506
# about to start run bwa-mem_4DNFIBA968MK_4DNFIPZ7L8M6e868d8b0-8c18-4c82-bf43-7ff3fb64f25c
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 2, 9, 645000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'ed437a8c-52e9-11e8-a670-e7710121a12e', 'HTTPHeaders': {'x-amzn-requestid': 'ed437a8c-52e9-11e8-a670-e7710121a12e', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIBA968MK_4DNFIPZ7L8M6e868d8b0-8c18-4c82-bf43-7ff3fb64f25c'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIBA968MK_4DNFIPZ7L8M6e868d8b0-8c18-4c82-bf43-7ff3fb64f25c
# about to start run bwa-mem_4DNFIZOQAXB5_4DNFIPEHMVRZ058d126e-e8fb-4582-bc4a-40f835a73927
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 2, 12, 487000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'eef262e6-52e9-11e8-9059-8f8960dd49a4', 'HTTPHeaders': {'x-amzn-requestid': 'eef262e6-52e9-11e8-9059-8f8960dd49a4', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIZOQAXB5_4DNFIPEHMVRZ058d126e-e8fb-4582-bc4a-40f835a73927'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIZOQAXB5_4DNFIPEHMVRZ058d126e-e8fb-4582-bc4a-40f835a73927
# about to start run bwa-mem_4DNFIEBA3XRV_4DNFIEQHWHC8386b3015-e2cd-4803-a63f-26bad883e524
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 2, 14, 718000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'f0487d51-52e9-11e8-9059-8f8960dd49a4', 'HTTPHeaders': {'x-amzn-requestid': 'f0487d51-52e9-11e8-9059-8f8960dd49a4', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIEBA3XRV_4DNFIEQHWHC8386b3015-e2cd-4803-a63f-26bad883e524'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIEBA3XRV_4DNFIEQHWHC8386b3015-e2cd-4803-a63f-26bad883e524
# 4DNEX8XQA6B5 has missing Part1 runs
# Part3 not ready
#
# 7 4DNESG15UT75
# DNaseI mouse
# about to start run bwa-mem_4DNFI7XPC1TK_4DNFI2VC7ZYLcf2f00da-c781-4921-b441-442b7a4c5f91
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 2, 24, 377000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'f60b6738-52e9-11e8-9b1f-25425af66925', 'HTTPHeaders': {'x-amzn-requestid': 'f60b6738-52e9-11e8-9b1f-25425af66925', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFI7XPC1TK_4DNFI2VC7ZYLcf2f00da-c781-4921-b441-442b7a4c5f91'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFI7XPC1TK_4DNFI2VC7ZYLcf2f00da-c781-4921-b441-442b7a4c5f91
# about to start run bwa-mem_4DNFIL18JWJT_4DNFIOWSEDWX1e338040-bab2-4ed5-a5a2-4d2e2b3e8864
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 2, 26, 64000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'f70b4ab4-52e9-11e8-aefb-633b0dcb112e', 'HTTPHeaders': {'x-amzn-requestid': 'f70b4ab4-52e9-11e8-aefb-633b0dcb112e', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIL18JWJT_4DNFIOWSEDWX1e338040-bab2-4ed5-a5a2-4d2e2b3e8864'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIL18JWJT_4DNFIOWSEDWX1e338040-bab2-4ed5-a5a2-4d2e2b3e8864
# about to start run bwa-mem_4DNFIRFKOOMO_4DNFIZZMC5UT0ce13171-040c-4050-9d3b-dd3fc2594c26
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 2, 28, 57000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'f83aca06-52e9-11e8-b8c4-77b7a166ab51', 'HTTPHeaders': {'x-amzn-requestid': 'f83aca06-52e9-11e8-b8c4-77b7a166ab51', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIRFKOOMO_4DNFIZZMC5UT0ce13171-040c-4050-9d3b-dd3fc2594c26'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIRFKOOMO_4DNFIZZMC5UT0ce13171-040c-4050-9d3b-dd3fc2594c26
# about to start run bwa-mem_4DNFIMZFKQRO_4DNFIQI87PTX72b29dd4-adb0-4c9a-abdb-1b0a4b426ece
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 2, 29, 929000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'f957f9c8-52e9-11e8-95d7-ddb2057c13b9', 'HTTPHeaders': {'x-amzn-requestid': 'f957f9c8-52e9-11e8-95d7-ddb2057c13b9', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIMZFKQRO_4DNFIQI87PTX72b29dd4-adb0-4c9a-abdb-1b0a4b426ece'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIMZFKQRO_4DNFIQI87PTX72b29dd4-adb0-4c9a-abdb-1b0a4b426ece
# 4DNEX3IVMKFZ has missing Part1 runs
# about to start run bwa-mem_4DNFIIW3UJMR_4DNFI6GRH8BG0161d782-253a-4567-8edc-991c810b6a2e
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 2, 32, 393000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'fad0ddfb-52e9-11e8-a9cb-11bebb895c71', 'HTTPHeaders': {'x-amzn-requestid': 'fad0ddfb-52e9-11e8-a9cb-11bebb895c71', 'content-length': '178', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIIW3UJMR_4DNFI6GRH8BG0161d782-253a-4567-8edc-991c810b6a2e'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:bwa-mem_4DNFIIW3UJMR_4DNFI6GRH8BG0161d782-253a-4567-8edc-991c810b6a2e
# 4DNEXXX48QKL has missing Part1 runs
# 4DNEXSURRHM7 part1 complete
# 4DNEXSURRHM7 Part2 did not complete
# about to start run hi-c-processing-bam_4DNEXSURRHM7866ac2ec-edd3-43a4-b107-f612f08344b3
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 2, 47, 808000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '040129b5-52ea-11e8-92c3-7f700d63b480', 'HTTPHeaders': {'x-amzn-requestid': '040129b5-52ea-11e8-92c3-7f700d63b480', 'content-length': '177', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-bam_4DNEXSURRHM7866ac2ec-edd3-43a4-b107-f612f08344b3'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-bam_4DNEXSURRHM7866ac2ec-edd3-43a4-b107-f612f08344b3
# Part3 not ready
#
# 8 4DNESZFHB53P
# DNaseI human
# 4DNEX778XE4J part1 complete
# 4DNEX778XE4J part2 complete
# 4DNEXEKTHDKQ part1 complete
# 4DNEXEKTHDKQ part2 complete
# 4DNESZFHB53P is missing Part3
# about to start run hi-c-processing-pairs-nore_4DNESZFHB53P68851e40-83cc-4543-bb2e-00607e41c76f
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 2, 56, 553000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '09373d65-52ea-11e8-9b21-1155316df1e2', 'HTTPHeaders': {'x-amzn-requestid': '09373d65-52ea-11e8-9b21-1155316df1e2', 'content-length': '184', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nore_4DNESZFHB53P68851e40-83cc-4543-bb2e-00607e41c76f'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nore_4DNESZFHB53P68851e40-83cc-4543-bb2e-00607e41c76f
#
# 9 4DNESGTHHJAC
# DNaseI human
# 4DNEXGBN93KT part1 complete
# 4DNEXGBN93KT part2 complete
# 4DNEXIIJKSEL part1 complete
# 4DNEXIIJKSEL part2 complete
# 4DNESGTHHJAC is missing Part3
# about to start run hi-c-processing-pairs-nore_4DNESGTHHJAC4b883a4d-66d8-4af5-a65d-230743dd1474
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 3, 16, 126000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '14e35e45-52ea-11e8-a1e0-63a4d4eb68ba', 'HTTPHeaders': {'x-amzn-requestid': '14e35e45-52ea-11e8-a1e0-63a4d4eb68ba', 'content-length': '184', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nore_4DNESGTHHJAC4b883a4d-66d8-4af5-a65d-230743dd1474'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nore_4DNESGTHHJAC4b883a4d-66d8-4af5-a65d-230743dd1474
#
# 10 4DNES6G787KF
# DNaseI human
# 4DNEXRGPHY4P part1 complete
# 4DNEXRGPHY4P part2 complete
# 4DNEXGZH6KEK part1 complete
# 4DNEXGZH6KEK part2 complete
# part3 still running
#
# 11 4DNESSU7RRNR
# DNaseI human
# 4DNEXR5M1VEX part1 complete
# 4DNEXR5M1VEX part2 complete
# 4DNEXWZTQFYP part1 complete
# 4DNEXWZTQFYP part2 complete
# part3 still running
#
# 12 4DNESW72J62T
# DNaseI human
# 4DNEXWPS7HX4 part1 complete
# 4DNEXWPS7HX4 part2 complete
# 4DNEX2BP2PR5 part1 complete
# 4DNEX2BP2PR5 part2 complete
# part3 still running
#
# 13 4DNESRCFT5AI
# MNase human
# 4DNEXQMEU2O4 part1 complete
# 4DNEXQMEU2O4 part2 complete
# 4DNEXWHALJ1K part1 complete
# 4DNEXWHALJ1K part2 complete
# 4DNEX9JAVMKE part1 complete
# 4DNEX9JAVMKE part2 complete
# 4DNEX24VTARO part1 complete
# 4DNEX24VTARO part2 complete
# 4DNESRCFT5AI is missing Part3
# about to start run hi-c-processing-pairs-nore_4DNESRCFT5AI6d156cb7-37b6-4f8b-a156-18c7c28ab48d
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 5, 4, 416000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '556fb8ef-52ea-11e8-bf18-5dfb9e4d99b2', 'HTTPHeaders': {'x-amzn-requestid': '556fb8ef-52ea-11e8-bf18-5dfb9e4d99b2', 'content-length': '184', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nore_4DNESRCFT5AI6d156cb7-37b6-4f8b-a156-18c7c28ab48d'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nore_4DNESRCFT5AI6d156cb7-37b6-4f8b-a156-18c7c28ab48d
#
# 14 4DNESCZJD9KK
# MNase human
# 4DNEXC1TYVLD part1 complete
# 4DNEXC1TYVLD part2 complete
# 4DNEX9TF73VI part1 complete
# 4DNEX9TF73VI part2 complete
# 4DNEXRJYVOZJ part1 complete
# 4DNEXRJYVOZJ part2 complete
# 4DNEXONC5BJ1 part1 complete
# 4DNEXONC5BJ1 part2 complete
# 4DNEX1MDLILR part1 complete
# 4DNEX1MDLILR part2 complete
# 4DNEX5F27GL2 part1 complete
# 4DNEX5F27GL2 part2 complete
# part3 still running
# 0
# []
