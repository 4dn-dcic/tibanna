# %%
from core.utils import Tibanna
from core import ff_utils
from core.utils import run_workflow
from datetime import datetime
from core.wfr import *

env = 'fourfront-webprod'
tibanna = Tibanna(env=env)
tibanna.ff_keys['default']['server'] = 'https://data.4dnucleome.org'
ff = ff_utils.fdn_connection(key=tibanna.ff_keys)
tibanna.ff_keys['default']['server'] = 'https://data.4dnucleome.org'
exclude_miseq = True

# %%
import time

# for a given experiment set and some parameters like instrument
# print set of files and their partA hic workflow status
# if there are one that are running report the number of running cases
# if there are file pairs that don't have a corresponding part A, report them separately

wf_dict =[
    {'wf_name': 'bwa-mem',
     'wf_uuid': '3feedadc-50f9-4bb4-919b-09a8b731d0cc',
     'parameters':{"nThreads": 16},
    },
    {'wf_name': 'hi-c-processing-bam',
     'wf_uuid': '023bfb3e-9a8b-42b9-a9d4-216079526f68',
     'parameters':{"nthreads_merge": 16, "nthreads_parse_sort": 16},
    },
    {'wf_name': 'hi-c-processing-pairs-nonorm',
     'wf_uuid': 'bd6e25ea-f368-4758-a821-d30e0b5a4100',
     'parameters': {"nthreads": 1, "maxmem": "32g"},
    }    
]

# url for hic exps
exp_types = ['capture%20Hi-C', 'PLAC-seq']
set_url = '/search/?'+ \
            '&'.join(['experiments_in_set.experiment_type='+i for i in exp_types])+ \
            '&type=ExperimentSetReplicate' + \
            '&status=released&status=released%20to%20project'
run_sets = ff_utils.get_metadata(set_url , connection=ff)['@graph']

add_pc = True
add_rel = True
add_wfr = True

counter = 0
completed = 0
completed_acc = []

all_sets = len(run_sets)
print(str(all_sets)+' total number of sets')
run_sets = [i for i in run_sets if "HiC_Pipeline_0.2.5"  not in i.get('completed_processes', [])]
print(str(all_sets-len(run_sets))+ ' sets completed')

for a_set in run_sets: 
    counter += 1

    print

    fastqpairs, organism, enzyme, bwa_ref, chrsize_ref, enz_ref, f_size = find_pairs(a_set, exclude_miseq, ff, tibanna)

    if not bwa_ref or not chrsize_ref:
        print counter, a_set['accession'], organism, enzyme, 'skipping set with not chrsize/bwa index'
        continue
    
    if not enz_ref:
        print counter, a_set['accession'], 'skipping not ready NZ', organism, enzyme
        continue
    
#     if f_size < 0.00001:
#         print counter, a_set['accession'], 'skipping small file size', str(f_size) 
#         continue
        
        
    print counter, a_set['accession']
    print enzyme, organism
    part3 = 'done'
    list_release = []
    set_pairs = []        
    # cycle through the experiments
    for exp in fastqpairs.keys():
        if not fastqpairs.get(exp):
            print(exp, 'does not have any fastq pairs')
            continue
        # Check Part 1 and See if all are okay
        exp_bams = []
        part1 = 'done'
        part2 = 'done'
        for pair in fastqpairs[exp]:
            #############
            bam1 = get_wfr_out(pair[0], 'bwa-mem 0.2.5', 'bam', ff)
            bam2 = get_wfr_out(pair[1], 'bwa-mem 0.2.5', 'bam', ff)
            # if run is not successful
            if bam1.startswith('no') or not bam1 or bam1 != bam2:
                part1 = 'not ready'
                if add_wfr:
                    if not bwa_index:
                        print 'not yet usable', organism
                        continue
                    inp_f = {'fastq1':pair[0], 'fastq2':pair[1], 'bwa_index':bwa_ref}
                    name_tag = pair[0].split('/')[2]+'_'+pair[1].split('/')[2]
                    run_missing_wfr(wf_dict[0], inp_f, name_tag, ff, env, tibanna)
            elif bam1 == 'running':
                part1 = 'still running'
                print('part1 still running')
            # if successful
            else:
                exp_bams.append(bam1)
                list_release.append(bam1)
        # stop progress to part2 
        if part1 is not 'done':
            print exp, 'has missing Part1 runs'
            part2 = 'not ready'
            part3 = 'not ready'
            continue
        print exp, 'part1 complete'
        #check if part 2 is run already, it not start the run
        exp_com_bam = []
        exp_pairs = []
        for bam in exp_bams:
            com_bam = get_wfr_out(bam, 'hi-c-processing-bam 0.2.5', 'bam', ff)
            pairs = get_wfr_out(bam, 'hi-c-processing-bam 0.2.5', 'pairs', ff)
            # try to run if missing
            if pairs.startswith('no') or not pairs:
                part2 = 'not ready'
                part3 = 'not ready'
                
            elif pairs == 'running':
                part2 = 'still running'
                part3 = 'not ready'
                
            else:
                exp_com_bam.append(com_bam)
                exp_pairs.append(pairs)
                
        # if still running, skip to next experiment
        if part2 == 'still running':
            print('part2 still running')
            continue
        
        # make sure all bams went through the same wfr and produces same file
        if part2 != 'done' or len(list(set(exp_com_bam))) != 1 or len(list(set(exp_pairs))) !=1:
            print exp, 'Part2 did not complete'
            part3 = 'not ready' 
        
            if add_wfr:
                if not chrsize_ref:
                    print 'not yet usable', organism
                    continue
                # make sure no duplicates
                inp_f = {'input_bams':exp_bams, 'chromsize':chrsize_ref}           
                run_missing_wfr(wf_dict[1], inp_f, exp, ff, env, tibanna)   
            continue
            
        # add bam and pairs to exp proc file
        list_release.extend([exp_com_bam[0],exp_pairs[0]])
        if add_pc:
            add_processed_files(exp, [exp_com_bam[0],exp_pairs[0]], ff)
        
        print exp, 'part2 complete'
        set_pairs.append(exp_pairs[0])
    
    if part3 != 'done':
        print 'Part3 not ready'
        continue
    
    if not set_pairs:
        print 'no pairs can be produced from this set'
        continue
        
    merged_pairs = []
    for set_pair in set_pairs:
        merged_pair = get_wfr_out(set_pair, 'hi-c-processing-pairs-nonorm 0.2.5', 'pairs', ff)
        hic = get_wfr_out(set_pair, 'hi-c-processing-pairs-nonorm 0.2.5', 'hic', ff)
        mcool = get_wfr_out(set_pair, 'hi-c-processing-pairs-nonorm 0.2.5', 'mcool', ff)
        normvec = get_wfr_out(set_pair, 'hi-c-processing-pairs-nonorm 0.2.5', 'normvector_juicerformat', ff)
        if merged_pair.startswith('no') or not merged_pair:
            part3 = 'not ready'
            break
        elif merged_pair == 'running':
            part3 = 'still running'
            break
        else:
            merged_pairs.append(merged_pair)
    
    
    # if part3 is still running report it, and skip the rest of the script
    if part3 == 'still running':
        print 'part3', part3
        continue        
                
    if part3 != 'done' or len(list(set(merged_pairs))) != 1:
        print a_set['accession'], 'is missing Part3'
        
        # if it is not run, and add_wfr is true, go for it, then skip the rest of the script
        if add_wfr:
            if not chrsize_ref:
                print 'not yet usable', organism
                continue

            if not enz_ref:
                print 'restriction enzyme not ready for', organism, enzyme
                continue
            inp_f = {'input_pairs':set_pairs, 'chromsizes':chrsize_ref, 'restriction_file': enz_ref} 
            run_missing_wfr(wf_dict[2], inp_f, a_set['accession'], ff, env, tibanna)
        continue
    #####
    #add competed flag to experiment
    if add_pc and add_rel:
        ff_utils.patch_metadata({"completed_processes":["HiC_Pipeline_0.2.5"]}, obj_id=a_set['accession'] ,connection=ff)
    
    # add processed files to set
    list_release.extend([merged_pair, hic, mcool, normvec])
    if add_pc:
        add_processed_files(a_set['accession'], [merged_pair, hic, mcool, normvec], ff)
    
    #release files and wfrs
    if add_rel:
        release_files(a_set['accession'], list(set(list_release)), ff)
    
    completed += 1
    completed_acc.append(a_set['accession'])
    print a_set['accession'], 'part3 complete'

    
print completed
print completed_acc
# Out:
# 30 total number of sets
# 0 sets completed
#
# 1 4DNESIF5UIQE
# MboI human
# 4DNEXIUJ7REK part1 complete
# 4DNEXIUJ7REK part2 complete
# 4DNEXANS985X part1 complete
# 4DNEXANS985X part2 complete
# part3 still running
#
# 2 4DNESQMO66LZ
# MboI human
# 4DNEXLV8HIAA part1 complete
# 4DNEXLV8HIAA part2 complete
# 4DNEXMN2HP68 part1 complete
# 4DNEXMN2HP68 part2 complete
# part3 still running
#
# 3 4DNESTZUCQH5
# MboI human
# 4DNEXQXUGDXG part1 complete
# 4DNEXQXUGDXG part2 complete
# part3 still running
#
# 4 4DNES8TLFCMQ
# MboI human
# 4DNEX2VTRKTP part1 complete
# 4DNEX2VTRKTP part2 complete
# part3 still running
#
# 5 4DNESQ9YYPQZ
# MboI human
# 4DNEXFETO9VX part1 complete
# 4DNEXFETO9VX part2 complete
# 4DNEXCQ2ZNXO part1 complete
# 4DNEXCQ2ZNXO part2 complete
# part3 still running
#
# 6 4DNES917ZVA6
# MboI human
# 4DNEX83M7A57 part1 complete
# 4DNEX83M7A57 part2 complete
# 4DNES917ZVA6 is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNES917ZVA6a91497c9-54c3-4887-9f39-c3b82ffaa1ac
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 23, 3, 231000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'd8766fc3-52ec-11e8-9fba-4f88e26e006c', 'HTTPHeaders': {'x-amzn-requestid': 'd8766fc3-52ec-11e8-9fba-4f88e26e006c', 'content-length': '186', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNES917ZVA6a91497c9-54c3-4887-9f39-c3b82ffaa1ac'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNES917ZVA6a91497c9-54c3-4887-9f39-c3b82ffaa1ac
#
# 7 4DNESWPMRBIZ
# MboI human
# 4DNEXYUI9JCI part1 complete
# 4DNEXYUI9JCI part2 complete
# 4DNEXPSSVEUO part1 complete
# 4DNEXPSSVEUO part2 complete
# part3 still running
#
# 8 4DNESNI4PPYX
# MboI human
# 4DNEX7JISNEA part1 complete
# 4DNEX7JISNEA part2 complete
# part3 still running
#
# 9 4DNESAVVP47G
# MboI human
# 4DNEX4XIH9I8 part1 complete
# 4DNEX4XIH9I8 part2 complete
# part3 still running
#
# 10 4DNES2ZDGCY5
# MboI human
# 4DNEX1GEXL4R part1 complete
# 4DNEX1GEXL4R part2 complete
# part3 still running
#
# 11 4DNESA2R77LP
# MboI human
# 4DNEX47BWKZQ part1 complete
# 4DNEX47BWKZQ part2 complete
# 4DNEXX33SRFJ part1 complete
# 4DNEXX33SRFJ part2 complete
# part3 still running
#
# 12 4DNESVGV5YDR
# MboI human
# 4DNEXF6CEY13 part1 complete
# 4DNEXF6CEY13 part2 complete
# 4DNEXAKJPY9Y part1 complete
# 4DNEXAKJPY9Y part2 complete
# part3 still running
#
# 13 4DNES4A1BNPI
# MboI human
# 4DNEXMNAPSO2 part1 complete
# 4DNEXMNAPSO2 part2 complete
# 4DNEX914EZ8N part1 complete
# 4DNEX914EZ8N part2 complete
# part3 still running
#
# 14 4DNESR1UBP9L
# MboI human
# 4DNEXAJWZB18 part1 complete
# 4DNEXAJWZB18 part2 complete
# 4DNEXR9SQK76 part1 complete
# 4DNEXR9SQK76 part2 complete
# 4DNEX9WXSU5B part1 complete
# 4DNEX9WXSU5B part2 complete
# 4DNESR1UBP9L is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNESR1UBP9L01afe6be-c811-47b0-9b08-29cd26fbdbe9
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 26, 23, 376000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '4fc2c014-52ed-11e8-b798-d1d7d77a2191', 'HTTPHeaders': {'x-amzn-requestid': '4fc2c014-52ed-11e8-b798-d1d7d77a2191', 'content-length': '186', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESR1UBP9L01afe6be-c811-47b0-9b08-29cd26fbdbe9'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESR1UBP9L01afe6be-c811-47b0-9b08-29cd26fbdbe9
#
# 15 4DNESNOJ28YT
# MboI human
# 4DNEXRZJ37CB part1 complete
# 4DNEXRZJ37CB part2 complete
# 4DNEXURO3NJZ part1 complete
# 4DNEXURO3NJZ part2 complete
# 4DNESNOJ28YT is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNESNOJ28YT2e255ad9-664a-4c85-baf7-3a97b3fb206d
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 26, 55, 637000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '62f96b55-52ed-11e8-b3f4-eb97e80abb31', 'HTTPHeaders': {'x-amzn-requestid': '62f96b55-52ed-11e8-b3f4-eb97e80abb31', 'content-length': '186', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESNOJ28YT2e255ad9-664a-4c85-baf7-3a97b3fb206d'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESNOJ28YT2e255ad9-664a-4c85-baf7-3a97b3fb206d
#
# 16 4DNESMSJXT8O
# MboI human
# 4DNEXVKIGPTN part1 complete
# 4DNEXVKIGPTN part2 complete
# 4DNEX8KBUJ6S part1 complete
# 4DNEX8KBUJ6S part2 complete
# 4DNESMSJXT8O is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNESMSJXT8Oeb8eb355-4fa0-4fa2-bb99-6ab283f758b0
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 27, 31, 954000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '78a0c996-52ed-11e8-945e-d94c58b4ba67', 'HTTPHeaders': {'x-amzn-requestid': '78a0c996-52ed-11e8-945e-d94c58b4ba67', 'content-length': '186', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESMSJXT8Oeb8eb355-4fa0-4fa2-bb99-6ab283f758b0'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESMSJXT8Oeb8eb355-4fa0-4fa2-bb99-6ab283f758b0
#
# 17 4DNESNCK7FEW
# MboI human
# 4DNEXJ9DMCWX part1 complete
# 4DNEXJ9DMCWX part2 complete
# 4DNEX4IKF8FY part1 complete
# 4DNEX4IKF8FY part2 complete
# 4DNESNCK7FEW is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNESNCK7FEWa8d935a6-5c5c-49f2-ac96-d5dbf5212f31
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 28, 9, 963000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '8f483187-52ed-11e8-a616-05ee53c17964', 'HTTPHeaders': {'x-amzn-requestid': '8f483187-52ed-11e8-a616-05ee53c17964', 'content-length': '186', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESNCK7FEWa8d935a6-5c5c-49f2-ac96-d5dbf5212f31'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESNCK7FEWa8d935a6-5c5c-49f2-ac96-d5dbf5212f31
#
# 18 4DNESLBTEN66
# MboI human
# 4DNEX88KQH75 part1 complete
# 4DNEX88KQH75 part2 complete
# 4DNESLBTEN66 is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNESLBTEN66d3361911-e37d-40b9-8385-48e192b4943d
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 28, 33, 57000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '9d0b24f2-52ed-11e8-bd91-5ff45b64f1b1', 'HTTPHeaders': {'x-amzn-requestid': '9d0b24f2-52ed-11e8-bd91-5ff45b64f1b1', 'content-length': '186', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESLBTEN66d3361911-e37d-40b9-8385-48e192b4943d'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESLBTEN66d3361911-e37d-40b9-8385-48e192b4943d
#
# 19 4DNES5YI4ZCE
# MboI human
# 4DNEXLFZA8EQ part1 complete
# 4DNEXLFZA8EQ part2 complete
# 4DNES5YI4ZCE is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNES5YI4ZCEd273ba09-15f3-44ea-bbe8-593253e494c0
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 28, 46, 481000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'a50d9ed2-52ed-11e8-9b1f-25425af66925', 'HTTPHeaders': {'x-amzn-requestid': 'a50d9ed2-52ed-11e8-9b1f-25425af66925', 'content-length': '186', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNES5YI4ZCEd273ba09-15f3-44ea-bbe8-593253e494c0'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNES5YI4ZCEd273ba09-15f3-44ea-bbe8-593253e494c0
# 20 4DNESZ4F7V39
# MboI human
# 4DNEXCVXZY97 part1 complete
# 4DNEXCVXZY97 part2 complete
# 4DNESZ4F7V39 is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNESZ4F7V3932712188-899e-40ef-b3f9-81f91bb895e2
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 29, 0, 85000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'ad283465-52ed-11e8-945e-d94c58b4ba67', 'HTTPHeaders': {'x-amzn-requestid': 'ad283465-52ed-11e8-945e-d94c58b4ba67', 'content-length': '186', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESZ4F7V3932712188-899e-40ef-b3f9-81f91bb895e2'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESZ4F7V3932712188-899e-40ef-b3f9-81f91bb895e2
#
# 21 4DNESRF2JLP3
# MboI human
# 4DNEX9GCPXZN part1 complete
# 4DNEX9GCPXZN part2 complete
# 4DNEXHG5WSK5 part1 complete
# 4DNEXHG5WSK5 part2 complete
# 4DNESRF2JLP3 is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNESRF2JLP3f2786e5a-fd4c-4801-b7cc-2612d2236a82
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 29, 29, 455000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'bea792a0-52ed-11e8-973b-f9f090a87219', 'HTTPHeaders': {'x-amzn-requestid': 'bea792a0-52ed-11e8-973b-f9f090a87219', 'content-length': '186', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESRF2JLP3f2786e5a-fd4c-4801-b7cc-2612d2236a82'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESRF2JLP3f2786e5a-fd4c-4801-b7cc-2612d2236a82
#
# 22 4DNESWQ4K74H
# MboI human
# 4DNEXWQOA5OG part1 complete
# 4DNEXWQOA5OG part2 complete
# 4DNEXCGG8BKP part1 complete
# 4DNEXCGG8BKP part2 complete
# 4DNEXT66BJKO part1 complete
# 4DNEXT66BJKO part2 complete
# 4DNEXMCKZQUA part1 complete
# 4DNEXMCKZQUA part2 complete
# 4DNESWQ4K74H is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNESWQ4K74H73178860-0d87-48e5-a855-e6bd627e9495
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 30, 34, 433000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'e564b8a1-52ed-11e8-95d7-ddb2057c13b9', 'HTTPHeaders': {'x-amzn-requestid': 'e564b8a1-52ed-11e8-95d7-ddb2057c13b9', 'content-length': '186', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESWQ4K74H73178860-0d87-48e5-a855-e6bd627e9495'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESWQ4K74H73178860-0d87-48e5-a855-e6bd627e9495
#
# 23 4DNESWZZWT68
# MboI human
# 4DNEXGG59BQC part1 complete
# 4DNEXGG59BQC part2 complete
# 4DNEXR4F5WJJ part1 complete
# 4DNEXR4F5WJJ part2 complete
# 4DNEXJIB98HQ part1 complete
# 4DNEXJIB98HQ part2 complete
# 4DNEX4SJDB52 part1 complete
# 4DNEX4SJDB52 part2 complete
# 4DNESWZZWT68 is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNESWZZWT6824e11381-5d61-414b-98a8-a7453c61c615
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 31, 42, 624000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '0e09fdbb-52ee-11e8-a670-e7710121a12e', 'HTTPHeaders': {'x-amzn-requestid': '0e09fdbb-52ee-11e8-a670-e7710121a12e', 'content-length': '186', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESWZZWT6824e11381-5d61-414b-98a8-a7453c61c615'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESWZZWT6824e11381-5d61-414b-98a8-a7453c61c615
#
# 24 4DNESAYH7WXY
# MboI human
# 4DNEX7FI4QSK part1 complete
# 4DNEX7FI4QSK part2 complete
# 4DNESAYH7WXY is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNESAYH7WXY
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 32, 2, 278000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '19c05882-52ee-11e8-aefb-633b0dcb112e', 'HTTPHeaders': {'x-amzn-requestid': '19c05882-52ee-11e8-aefb-633b0dcb112e', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESAYH7WXY'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESAYH7WXY
#
# 25 4DNESWFRUPLR
# MboI human
# 4DNEXY744GG9 part1 complete
# 4DNEXY744GG9 part2 complete
# 4DNEXK179IOV part1 complete
# 4DNEXK179IOV part2 complete
# 4DNEX8KPXKZE part1 complete
# 4DNEX8KPXKZE part2 complete
# 4DNEXU2KZRN9 part1 complete
# 4DNEXU2KZRN9 Part2 did not complete
# about to start run hi-c-processing-bam_4DNEXU2KZRN9
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 33, 21, 171000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '48c7394c-52ee-11e8-9f38-9feb95690f22', 'HTTPHeaders': {'x-amzn-requestid': '48c7394c-52ee-11e8-9f38-9feb95690f22', 'content-length': '141', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-bam_4DNEXU2KZRN9'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-bam_4DNEXU2KZRN9
# Part3 not ready
#
# 26 4DNESYP3AUZS
# MboI human
# 4DNEXBAAXHZW part1 complete
# 4DNEXBAAXHZW part2 complete
# 4DNESYP3AUZS is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNESYP3AUZS
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 33, 40, 708000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '546aa819-52ee-11e8-b4f2-f9e145779696', 'HTTPHeaders': {'x-amzn-requestid': '546aa819-52ee-11e8-b4f2-f9e145779696', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESYP3AUZS'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESYP3AUZS
#
# 27 4DNESJWXORCI
# MboI human
# 4DNEXDG1ROVP part1 complete
# 4DNEXDG1ROVP part2 complete
# 4DNEX8SFWCYB part1 complete
# 4DNEX8SFWCYB part2 complete
# 4DNEXQ9SRQJN part1 complete
# 4DNEXQ9SRQJN part2 complete
# 4DNEXLWSXULR part1 complete
# 4DNEXLWSXULR part2 complete
# 4DNESJWXORCI is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNESJWXORCIe560a202-ab8b-4b75-879b-d1d2ad061eaf
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 35, 3, 574000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '85ce8c19-52ee-11e8-9e49-0bc691c74612', 'HTTPHeaders': {'x-amzn-requestid': '85ce8c19-52ee-11e8-9e49-0bc691c74612', 'content-length': '186', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESJWXORCIe560a202-ab8b-4b75-879b-d1d2ad061eaf'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESJWXORCIe560a202-ab8b-4b75-879b-d1d2ad061eaf
# 28 4DNES3CUDIXW
# MboI human
# 4DNEX1BOSCUW part1 complete
# 4DNEX1BOSCUW Part2 did not complete
# about to start run hi-c-processing-bam_4DNEX1BOSCUW
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 35, 31, 63000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '96332c0f-52ee-11e8-b2c8-23a1b1d005e0', 'HTTPHeaders': {'x-amzn-requestid': '96332c0f-52ee-11e8-b2c8-23a1b1d005e0', 'content-length': '141', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-bam_4DNEX1BOSCUW'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-bam_4DNEX1BOSCUW
# 4DNEX5PPVGJN part1 complete
# 4DNEX5PPVGJN part2 complete
# 4DNEXU67SGF3 part1 complete
# 4DNEXU67SGF3 part2 complete
# 4DNEXPUK1J27 part1 complete
# 4DNEXPUK1J27 part2 complete
# Part3 not ready
#
# 29 4DNESG4XBHWB
# MboI human
# 4DNEXV22N38P part1 complete
# 4DNEXV22N38P part2 complete
# 4DNEXFHWUX8H part1 complete
# 4DNEXFHWUX8H part2 complete
# 4DNEXTJBAHTN part1 complete
# 4DNEXTJBAHTN part2 complete
# 4DNEX23TSUEX part1 complete
# 4DNEX23TSUEX part2 complete
# 4DNESG4XBHWB is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNESG4XBHWB0fadd70a-f989-4fd4-a940-ca85e9385f9d
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 37, 27, 699000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': 'dbb81b31-52ee-11e8-b81e-f746968fa635', 'HTTPHeaders': {'x-amzn-requestid': 'dbb81b31-52ee-11e8-b81e-f746968fa635', 'content-length': '186', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESG4XBHWB0fadd70a-f989-4fd4-a940-ca85e9385f9d'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESG4XBHWB0fadd70a-f989-4fd4-a940-ca85e9385f9d
#
# 30 4DNESEYZC9D9
# MboI human
# 4DNEX8VI8Q77 part1 complete
# 4DNEX8VI8Q77 part2 complete
# 4DNEX5H8FKJV part1 complete
# 4DNEX5H8FKJV part2 complete
# 4DNEXRIDF1WQ part1 complete
# 4DNEXRIDF1WQ part2 complete
# 4DNEXAF8PXDJ part1 complete
# 4DNEXAF8PXDJ part2 complete
# 4DNEX4RF5AW7 part1 complete
# 4DNEX4RF5AW7 part2 complete
# 4DNEXTIGW52V part1 complete
# 4DNEXTIGW52V part2 complete
# 4DNEX9UG6UO9 part1 complete
# 4DNEX9UG6UO9 part2 complete
# 4DNESEYZC9D9 is missing Part3
# about to start run hi-c-processing-pairs-nonorm_4DNESEYZC9D9
# response from aws was:
#  {u'startDate': datetime.datetime(2018, 5, 8, 14, 39, 31, 211000, tzinfo=tzlocal()), 'ResponseMetadata': {'RetryAttempts': 0, 'HTTPStatusCode': 200, 'RequestId': '25583821-52ef-11e8-845f-091819cb0998', 'HTTPHeaders': {'x-amzn-requestid': '25583821-52ef-11e8-845f-091819cb0998', 'content-length': '150', 'content-type': 'application/x-amz-json-1.0'}}, u'executionArn': u'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESEYZC9D9'}
# url to view status:
# https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:hi-c-processing-pairs-nonorm_4DNESEYZC9D9
# 0
# []
